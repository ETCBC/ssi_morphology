# %%
# %%html
# <style>
#     table {float:left}
# </style>
# Out:
# <style>
#     table {float:left}
# </style>

# %% [markdown]
# First step: read the analysis of the model errors into a data frame.
#
# The legend of the column headers is as follows.
#
# Mnemonic|Description
# :-----|:-----
# ec|Error class {1: "in beam", 2: "not in beam", 3: "no correct solutions"}
# lex|Lexeme
# ls|Lexical set
# sp|Part of speech
# pfm|Preformative
# vbs|Verbal stem
# vbe|Verbal ending
# nme|Nominal ending
# prs|Pronominal suffix
# vt|Verbal tense
# ps|Person
# nu|Number
# gn|Gender
# st|State
# form|Input form

# %%
from pandas import factorize, read_csv

df = read_csv('model_errors.csv')

# %%
df
# Out:
#        ec      lex  ls  sp  pfm  vbs  vbe  nme  prs  vt  ps  nu  gn  st  \
# 0       1     R<H[   0   1    1    0    1    6    0   4   0   0   0   0
# 1       1     ZMM/   0   2   -1   -1   -1    1    6  -1  -1   1   2   2
# 2       1  >LJHW=/   0   3   -1   -1   -1    1   -1  -1  -1   1   2   0
# 3       3     KWL[   0   1    0    1    3    0   13   2   2   1   2  -1
# 4       1     MS</   0   2   -1   -1   -1    5   12  -1  -1   3   2   2
# ...    ..      ...  ..  ..  ...  ...  ...  ...  ...  ..  ..  ..  ..  ..
# 22238   2     BLQ[   0   1    7    4    1    2    0  62   0   1   1   2
# 22239   1     LQX[   0   1    2    0    1    0    8   1   3   1   2  -1
# 22240   2  DBR===/   0   2   -1   -1   -1    5    4  -1  -1   3   2   2
# 22241   2     DBR[  -1   1    0    0    1    5    0   6   0   3   2   1
# 22242   1       >T   0   5   -1   -1   -1   -1    4  -1  -1  -1  -1  -1
#
#                  form
# 0          !!R<(H[/WT
# 1              ZMM/+W
# 2             >LJHW=/
# 3      K(WL&K&L[T:d+M
# 4            MS</J+HM
# ...               ...
# 22238    !M!BLQ[/H:du
# 22239      !J!(LQX[+H
# 22240      DBR===/J+K
# 22241          DBR[/J
# 22242          >&WT+K
#
# [22243 rows x 15 columns]

# %%
# What are the sizes of the error classes?
df['ec'].value_counts()
# Out:
# 1    10899
# 2    10255
# 3     1089
# Name: ec, dtype: int64

# %% [markdown]
# Our goal is to discover whether there is any relation between the error classes and the input forms. The numbers in the analysis of the input forms are not quantities, but codes. So we are dealing with categorical data. Let us therefore factorize the data, but keep the original ordering of the values, because there is some logic to it.

# %%
# Create the correlation matrix (cm)
cm = df.apply(lambda x : factorize(x, sort=True)[0]).corr()

# %%
cm
# Out:
#             ec       lex        ls        sp       pfm       vbs       vbe  \
# ec    1.000000  0.018982  0.001724  0.028676  0.011926  0.062948 -0.005075
# lex   0.018982  1.000000  0.062335 -0.021713  0.012756  0.030054  0.009608
# ls    0.001724  0.062335  1.000000 -0.173208  0.092505  0.104931  0.071526
# sp    0.028676 -0.021713 -0.173208  1.000000 -0.296331 -0.318431 -0.238741
# pfm   0.011926  0.012756  0.092505 -0.296331  1.000000  0.554387  0.332915
# vbs   0.062948  0.030054  0.104931 -0.318431  0.554387  1.000000  0.355796
# vbe  -0.005075  0.009608  0.071526 -0.238741  0.332915  0.355796  1.000000
# nme   0.059388 -0.009279 -0.066146  0.158720 -0.287681 -0.317255 -0.343667
# prs   0.011801 -0.023887 -0.023035 -0.090798 -0.013230 -0.039969 -0.057712
# vt    0.036430  0.009015  0.099490 -0.321818  0.378911  0.462039  0.166522
# ps   -0.041921  0.029922  0.116522 -0.373064  0.524977  0.591973  0.544935
# nu    0.010359  0.018031 -0.017551  0.016536 -0.018999 -0.028301  0.290918
# gn   -0.047717  0.027051 -0.037861  0.056211 -0.094689 -0.057784 -0.151842
# st    0.022935 -0.018093 -0.088154  0.206867 -0.359174 -0.380760 -0.468163
# form  0.004403  0.395463 -0.029865  0.206633 -0.541687 -0.277775 -0.243076
#
#            nme       prs        vt        ps        nu        gn        st  \
# ec    0.059388  0.011801  0.036430 -0.041921  0.010359 -0.047717  0.022935
# lex  -0.009279 -0.023887  0.009015  0.029922  0.018031  0.027051 -0.018093
# ls   -0.066146 -0.023035  0.099490  0.116522 -0.017551 -0.037861 -0.088154
# sp    0.158720 -0.090798 -0.321818 -0.373064  0.016536  0.056211  0.206867
# pfm  -0.287681 -0.013230  0.378911  0.524977 -0.018999 -0.094689 -0.359174
# vbs  -0.317255 -0.039969  0.462039  0.591973 -0.028301 -0.057784 -0.380760
# vbe  -0.343667 -0.057712  0.166522  0.544935  0.290918 -0.151842 -0.468163
# nme   1.000000  0.109041 -0.065739 -0.540582  0.454711  0.024891  0.581602
# prs   0.109041  1.000000 -0.043472  0.013718  0.025768  0.002858  0.196354
# vt   -0.065739 -0.043472  1.000000  0.233481 -0.090934 -0.070836  0.019242
# ps   -0.540582  0.013718  0.233481  1.000000  0.055319  0.050702 -0.733981
# nu    0.454711  0.025768 -0.090934  0.055319  1.000000  0.228798  0.076740
# gn    0.024891  0.002858 -0.070836  0.050702  0.228798  1.000000  0.072170
# st    0.581602  0.196354  0.019242 -0.733981  0.076740  0.072170  1.000000
# form  0.224179 -0.034695 -0.246181 -0.334948  0.153391  0.137710  0.238779
#
#           form
# ec    0.004403
# lex   0.395463
# ls   -0.029865
# sp    0.206633
# pfm  -0.541687
# vbs  -0.277775
# vbe  -0.243076
# nme   0.224179
# prs  -0.034695
# vt   -0.246181
# ps   -0.334948
# nu    0.153391
# gn    0.137710
# st    0.238779
# form  1.000000

# %%
# Which columns have the strongest correlation?  We need to exclude
# the diagonal, because we are not interested in the correlation of
# a column with itself, which is 1.

from numpy import eye

n = cm.shape[0]
ix = cm.mask(eye(n, dtype=bool)).stack().idxmax()
print('Positive:', cm[ix[0]][ix[1]], "at", ix)
# Out:
# Positive: 0.5919734187073089 at ('vbs', 'ps')

# %%
# Which columns have the strongest negative correlation?
ix = df.corr().stack().idxmin()
print('Negative:', cm[ix[0]][ix[1]], "at", ix)
# Out:
# Negative: -0.7339812597765805 at ('ps', 'st')

# %% [markdown]
# These values make sense; so this rather crude approach may work for our purpose. Person is greatly determined by verbs and a nominal with state cannot have a value for person. As were are trying to spot noticeable effects
# regardless of whether they are positive of negative, let us make a table of the absolute value of the correspondences.

# %%
cm.apply(lambda x: abs(x)).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_5985c_row0_col0,#T_5985c_row1_col1,#T_5985c_row2_col2,#T_5985c_row3_col3,#T_5985c_row4_col4,#T_5985c_row5_col5,#T_5985c_row6_col6,#T_5985c_row7_col7,#T_5985c_row8_col8,#T_5985c_row9_col9,#T_5985c_row10_col10,#T_5985c_row11_col11,#T_5985c_row12_col12,#T_5985c_row13_col13,#T_5985c_row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_5985c_row0_col1,#T_5985c_row0_col8,#T_5985c_row4_col0,#T_5985c_row4_col8,#T_5985c_row4_col11,#T_5985c_row8_col0,#T_5985c_row10_col8,#T_5985c_row11_col0,#T_5985c_row11_col1,#T_5985c_row13_col1,#T_5985c_row13_col9{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_5985c_row0_col2,#T_5985c_row0_col4,#T_5985c_row0_col6,#T_5985c_row0_col11,#T_5985c_row0_col14,#T_5985c_row1_col4,#T_5985c_row1_col5,#T_5985c_row1_col7,#T_5985c_row1_col9,#T_5985c_row1_col13,#T_5985c_row2_col0,#T_5985c_row4_col1,#T_5985c_row6_col0,#T_5985c_row6_col1,#T_5985c_row7_col1,#T_5985c_row8_col4,#T_5985c_row8_col10,#T_5985c_row8_col12,#T_5985c_row9_col1,#T_5985c_row9_col13,#T_5985c_row11_col3,#T_5985c_row11_col5,#T_5985c_row12_col8,#T_5985c_row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_5985c_row0_col3,#T_5985c_row3_col1,#T_5985c_row8_col1,#T_5985c_row8_col5,#T_5985c_row8_col11{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_5985c_row0_col5,#T_5985c_row5_col8,#T_5985c_row12_col2,#T_5985c_row12_col10{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_5985c_row0_col7,#T_5985c_row10_col12{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_5985c_row0_col9,#T_5985c_row0_col10,#T_5985c_row8_col14,#T_5985c_row12_col5,#T_5985c_row14_col2{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_5985c_row0_col12,#T_5985c_row10_col11,#T_5985c_row12_col0{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_5985c_row0_col13,#T_5985c_row1_col3,#T_5985c_row1_col6,#T_5985c_row1_col11,#T_5985c_row2_col11,#T_5985c_row3_col11,#T_5985c_row11_col4{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_5985c_row1_col0,#T_5985c_row1_col10,#T_5985c_row5_col11,#T_5985c_row11_col2,#T_5985c_row12_col1,#T_5985c_row12_col7{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_5985c_row1_col2,#T_5985c_row5_col0,#T_5985c_row11_col13,#T_5985c_row12_col9{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_5985c_row1_col8,#T_5985c_row2_col8,#T_5985c_row5_col1,#T_5985c_row7_col12,#T_5985c_row8_col2,#T_5985c_row10_col1,#T_5985c_row11_col8,#T_5985c_row13_col0{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_5985c_row1_col12,#T_5985c_row2_col14,#T_5985c_row3_col0{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_5985c_row1_col14{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_5985c_row2_col1,#T_5985c_row3_col12,#T_5985c_row8_col6{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_5985c_row2_col3,#T_5985c_row6_col9{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_5985c_row2_col4,#T_5985c_row2_col5,#T_5985c_row9_col11{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_5985c_row2_col6,#T_5985c_row6_col2,#T_5985c_row9_col12,#T_5985c_row13_col11,#T_5985c_row13_col12{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_5985c_row2_col7,#T_5985c_row5_col12,#T_5985c_row6_col8,#T_5985c_row7_col0,#T_5985c_row7_col9,#T_5985c_row9_col7,#T_5985c_row12_col13{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_5985c_row2_col9,#T_5985c_row4_col2,#T_5985c_row4_col12{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_5985c_row2_col10,#T_5985c_row5_col2{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_5985c_row2_col12,#T_5985c_row8_col9,#T_5985c_row9_col0,#T_5985c_row14_col8{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_5985c_row2_col13{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_5985c_row3_col2{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_5985c_row3_col4,#T_5985c_row11_col6{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_5985c_row3_col5,#T_5985c_row7_col5{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_5985c_row3_col6,#T_5985c_row13_col14{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_5985c_row3_col7,#T_5985c_row6_col12,#T_5985c_row11_col14{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_5985c_row3_col8,#T_5985c_row13_col2{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_5985c_row3_col9{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_5985c_row3_col10{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_5985c_row3_col13,#T_5985c_row13_col3,#T_5985c_row13_col8,#T_5985c_row14_col3{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_5985c_row3_col14{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_5985c_row4_col3,#T_5985c_row6_col11{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_5985c_row4_col5,#T_5985c_row4_col14,#T_5985c_row10_col6{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_5985c_row4_col6,#T_5985c_row10_col14{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_5985c_row4_col7,#T_5985c_row7_col4{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_5985c_row4_col9,#T_5985c_row9_col4{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_5985c_row4_col10,#T_5985c_row10_col4{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_5985c_row4_col13{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_5985c_row5_col3{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_5985c_row5_col4{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_5985c_row5_col6{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_5985c_row5_col7,#T_5985c_row9_col3{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_5985c_row5_col9,#T_5985c_row6_col13{
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }#T_5985c_row5_col10{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_5985c_row5_col13{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_5985c_row5_col14{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_5985c_row6_col3,#T_5985c_row9_col10,#T_5985c_row10_col9,#T_5985c_row14_col13{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_5985c_row6_col4,#T_5985c_row14_col10{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_5985c_row6_col5,#T_5985c_row6_col7{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_5985c_row6_col10,#T_5985c_row10_col7,#T_5985c_row14_col4{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_5985c_row6_col14,#T_5985c_row14_col6,#T_5985c_row14_col9{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_5985c_row7_col2{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_5985c_row7_col3,#T_5985c_row12_col6{
#             background

# %% [markdown]
# Unfortunately I do not see clear signs of a relationship between the error classes and the other parameters of the analysis. The correlation with verbal stem is slightly higher. That could be because forms with verbal stem are relatively rare (17% of the analytical dictionary) and therefore less trained on.
#
# The slightly elevated value for nominal ending I cannot completely explain. The incidence of the nominal endings in the model errors (62%) is comparable to that in the analytical dictionary (59%). There is, however, some fluctuation in the distribution over the values of nominal ending, as is shown below.

# %%
# Create a data frame with the relative frequencies of the values
# for nominal ending in the list of model errors (rf_me).
rf_me = df.nme.value_counts(normalize=True)
rf_me = rf_me.rename_axis('nme').reset_index(name='relfreq')

# %%
# Create a data frame with the relative frequencies of the values
# for nominal ending in the analytical dictionary (rf_ad).
from pandas import DataFrame

nme_anwb = DataFrame([[0, 13074], [1, 10772], [5, 2006], [4, 1732], [3, 1602], [6, 1577], 
[2, 1018], [12, 615], [-1, 343], [13, 147], [7, 142], [14, 45], [16, 20], [9, 20
], [17, 18], [15, 12], [10, 3]], columns=['nme', 'freq'])

rf_ad = nme_anwb['relfreq'] = nme_anwb.freq/nme_anwb.freq.sum()
rf_ad = rf_ad.rename_axis('nme').reset_index(name='relfreq')

# Merge the two on column 'nme'
rfs = rf_me.merge(rf_ad, on='nme')
rfs.columns = ['nme', 'me', 'ad']
rfs['diff'] = (rfs.me - rfs.ad)/(rfs.me + rfs.ad)
rfs
# Out:
#     nme        me        ad      diff
# 0     0  0.366048  0.394437 -0.037330
# 1     1  0.350672  0.324986  0.038016
# 2     6  0.056647  0.030713  0.296870
# 3     4  0.056602  0.048332  0.078816
# 4     5  0.055208  0.047577  0.074242
# 5     3  0.043654  0.052254 -0.089664
# 6     2  0.034483  0.060520 -0.274069
# 7    12  0.013487  0.000603  0.914357
# 8     7  0.004900  0.018554 -0.582138
# 9    13  0.004226  0.000603  0.750120
# 10   14  0.001888  0.000543  0.553280
# 11    9  0.000809  0.004435 -0.691374
# 12   15  0.000539  0.000362  0.196844
# 13   16  0.000450  0.000091  0.664838
