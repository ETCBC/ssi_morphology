# %%
import os, collections

import pandas as pd
import numpy as np

from sklearn.utils import shuffle

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/your_project_folder/'
# Out:
# Mounted at /content/gdrive

# %%
def read_data_from_file(filename, data_dict):

    with open(filename) as fp:
        line = fp.readline()
        while line:
            bo, ch, ve, text = tuple(line.strip().split('\t'))
            words = text.split()
            for w in words:  
                # in the output data, composite placenames have a '_', which cannot be found in the input data
                words_split = w.split('_')               
                for word_split in words_split:
                    data_dict[bo].append(word_split)
        
            line = fp.readline()
            
    return data_dict

# %% [markdown]
# # Nieuwe sectie

# %%
input_file = '/content/t-in_voc'
input_data = collections.defaultdict(list)

output_file = '/content/t-out'
output_data = collections.defaultdict(list)

input_data = read_data_from_file(input_file, input_data)
output_data = read_data_from_file(output_file, output_data)

# %%
print(len(input_data['Gen']))
print(len(output_data['Gen']))
# Out:
# 20611
# 20611

# %%
input_data['Gen'][0:10]
# Out:
# ['B.:R;>CIJT',
#  'B.@R@>',
#  '>:ELOHIJM',
#  '>;T',
#  'HAC.@MAJIM',
#  'W:>;T',
#  'H@>@REY',
#  'W:H@>@REY',
#  'H@J:T@H',
#  'TOHW.']

# %%
output_data['Gen'][0:10]
# Out:
# ['B-R>CJT/',
#  'BR>[',
#  '>LH(J(M/JM',
#  '>T',
#  'H-CMJ(M/(JM',
#  'W->T',
#  'H->RY/:a',
#  'W-H->RY/:a',
#  'HJ(H[&TH',
#  'THW/']

# %%
def make_in_out_sequences(data_dict, sequence_length):
    
    all_sequences = []
    for words_list in data_dict.values():

        for w in range(len(words_list) - sequence_length + 1):
    
            seq = ' '.join([words_list[ind] for ind in list(range(w, w + sequence_length))])
        
            # remove some special signs from output data (':', and '='). These only make the sequences longer.
            seq = seq.replace("=", "").replace(":a", "a").replace(":c", "c").replace(":d", "d").replace(":du", "du")
            all_sequences.append(seq)
        
    return all_sequences

# %%
sequence_length = 1

all_in_seqs = make_in_out_sequences(input_data, sequence_length)
all_out_seqs = make_in_out_sequences(output_data, sequence_length)

# %%
all_in_seqs[0:10]
# Out:
# ['B.:R;>CIJT',
#  'B.@R@>',
#  '>:ELOHIJM',
#  '>;T',
#  'HAC.@MAJIM',
#  'W:>;T',
#  'H@>@REY',
#  'W:H@>@REY',
#  'H@J:T@H',
#  'TOHW.']

# %%
print(len(all_in_seqs))
print(len(all_out_seqs))
# Out:
# 300676
# 300676

# %%
for i in range(206000,206020):
  print(all_in_seqs[i], '---', all_out_seqs[i])
# Out:
# B.:BOW>@M --- B-!!BW>[/+M
# J@BOW> --- !J!BW>[
# W.B:Y;>T@M --- W-B-!!(JY>[/T+M
# J;Y;>W. --- !J!(JY>[W
# W.BAXAG.IJM --- W-B-(H-XG/JM
# W.BAM.OW<:ADIJM --- W-B-(H-MW<D/JM
# T.IH:JEH --- !T!HJH[
# HAM.IN:X@H --- H-MNX(H/H
# >;JP@H --- >JP(H/H
# LAP.@R --- L-(H-PR/a
# W:>;JP@H --- W->JP(H/H
# L@>AJIL --- L-(H->JL/a
# W:LAK.:B@FIJM --- W-L-(H-KBF/JM
# MAT.AT --- MTT/
# J@DOW --- JD/+W
# W:CEMEN --- W-CMN/
# HIJN --- HJN/
# L@>;JP@H --- L-(H->JP(H/H
# W:KIJ --- W-KJ
# JA<:AFEH --- !J!<FH[

# %%
def prepare_train_data(input_data, output_data):

    input_seqs = []
    output_seqs = []
    input_chars = set()
    output_chars = set()

    # iterate over all the books
    for seq in range(len(input_data)): 
      
        #if len(output_data[seq]) > 40:
        #  continue
          
        if "*" in input_data[seq]: # cases of ketiv/qere are complicated, just skip them!
          continue

        input_list = list(input_data[seq])

        output_list = list(output_data[seq])
        output_list = ['\t'] + output_list + ['\n']

        input_seqs.append(input_list)
        output_seqs.append(output_list)

        for input_ch in input_list:
            input_chars.add(input_ch)
        
        for output_ch in output_list:
            output_chars.add(output_ch)
                
    
    input_chars = sorted(list(input_chars))
    output_chars = sorted(list(output_chars))
    
    max_len_input = max([len(seq) for seq in input_seqs])
    max_len_output = max([len(seq) for seq in output_seqs])
    
    # shuffle the data. The model will get the data in small batches, it is preferable if the batches are more or less homogeneous
    # of course the inputs and outputs have to be shuffled identically
    input_seqs, output_seqs = shuffle(input_seqs, output_seqs)
    
    return input_seqs, output_seqs, input_chars, output_chars, max_len_input, max_len_output

# %%
def create_dicts(input_voc, output_voc):
    
    # these dicts map the input sequences
    input_idx2char = {}
    input_char2idx = {}

    for k, v in enumerate(input_voc):
        input_idx2char[k] = v
        input_char2idx[v] = k
     
    # and these dicts map the output sequences of parts of speech
    output_idx2char = {}
    output_char2idx = {}
    
    for k, v in enumerate(output_voc):
        output_idx2char[k] = v
        output_char2idx[v] = k
        
    return input_idx2char, input_char2idx, output_idx2char, output_char2idx

# %%
def one_hot_encode(nb_samples, max_len_input, max_len_output, input_chars, output_chars, input_char2idx, output_char2idx, input_seqs, output_seqs):
    
    # three-dimensional numpy arrays are created 
    tokenized_input = np.zeros(shape = (nb_samples, max_len_input, len(input_chars)), dtype='float32')
    tokenized_output = np.zeros(shape = (nb_samples, max_len_output, len(output_chars)), dtype='float32')
    target_data = np.zeros((nb_samples, max_len_output, len(output_chars)), dtype='float32')

    for i in range(nb_samples):
        for k, ch in enumerate(input_seqs[i]):
            tokenized_input[i, k, input_char2idx[ch]] = 1
        
        for k, ch in enumerate(output_seqs[i]):
            tokenized_output[i, k, output_char2idx[ch]] = 1

            # decoder_target_data will be ahead by one timestep and will not include the start character.
            if k > 0:
                target_data[i, k-1, output_char2idx[ch]] = 1
                
    return tokenized_input, tokenized_output, target_data

# %%
from tensorflow.keras.layers import Attention

def define_LSTM_model(input_chars, output_chars):

    # encoder model
    encoder_input = Input(shape=(None,len(input_chars)))
    encoder_LSTM = LSTM(50,activation='relu',return_state=True, return_sequences=True)(encoder_input)
    encoder_LSTM = LSTM(50,return_state=True)(encoder_LSTM)
    encoder_outputs, encoder_h, encoder_c = encoder_LSTM
    encoder_states = [encoder_h, encoder_c]
    

    # decoder model
    decoder_input = Input(shape=(None,len(output_chars)))
    decoder_LSTM = LSTM(50, return_sequences=True, return_state = True)
    decoder_out1, _ , _ = decoder_LSTM(decoder_input, initial_state=encoder_states)
    decoder_dense = Dense(len(output_chars), activation='softmax')
    decoder_out2 = decoder_dense(decoder_out1)

    # Attention layer
    attention_layer = Attention()([encoder_outputs, decoder_out1])
  

    model = Model(inputs=[encoder_input, decoder_input],outputs=[decoder_out2])

    model.summary()

    return encoder_input, encoder_states, decoder_input, decoder_out2, decoder_dense, model

# %%
def compile_and_train(model, one_hot_in, one_hot_out, targets, batch_size, epochs, val_split):

    callback = EarlyStopping(monitor='val_loss', patience=3, verbose=0, mode='auto')
    adam = Adam(lr=0.0006, beta_1=0.995, beta_2=0.999, epsilon=0.00000001)
    model.compile(optimizer=adam, loss='categorical_crossentropy')
    model.fit(x=[one_hot_in,one_hot_out], 
              y=targets,
              batch_size=batch_size,
              epochs=epochs,
              validation_split=val_split,
              callbacks=[callback])
    
    return model

# %%
input_seqs, output_seqs, input_chars, output_chars, max_len_input, max_len_output = prepare_train_data(all_in_seqs, all_out_seqs)
print(len(input_seqs))
# Out:
# 299488

# %%
input_idx2char, input_char2idx, output_idx2char, output_char2idx = create_dicts(input_chars, output_chars)

nb_samples = len(input_seqs)
one_hot_input, one_hot_output, target_data = one_hot_encode(nb_samples, max_len_input, max_len_output, input_chars, output_chars, input_char2idx, output_char2idx, input_seqs, output_seqs)

# %%
train_size = 290000

one_hot_input_train = one_hot_input[0:train_size]
one_hot_output_train = one_hot_output[0:train_size]
target_data_train = target_data[0:train_size]

# %%
print(max_len_input, max_len_output)
# Out:
# 23 28

# %%
encoder_input, encoder_states, decoder_input, decoder_dense, attention_layer, model = define_LSTM_model(input_chars, output_chars)
model = compile_and_train(model, one_hot_input_train, one_hot_output_train, target_data_train, 1024, 150, 0.05)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 32)]   0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, None, 50), ( 16600       input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 42)]   0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50), (None,  20200       lstm[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, None, 50), ( 18600       input_2[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 42)     2142        lstm_2[0][0]
# ==================================================================================================
# Total params: 57,542
# Trainable params: 57,542
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/150
# 270/270 [==============================] - 37s 105ms/step - loss: 0.9033 - val_loss: 0.8598
# Epoch 2/150
# 270/270 [==============================] - 28s 104ms/step - loss: 0.8502 - val_loss: 0.8415
# Epoch 3/150
# 270/270 [==============================] - 28s 104ms/step - loss: 0.8367 - val_loss: 0.8282
# Epoch 4/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.8217 - val_loss: 0.8135
# Epoch 5/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.8049 - val_loss: 0.7961
# Epoch 6/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.7855 - val_loss: 0.7751
# Epoch 7/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.7634 - val_loss: 0.7504
# Epoch 8/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.7402 - val_loss: 0.7283
# Epoch 9/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.7178 - val_loss: 0.7048
# Epoch 10/150
# 270/270 [==============================] - 28s 102ms/step - loss: 0.6961 - val_loss: 0.6840
# Epoch 11/150
# 270/270 [==============================] - 29s 106ms/step - loss: 0.6751 - val_loss: 0.6626
# Epoch 12/150
# 270/270 [==============================] - 28s 102ms/step - loss: 0.6569 - val_loss: 0.6482
# Epoch 13/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.6402 - val_loss: 0.6327
# Epoch 14/150
# 270/270 [==============================] - 28s 102ms/step - loss: 0.6245 - val_loss: 0.6166
# Epoch 15/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.6094 - val_loss: 0.6016
# Epoch 16/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.5967 - val_loss: 0.5903
# Epoch 17/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.5847 - val_loss: 0.5796
# Epoch 18/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.5732 - val_loss: 0.5687
# Epoch 19/150
# 270/270 [==============================] - 27s 99ms/step - loss: 0.5628 - val_loss: 0.5581
# Epoch 20/150
# 270/270 [==============================] - 26s 97ms/step - loss: 0.5533 - val_loss: 0.5486
# Epoch 21/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.5445 - val_loss: 0.5394
# Epoch 22/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.5361 - val_loss: 0.5312
# Epoch 23/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.5278 - val_loss: 0.5264
# Epoch 24/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.5204 - val_loss: 0.5186
# Epoch 25/150
# 270/270 [==============================] - 28s 103ms/step - loss: 0.5139 - val_loss: 0.5144
# Epoch 26/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.5070 - val_loss: 0.5050
# Epoch 27/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.5007 - val_loss: 0.4983
# Epoch 28/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.4947 - val_loss: 0.4958
# Epoch 29/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.4899 - val_loss: 0.4855
# Epoch 30/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4846 - val_loss: 0.4829
# Epoch 31/150
# 270/270 [==============================] - 27s 99ms/step - loss: 0.4795 - val_loss: 0.4791
# Epoch 32/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.4750 - val_loss: 0.4767
# Epoch 33/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.4712 - val_loss: 0.4727
# Epoch 34/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.4666 - val_loss: 0.4658
# Epoch 35/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4632 - val_loss: 0.4638
# Epoch 36/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.4594 - val_loss: 0.4604
# Epoch 37/150
# 270/270 [==============================] - 28s 103ms/step - loss: 0.4564 - val_loss: 0.4603
# Epoch 38/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4526 - val_loss: 0.4523
# Epoch 39/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4499 - val_loss: 0.4511
# Epoch 40/150
# 270/270 [==============================] - 27s 99ms/step - loss: 0.4474 - val_loss: 0.4506
# Epoch 41/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4442 - val_loss: 0.4438
# Epoch 42/150
# 270/270 [==============================] - 26s 98ms/step - loss: 0.4413 - val_loss: 0.4432
# Epoch 43/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4383 - val_loss: 0.4393
# Epoch 44/150
# 270/270 [==============================] - 28s 103ms/step - loss: 0.4355 - val_loss: 0.4363
# Epoch 45/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4332 - val_loss: 0.4325
# Epoch 46/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.4322 - val_loss: 0.4305
# Epoch 47/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4298 - val_loss: 0.4308
# Epoch 48/150
# 270/270 [==============================] - 26s 98ms/step - loss: 0.4281 - val_loss: 0.4276
# Epoch 49/150
# 270/270 [==============================] - 26s 97ms/step - loss: 0.4258 - val_loss: 0.4288
# Epoch 50/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4237 - val_loss: 0.4244
# Epoch 51/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4223 - val_loss: 0.4224
# Epoch 52/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.4210 - val_loss: 0.4238
# Epoch 53/150
# 270/270 [==============================] - 28s 103ms/step - loss: 0.4188 - val_loss: 0.4225
# Epoch 54/150
# 270/270 [==============================] - 28s 102ms/step - loss: 0.4170 - val_loss: 0.4167
# Epoch 55/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.4144 - val_loss: 0.4195
# Epoch 56/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.4122 - val_loss: 0.4131
# Epoch 57/150
# 270/270 [==============================] - 26s 98ms/step - loss: 0.4104 - val_loss: 0.4103
# Epoch 58/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.4086 - val_loss: 0.4113
# Epoch 59/150
# 270/270 [==============================] - 26s 98ms/step - loss: 0.4070 - val_loss: 0.4064
# Epoch 60/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.4056 - val_loss: 0.4071
# Epoch 61/150
# 270/270 [==============================] - 27s 99ms/step - loss: 0.4042 - val_loss: 0.4070
# Epoch 62/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4033 - val_loss: 0.4040
# Epoch 63/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.4016 - val_loss: 0.4064
# Epoch 64/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.4005 - val_loss: 0.4014
# Epoch 65/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.3990 - val_loss: 0.4034
# Epoch 66/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.3981 - val_loss: 0.4023
# Epoch 67/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.3964 - val_loss: 0.3973
# Epoch 68/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3954 - val_loss: 0.4006
# Epoch 69/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.3944 - val_loss: 0.3967
# Epoch 70/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.3931 - val_loss: 0.3972
# Epoch 71/150
# 270/270 [==============================] - 27s 99ms/step - loss: 0.3920 - val_loss: 0.3928
# Epoch 72/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.3911 - val_loss: 0.3962
# Epoch 73/150
# 270/270 [==============================] - 28s 102ms/step - loss: 0.3900 - val_loss: 0.3971
# Epoch 74/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.3897 - val_loss: 0.3921
# Epoch 75/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3884 - val_loss: 0.3901
# Epoch 76/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3873 - val_loss: 0.3885
# Epoch 77/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3868 - val_loss: 0.3929
# Epoch 78/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.3852 - val_loss: 0.3877
# Epoch 79/150
# 270/270 [==============================] - 27s 99ms/step - loss: 0.3838 - val_loss: 0.3862
# Epoch 80/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3832 - val_loss: 0.3893
# Epoch 81/150
# 270/270 [==============================] - 28s 103ms/step - loss: 0.3825 - val_loss: 0.3827
# Epoch 82/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3815 - val_loss: 0.3851
# Epoch 83/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3808 - val_loss: 0.3834
# Epoch 84/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.3799 - val_loss: 0.3817
# Epoch 85/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.3797 - val_loss: 0.3833
# Epoch 86/150
# 270/270 [==============================] - 27s 101ms/step - loss: 0.3785 - val_loss: 0.3803
# Epoch 87/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.3818 - val_loss: 0.3850
# Epoch 88/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.3798 - val_loss: 0.3792
# Epoch 89/150
# 270/270 [==============================] - 28s 103ms/step - loss: 0.3781 - val_loss: 0.3807
# Epoch 90/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3767 - val_loss: 0.3768
# Epoch 91/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3762 - val_loss: 0.3786
# Epoch 92/150
# 270/270 [==============================] - 27s 102ms/step - loss: 0.3754 - val_loss: 0.3785
# Epoch 93/150
# 270/270 [==============================] - 27s 100ms/step - loss: 0.3747 - val_loss: 0.3805

# %%
# Encoder inference model
encoder_model_inf = Model(encoder_input, encoder_states)

# Decoder inference model
decoder_input = Input(shape=(None,len(output_chars)))
decoder_LSTM = LSTM(50, return_sequences=True, return_state = True)
decoder_out1, _ , _ = decoder_LSTM(decoder_input, initial_state=encoder_states)
decoder_dense = Dense(len(output_chars), activation='softmax')
decoder_out2 = decoder_dense(decoder_out1)
decoder_state_input_h = Input(shape=(50,))
decoder_state_input_c = Input(shape=(50,))
decoder_input_states = [decoder_state_input_h, decoder_state_input_c]
decoder_LSTM = LSTM(50, return_sequences=True, return_state = True)

decoder_out1, decoder_h, decoder_c = decoder_LSTM(decoder_input)

decoder_states = [decoder_h , decoder_c]

decoder_out = decoder_dense(decoder_out1)

decoder_model_inf = Model(inputs=[decoder_input] + decoder_input_states,
                          outputs=[decoder_out] + decoder_states )

# %%
def decode_seq(inp_seq):

    states_val = encoder_model_inf.predict(inp_seq)

    target_seq = np.zeros((1, 1, len(output_chars)))
    target_seq[0, 0, output_char2idx['\t']] = 1

    predicted_seq = []
    stop_condition = False
    

    while not stop_condition:

        decoder_out, decoder_h, decoder_c = decoder_model_inf.predict(x=[target_seq] + states_val)

        max_val_index = np.argmax(decoder_out[0,-1,:])
        sampled_out_char = output_idx2char[max_val_index]
        predicted_seq.append(sampled_out_char)

        if (sampled_out_char == '\n' or len(predicted_seq) >= max_length):
            stop_condition = True

        target_seq = np.zeros((1, 1, len(output_chars)))
        target_seq[0, 0, max_val_index] = 1

        states_val = [decoder_h, decoder_c]

    return predicted_seq

# %%
all_preds = []

in_ind = train_size + 1
out_ind = len(one_hot_input)
max_length = 15

#in_ind = 0
#out_ind = 1000
  
inputs = input_seqs[in_ind:out_ind]
one_hot_test_data = one_hot_input[in_ind:out_ind]
output_seqs_test = output_seqs[in_ind:out_ind]


for seq_index in range(len(one_hot_test_data)):
    inp_seq = one_hot_test_data[seq_index:seq_index+1]
    
    predicted_sequence = decode_seq(inp_seq)
    
    true_val = ''.join(output_seqs_test[seq_index][1:-1])
    pred_val = ''.join(predicted_sequence[0:-1])
    #print(''.join(inputs[seq_index]), true_val, pred_val)
    print(seq_index)
    all_preds.append((''.join(inputs[seq_index]), true_val, pred_val))
# Out:
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# 4487
# 4488
# 4489
# 4490
# 4491
# 4492
# 4493
# 4494
# 4495
# 4496
# 4497
# 4498
# 4499
# 4500
# 4501
# 4502
# 4503
# 4504
# 4505
# 4506
# 4507
# 4508
# 4509
# 4510
# 4511
# 4512
# 4513
# 4514
# 4515
# 4516
# 4517
# 4518
# 4519
# 4520
# 4521
# 4522
# 4523
# 4524
# 4525
# 4526
# 4527
# 4528
# 4529
# 4530
# 4531
# 4532
# 4533
# 4534
# 4535
# 4536
# 4537
# 4538
# 4539
# 4540
# 4541
# 4542
# 4543
# 4544
# 4545
# 4546
# 4547
# 4548
# 4549
# 4550
# 4551
# 4552
# 4553
# 4554
# 4555
# 4556
# 4557
# 4558
# 4559
# 4560
# 4561
# 4562
# 4563
# 4564
# 4565
# 4566
# 4567
# 4568
# 4569
# 4570
# 4571
# 4572
# 4573
# 4574
# 4575
# 4576
# 4577
# 4578
# 4579
# 4580
# 4581
# 4582
# 4583
# 4584
# 4585
# 4586
# 4587
# 4588
# 4589
# 4590
# 4591
# 4592
# 4593
# 4594
# 4595
# 4596
# 4597
# 4598
# 4599
# 4600
# 4601
# 4602
# 4603
# 4604
# 4605
# 4606
# 4607
# 4608
# 4609
# 4610
# 4611
# 4612
# 4613
# 4614
# 4615
# 4616
# 4617
# 4618
# 4619
# 4620
# 4621
# 4622
# 4623
# 4624
# 4625
# 4626
# 4627
# 4628
# 4629
# 4630
# 4631
# 4632
# 4633
# 4634
# 4635
# 4636
# 4637
# 4638
# 4639
# 4640
# 4641
# 4642
# 4643
# 4644
# 4645
# 4646
# 4647
# 4648
# 4649
# 4650
# 4651
# 4652
# 4653
# 4654
# 4655
# 4656
# 4657
# 4658
# 4659
# 4660
# 4661
# 4662
# 4663
# 4664
# 4665
# 4666
# 4667
# 4668
# 4669
# 4670
# 4671
# 4672
# 4673
# 4674
# 4675
# 4676
# 4677
# 4678
# 4679
# 4680
# 4681
# 4682
# 4683
# 4684
# 4685
# 4686
# 4687
# 4688
# 4689
# 4690
# 4691
# 4692
# 4693
# 4694
# 4695
# 4696
# 4697
# 4698
# 4699
# 4700
# 4701
# 4702
# 4703
# 4704
# 4705
# 4706
# 4707
# 4708
# 4709
# 4710
# 4711
# 4712
# 4713
# 4714
# 4715
# 4716
# 4717
# 4718
# 4719
# 4720
# 4721
# 4722
# 4723
# 4724
# 4725
# 4726
# 4727
# 4728
# 4729
# 4730
# 4731
# 4732
# 4733
# 4734
# 4735
# 4736
# 4737
# 4738
# 4739
# 4740
# 4741
# 4742
# 4743
# 4744
# 4745
# 4746
# 4747
# 4748
# 4749
# 4750
# 4751
# 4752
# 4753
# 4754
# 4755
# 4756
# 4757
# 4758
# 4759
# 4760
# 4761
# 4762
# 4763
# 4764
# 4765
# 4766
# 4767
# 4768
# 4769
# 4770
# 4771
# 4772
# 4773
# 4774
# 4775
# 4776
# 4777
# 4778
# 4779
# 4780
# 4781
# 4782
# 4783
# 4784
# 4785
# 4786
# 4787
# 4788
# 4789
# 4790
# 4791
# 4792
# 4793
# 4794
# 4795
# 4796
# 4797
# 4798
# 4799
# 4800
# 4801
# 4802
# 4803
# 4804
# 4805
# 4806
# 4807
# 4808
# 4809
# 4810
# 4811
# 4812
# 4813
# 4814
# 4815
# 4816
# 4817
# 4818
# 4819
# 4820
# 4821
# 4822
# 4823
# 4824
# 4825
# 4826
# 4827
# 4828
# 4829
# 4830
# 4831
# 4832
# 4833
# 4834
# 4835
# 4836
# 4837
# 4838
# 4839
# 4840
# 4841
# 4842
# 4843
# 4844
# 4845
# 4846
# 4847
# 4848
# 4849
# 4850
# 4851
# 4852
# 4853
# 4854
# 4855
# 4856
# 4857
# 4858
# 4859
# 4860
# 4861
# 4862
# 4863
# 4864
# 4865
# 4866
# 4867
# 4868
# 4869
# 4870
# 4871
# 4872
# 4873
# 4874
# 4875
# 4876
# 4877
# 4878
# 4879
# 4880
# 4881
# 4882
# 4883
# 4884
# 4885
# 4886
# 4887
# 4888
# 4889
# 4890
# 4891
# 4892
# 4893
# 4894
# 4895
# 4896
# 4897
# 4898
# 4899
# 4900
# 4901
# 4902
# 4903
# 4904
# 4905
# 4906
# 4907
# 4908
# 4909
# 4910
# 4911
# 4912
# 4913
# 4914
# 4915
# 4916
# 4917
# 4918
# 4919
# 4920
# 4921
# 4922
# 4923
# 4924
# 4925
# 4926
# 4927
# 4928
# 4929
# 4930
# 4931
# 4932
# 4933
# 4934
# 4935
# 4936
# 4937
# 4938
# 4939
# 4940
# 4941
# 4942
# 4943
# 4944
# 4945
# 4946
# 4947
# 4948
# 4949
# 4950
# 4951
# 4952
# 4953
# 4954
# 4955
# 4956
# 4957
# 4958
# 4959
# 4960
# 4961
# 4962
# 4963
# 4964
# 4965
# 4966
# 4967
# 4968
# 4969
# 4970
# 4971
# 4972
# 4973
# 4974
# 4975
# 4976
# 4977
# 4978
# 4979
# 4980
# 4981
# 4982
# 4983
# 4984
# 4985
# 4986
# 4987
# 4988
# 4989
# 4990
# 4991
# 4992
# 4993
# 4994
# 4995
# 4996
# 4997
# 4998
# 4999
# 5000
# 5001
# 5002
# 5003
# 5004
# 5005
# 5006
# 5007
# 5008
# 5009
# 5010
# 5011
# 5012
# 5013
# 5014
# 5015
# 5016
# 5017
# 5018
# 5019
# 5020
# 5021
# 5022
# 5023
# 5024
# 5025
# 5026
# 5027
# 5028
# 5029
# 5030
# 5031
# 5032
# 5033
# 5034
# 5035
# 5036
# 5037
# 5038
# 5039
# 5040
# 5041
# 5042
# 5043
# 5044
# 5045
# 5046
# 5047
# 5048
# 5049
# 5050
# 5051
# 5052
# 5053
# 5054
# 5055
# 5056
# 5057
# 5058
# 5059
# 5060
# 5061
# 5062
# 5063
# 5064
# 5065
# 5066
# 5067
# 5068
# 5069
# 5070
# 5071
# 5072
# 5073
# 5074
# 5075
# 5076
# 5077
# 5078
# 5079
# 5080
# 5081
# 5082
# 5083
# 5084
# 5085
# 5086
# 5087
# 5088
# 5089
# 5090
# 5091
# 5092
# 5093
# 5094
# 5095
# 5096
# 5097
# 5098
# 5099
# 5100
# 5101
# 5102
# 5103
# 5104
# 5105
# 5106
# 5107
# 5108
# 5109
# 5110
# 5111
# 5112
# 5113
# 5114
# 5115
# 5116
# 5117
# 5118
# 5119
# 5120
# 5121
# 5122
# 5123
# 5124
# 5125
# 5126
# 5127
# 5128
# 5129
# 5130
# 5131
# 5132
# 5133
# 5134
# 5135
# 5136
# 5137
# 5138
# 5139
# 5140
# 5141
# 5142
# 5143
# 5144
# 5145
# 5146
# 5147
# 5148
# 5149
# 5150
# 5151
# 5152
# 5153
# 5154
# 5155
# 5156
# 5157
# 5158
# 5159
# 5160
# 5161
# 5162
# 5163
# 5164
# 5165
# 5166
# 5167
# 5168
# 5169
# 5170
# 5171
# 5172
# 5173
# 5174
# 5175
# 5176
# 5177
# 5178
# 5179
# 5180
# 5181
# 5182
# 5183
# 5184
# 5185
# 5186
# 5187
# 5188
# 5189
# 5190
# 5191
# 5192
# 5193
# 5194
# 5195
# 5196
# 5197
# 5198
# 5199
# 5200
# 5201
# 5202
# 5203
# 5204
# 5205
# 5206
# 5207
# 5208
# 5209
# 5210
# 5211
# 5212
# 5213
# 5214
# 5215
# 5216
# 5217
# 5218
# 5219
# 5220
# 5221
# 5222
# 5223
# 5224
# 5225
# 5226
# 5227
# 5228
# 5229
# 5230
# 5231
# 5232
# 5233
# 5234
# 5235
# 5236
# 5237
# 5238
# 5239
# 5240
# 5241
# 5242
# 5243
# 5244
# 5245
# 5246
# 5247
# 5248
# 5249
# 5250
# 5251
# 5252
# 5253
# 5254
# 5255
# 5256
# 5257
# 5258
# 5259
# 5260
# 5261
# 5262
# 5263
# 5264
# 5265
# 5266
# 5267
# 5268
# 5269
# 5270
# 5271
# 5272
# 5273
# 5274
# 5275
# 5276
# 5277
# 5278
# 5279
# 5280
# 5281
# 5282
# 5283
# 5284
# 5285
# 5286
# 5287
# 5288
# 5289
# 5290
# 5291
# 5292
# 5293
# 5294
# 5295
# 5296
# 5297
# 5298
# 5299
# 5300
# 5301
# 5302
# 5303
# 5304
# 5305
# 5306
# 5307
# 5308
# 5309
# 5310
# 5311
# 5312
# 5313
# 5314
# 5315
# 5316
# 5317
# 5318
# 5319
# 5320
# 5321
# 5322
# 5323
# 5324
# 5325
# 5326
# 5327
# 5328
# 5329
# 5330
# 5331
# 5332
# 5333
# 5334
# 5335
# 5336
# 5337
# 5338
# 5339
# 5340
# 5341
# 5342
# 5343
# 5344
# 5345
# 5346
# 5347
# 5348
# 5349
# 5350
# 5351
# 5352
# 5353
# 5354
# 5355
# 5356
# 5357
# 5358
# 5359
# 5360
# 5361
# 5362
# 5363
# 5364
# 5365
# 5366
# 5367
# 5368
# 5369
# 5370
# 5371
# 5372
# 5373
# 5374
# 5375
# 5376
# 5377
# 5378
# 5379
# 5380
# 5381
# 5382
# 5383
# 5384
# 5385
# 5386
# 5387
# 5388
# 5389
# 5390
# 5391
# 5392
# 5393
# 5394
# 5395
# 5396
# 5397
# 5398
# 5399
# 5400
# 5401
# 5402
# 5403
# 5404
# 5405
# 5406
# 5407
# 5408
# 5409
# 5410
# 5411
# 5412
# 5413
# 5414
# 5415
# 5416
# 5417
# 5418
# 5419
# 5420
# 5421
# 5422
# 5423
# 5424
# 5425
# 5426
# 5427
# 5428
# 5429
# 5430
# 5431
# 5432
# 5433
# 5434
# 5435
# 5436
# 5437
# 5438
# 5439
# 5440
# 5441
# 5442
# 5443
# 5444
# 5445
# 5446
# 5447
# 5448
# 5449
# 5450
# 5451
# 5452
# 5453
# 5454
# 5455
# 5456
# 5457
# 5458
# 5459
# 5460
# 5461
# 5462
# 5463
# 5464
# 5465
# 5466
# 5467
# 5468
# 5469
# 5470
# 5471
# 5472
# 5473
# 5474
# 5475
# 5476
# 5477
# 5478
# 5479
# 5480
# 5481
# 5482
# 5483
# 5484
# 5485
# 5486
# 5487
# 5488
# 5489
# 5490
# 5491
# 5492
# 5493
# 5494
# 5495
# 5496
# 5497
# 5498
# 5499
# 5500
# 5501
# 5502
# 5503
# 5504
# 5505
# 5506
# 5507
# 5508
# 5509
# 5510
# 5511
# 5512
# 5513
# 5514
# 5515
# 5516
# 5517
# 5518
# 5519
# 5520
# 5521
# 5522
# 5523
# 5524
# 5525
# 5526
# 5527
# 5528
# 5529
# 5530
# 5531
# 5532
# 5533
# 5534
# 5535
# 5536
# 5537
# 5538
# 5539
# 5540
# 5541
# 5542
# 5543
# 5544
# 5545
# 5546
# 5547
# 5548
# 5549
# 5550
# 5551
# 5552
# 5553
# 5554
# 5555
# 5556
# 5557
# 5558
# 5559
# 5560
# 5561
# 5562
# 5563
# 5564
# 5565
# 5566
# 5567
# 5568
# 5569
# 5570
# 5571
# 5572
# 5573
# 5574
# 5575
# 5576
# 5577
# 5578
# 5579
# 5580
# 5581
# 5582
# 5583
# 5584
# 5585
# 5586
# 5587
# 5588
# 5589
# 5590
# 5591
# 5592
# 5593
# 5594
# 5595
# 5596
# 5597
# 5598
# 5599
# 5600
# 5601
# 5602
# 5603
# 5604
# 5605
# 5606
# 5607
# 5608
# 5609
# 5610
# 5611
# 5612
# 5613
# 5614
# 5615
# 5616
# 5617
# 5618
# 5619
# 5620
# 5621
# 5622
# 5623
# 5624
# 5625
# 5626
# 5627
# 5628
# 5629
# 5630
# 5631
# 5632
# 5633
# 5634
# 5635
# 5636
# 5637
# 5638
# 5639
# 5640
# 5641
# 5642
# 5643
# 5644
# 5645
# 5646
# 5647
# 5648
# 5649
# 5650
# 5651
# 5652
# 5653
# 5654
# 5655
# 5656
# 5657
# 5658
# 5659
# 5660
# 5661
# 5662
# 5663
# 5664
# 5665
# 5666
# 5667
# 5668
# 5669
# 5670
# 5671
# 5672
# 5673
# 5674
# 5675
# 5676
# 5677
# 5678
# 5679
# 5680
# 5681
# 5682
# 5683
# 5684
# 5685
# 5686
# 5687
# 5688
# 5689
# 5690
# 5691
# 5692
# 5693
# 5694
# 5695
# 5696
# 5697
# 5698
# 5699
# 5700
# 5701
# 5702
# 5703
# 5704
# 5705
# 5706
# 5707
# 5708
# 5709
# 5710
# 5711
# 5712
# 5713
# 5714
# 5715
# 5716
# 5717
# 5718
# 5719
# 5720
# 5721
# 5722
# 5723
# 5724
# 5725
# 5726
# 5727
# 5728
# 5729
# 5730
# 5731
# 5732
# 5733
# 5734
# 5735
# 5736
# 5737
# 5738
# 5739
# 5740
# 5741
# 5742
# 5743
# 5744
# 5745
# 5746
# 5747
# 5748
# 5749
# 5750
# 5751
# 5752
# 5753
# 5754
# 5755
# 5756
# 5757
# 5758
# 5759
# 5760
# 5761
# 5762
# 5763
# 5764
# 5765
# 5766
# 5767
# 5768
# 5769
# 5770
# 5771
# 5772
# 5773
# 5774
# 5775
# 5776
# 5777
# 5778
# 5779
# 5780
# 5781
# 5782
# 5783
# 5784
# 5785
# 5786
# 5787
# 5788
# 5789
# 5790
# 5791
# 5792
# 5793
# 5794
# 5795
# 5796
# 5797
# 5798
# 5799
# 5800
# 5801
# 5802
# 5803
# 5804
# 5805
# 5806
# 5807
# 5808
# 5809
# 5810
# 5811
# 5812
# 5813
# 5814
# 5815
# 5816
# 5817
# 5818
# 5819
# 5820
# 5821
# 5822
# 5823
# 5824
# 5825
# 5826
# 5827
# 5828
# 5829
# 5830
# 5831
# 5832
# 5833
# 5834
# 5835
# 5836
# 5837
# 5838
# 5839
# 5840
# 5841
# 5842
# 5843
# 5844
# 5845
# 5846
# 5847
# 5848
# 5849
# 5850
# 5851
# 5852
# 5853
# 5854
# 5855
# 5856
# 5857
# 5858
# 5859
# 5860
# 5861
# 5862
# 5863
# 5864
# 5865
# 5866
# 5867
# 5868
# 5869
# 5870
# 5871
# 5872
# 5873
# 5874
# 5875
# 5876
# 5877
# 5878
# 5879
# 5880
# 5881
# 5882
# 5883
# 5884
# 5885
# 5886
# 5887
# 5888
# 5889
# 5890
# 5891
# 5892
# 5893
# 5894
# 5895
# 5896
# 5897
# 5898
# 5899
# 5900
# 5901
# 5902
# 5903
# 5904
# 5905
# 5906
# 5907
# 5908
# 5909
# 5910
# 5911
# 5912
# 5913
# 5914
# 5915
# 5916
# 5917
# 5918
# 5919
# 5920
# 5921
# 5922
# 5923
# 5924
# 5925
# 5926
# 5927
# 5928
# 5929
# 5930
# 5931
# 5932
# 5933
# 5934
# 5935
# 5936
# 5937
# 5938
# 5939
# 5940
# 5941
# 5942
# 5943
# 5944
# 5945
# 5946
# 5947
# 5948
# 5949
# 5950
# 5951
# 5952
# 5953
# 5954
# 5955
# 5956
# 5957
# 5958
# 5959
# 5960
# 5961
# 5962
# 5963
# 5964
# 5965
# 5966
# 5967
# 5968
# 5969
# 5970
# 5971
# 5972
# 5973
# 5974
# 5975
# 5976
# 5977
# 5978
# 5979
# 5980
# 5981
# 5982
# 5983
# 5984
# 5985
# 5986
# 5987
# 5988
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994
# 5995
# 5996
# 5997
# 5998
# 5999
# 6000
# 6001
# 6002
# 6003
# 6004
# 6005
# 6006
# 6007
# 6008
# 6009
# 6010
# 6011
# 6012
# 6013
# 6014
# 6015
# 6016
# 6017
# 6018
# 6019
# 6020
# 6021
# 6022
# 6023
# 6024
# 6025
# 6026
# 6027
# 6028
# 6029
# 6030
# 6031
# 6032
# 6033
# 6034
# 6035
# 6036
# 6037
# 6038
# 6039
# 6040
# 6041
# 6042
# 6043
# 6044
# 6045
# 6046
# 6047
# 6048
# 6049
# 6050
# 6051
# 6052
# 6053
# 6054
# 6055
# 6056
# 6057
# 6058
# 6059
# 6060
# 6061
# 6062
# 6063
# 6064
# 6065
# 6066
# 6067
# 6068
# 6069
# 6070
# 6071
# 6072
# 6073
# 6074
# 6075
# 6076
# 6077
# 6078
# 6079
# 6080
# 6081
# 6082
# 6083
# 6084
# 6085
# 6086
# 6087
# 6088
# 6089
# 6090
# 6091
# 6092
# 6093
# 6094
# 6095
# 6096
# 6097
# 6098
# 6099
# 6100
# 6101
# 6102
# 6103
# 6104
# 6105
# 6106
# 6107
# 6108
# 6109
# 6110
# 6111
# 6112
# 6113
# 6114
# 6115
# 6116
# 6117
# 6118
# 6119
# 6120
# 6121
# 6122
# 6123
# 6124
# 6125
# 6126
# 6127
# 6128
# 6129
# 6130
# 6131
# 6132
# 6133
# 6134
# 6135
# 6136
# 6137
# 6138
# 6139
# 6140
# 6141
# 6142
# 6143
# 6144
# 6145
# 6146
# 6147
# 6148
# 6149
# 6150
# 6151
# 6152
# 6153
# 6154
# 6155
# 6156
# 6157
# 6158
# 6159
# 6160
# 6161
# 6162
# 6163
# 6164
# 6165
# 6166
# 6167
# 6168
# 6169
# 6170
# 6171
# 6172
# 6173
# 6174
# 6175
# 6176
# 6177
# 6178
# 6179
# 6180
# 6181
# 6182
# 6183
# 6184
# 6185
# 6186
# 6187
# 6188
# 6189
# 6190
# 6191
# 6192
# 6193
# 6194
# 6195
# 6196
# 6197
# 6198
# 6199
# 6200
# 6201
# 6202
# 6203
# 6204
# 6205
# 6206
# 6207
# 6208
# 6209
# 6210
# 6211
# 6212
# 6213
# 6214
# 6215
# 6216
# 6217
# 6218
# 6219
# 6220
# 6221
# 6222
# 6223
# 6224
# 6225
# 6226
# 6227
# 6228
# 6229
# 6230
# 6231
# 6232
# 6233
# 6234
# 6235
# 6236
# 6237
# 6238
# 6239
# 6240
# 6241
# 6242
# 6243
# 6244
# 6245
# 6246
# 6247
# 6248
# 6249
# 6250
# 6251
# 6252
# 6253
# 6254
# 6255
# 6256
# 6257
# 6258
# 6259
# 6260
# 6261
# 6262
# 6263
# 6264
# 6265
# 6266
# 6267
# 6268
# 6269
# 6270
# 6271
# 6272
# 6273
# 6274
# 6275
# 6276
# 6277
# 6278
# 6279
# 6280
# 6281
# 6282
# 6283
# 6284
# 6285
# 6286
# 6287
# 6288
# 6289
# 6290
# 6291
# 6292
# 6293
# 6294
# 6295
# 6296
# 6297
# 6298
# 6299
# 6300
# 6301
# 6302
# 6303
# 6304
# 6305
# 6306
# 6307
# 6308
# 6309
# 6310
# 6311
# 6312
# 6313
# 6314
# 6315
# 6316
# 6317
# 6318
# 6319
# 6320
# 6321
# 6322
# 6323
# 6324
# 6325
# 6326
# 6327
# 6328
# 6329
# 6330
# 6331
# 6332
# 6333
# 6334
# 6335
# 6336
# 6337
# 6338
# 6339
# 6340
# 6341
# 6342
# 6343
# 6344
# 6345
# 6346
# 6347
# 6348
# 6349
# 6350
# 6351
# 6352
# 6353
# 6354
# 6355
# 6356
# 6357
# 6358
# 6359
# 6360
# 6361
# 6362
# 6363
# 6364
# 6365
# 6366
# 6367
# 6368
# 6369
# 6370
# 6371
# 6372
# 6373
# 6374
# 6375
# 6376
# 6377
# 6378
# 6379
# 6380
# 6381
# 6382
# 6383
# 6384
# 6385
# 6386
# 6387
# 6388
# 6389
# 6390
# 6391
# 6392
# 6393
# 6394
# 6395
# 6396
# 6397
# 6398
# 6399
# 6400
# 6401
# 6402
# 6403
# 6404
# 6405
# 6406
# 6407
# 6408
# 6409
# 6410
# 6411
# 6412
# 6413
# 6414
# 6415
# 6416
# 6417
# 6418
# 6419
# 6420
# 6421
# 6422
# 6423
# 6424
# 6425
# 6426
# 6427
# 6428
# 6429
# 6430
# 6431
# 6432
# 6433
# 6434
# 6435
# 6436
# 6437
# 6438
# 6439
# 6440
# 6441
# 6442
# 6443
# 6444
# 6445
# 6446
# 6447
# 6448
# 6449
# 6450
# 6451
# 6452
# 6453
# 6454
# 6455
# 6456
# 6457
# 6458
# 6459
# 6460
# 6461
# 6462
# 6463
# 6464
# 6465
# 6466
# 6467
# 6468
# 6469
# 6470
# 6471
# 6472
# 6473
# 6474
# 6475
# 6476
# 6477
# 6478
# 6479
# 6480
# 6481
# 6482
# 6483
# 6484
# 6485
# 6486
# 6487
# 6488
# 6489
# 6490
# 6491
# 6492
# 6493
# 6494
# 6495
# 6496
# 6497
# 6498
# 6499
# 6500
# 6501
# 6502
# 6503
# 6504
# 6505
# 6506
# 6507
# 6508
# 6509
# 6510
# 6511
# 6512
# 6513
# 6514
# 6515
# 6516
# 6517
# 6518
# 6519
# 6520
# 6521
# 6522
# 6523
# 6524
# 6525
# 6526
# 6527
# 6528
# 6529
# 6530
# 6531
# 6532
# 6533
# 6534
# 6535
# 6536
# 6537
# 6538
# 6539
# 6540
# 6541
# 6542
# 6543
# 6544
# 6545
# 6546
# 6547
# 6548
# 6549
# 6550
# 6551
# 6552
# 6553
# 6554
# 6555
# 6556
# 6557
# 6558
# 6559
# 6560
# 6561
# 6562
# 6563
# 6564
# 6565
# 6566
# 6567
# 6568
# 6569
# 6570
# 6571
# 6572
# 6573
# 6574
# 6575
# 6576
# 6577
# 6578
# 6579
# 6580
# 6581
# 6582
# 6583
# 6584
# 6585
# 6586
# 6587
# 6588
# 6589
# 6590
# 6591
# 6592
# 6593
# 6594
# 6595
# 6596
# 6597
# 6598
# 6599
# 6600
# 6601
# 6602
# 6603
# 6604
# 6605
# 6606
# 6607
# 6608
# 6609
# 6610
# 6611
# 6612
# 6613
# 6614
# 6615
# 6616
# 6617
# 6618
# 6619
# 6620
# 6621
# 6622
# 6623
# 6624
# 6625
# 6626
# 6627
# 6628
# 6629
# 6630
# 6631
# 6632
# 6633
# 6634
# 6635
# 6636
# 6637
# 6638
# 6639
# 6640
# 6641
# 6642
# 6643
# 6644
# 6645
# 6646
# 6647
# 6648
# 6649
# 6650
# 6651
# 6652
# 6653
# 6654
# 6655
# 6656
# 6657
# 6658
# 6659
# 6660
# 6661
# 6662
# 6663
# 6664
# 6665
# 6666
# 6667
# 6668
# 6669
# 6670
# 6671
# 6672
# 6673
# 6674
# 6675
# 6676
# 6677
# 6678
# 6679
# 6680
# 6681
# 6682
# 6683
# 6684
# 6685
# 6686
# 6687
# 6688
# 6689
# 6690
# 6691
# 6692
# 6693
# 6694
# 6695
# 6696
# 6697
# 6698
# 6699
# 6700
# 6701
# 6702
# 6703
# 6704
# 6705
# 6706
# 6707
# 6708
# 6709
# 6710
# 6711
# 6712
# 6713
# 6714
# 6715
# 6716
# 6717
# 6718
# 6719
# 6720
# 6721
# 6722
# 6723
# 6724
# 6725
# 6726
# 6727
# 6728
# 6729
# 6730
# 6731
# 6732
# 6733
# 6734
# 6735
# 6736
# 6737
# 6738
# 6739
# 6740
# 6741
# 6742
# 6743
# 6744
# 6745
# 6746
# 6747
# 6748
# 6749
# 6750
# 6751
# 6752
# 6753
# 6754
# 6755
# 6756
# 6757
# 6758
# 6759
# 6760
# 6761
# 6762
# 6763
# 6764
# 6765
# 6766
# 6767
# 6768
# 6769
# 6770
# 6771
# 6772
# 6773
# 6774
# 6775
# 6776
# 6777
# 6778
# 6779
# 6780
# 6781
# 6782
# 6783
# 6784
# 6785
# 6786
# 6787
# 6788
# 6789
# 6790
# 6791
# 6792
# 6793
# 6794
# 6795
# 6796
# 6797
# 6798
# 6799
# 6800
# 6801
# 6802
# 6803
# 6804
# 6805
# 6806
# 6807
# 6808
# 6809
# 6810
# 6811
# 6812
# 6813
# 6814
# 6815
# 6816
# 6817
# 6818
# 6819
# 6820
# 6821
# 6822
# 6823
# 6824
# 6825
# 6826
# 6827
# 6828
# 6829
# 6830
# 6831
# 6832
# 6833
# 6834
# 6835
# 6836
# 6837
# 6838
# 6839
# 6840
# 6841
# 6842
# 6843
# 6844
# 6845
# 6846
# 6847
# 6848
# 6849
# 6850
# 6851
# 6852
# 6853
# 6854
# 6855
# 6856
# 6857
# 6858
# 6859
# 6860
# 6861
# 6862
# 6863
# 6864
# 6865
# 6866
# 6867
# 6868
# 6869
# 6870
# 6871
# 6872
# 6873
# 6874
# 6875
# 6876
# 6877
# 6878
# 6879
# 6880
# 6881
# 6882
# 6883
# 6884
# 6885
# 6886
# 6887
# 6888
# 6889
# 6890
# 6891
# 6892
# 6893
# 6894
# 6895
# 6896
# 6897
# 6898
# 6899
# 6900
# 6901
# 6902
# 6903
# 6904
# 6905
# 6906
# 6907
# 6908
# 6909
# 6910
# 6911
# 6912
# 6913
# 6914
# 6915
# 6916
# 6917
# 6918
# 6919
# 6920
# 6921
# 6922
# 6923
# 6924
# 6925
# 6926
# 6927
# 6928
# 6929
# 6930
# 6931
# 6932
# 6933
# 6934
# 6935
# 6936
# 6937
# 6938
# 6939
# 6940
# 6941
# 6942
# 6943
# 6944
# 6945
# 6946
# 6947
# 6948
# 6949
# 6950
# 6951
# 6952
# 6953
# 6954
# 6955
# 6956
# 6957
# 6958
# 6959
# 6960
# 6961
# 6962
# 6963
# 6964
# 6965
# 6966
# 6967
# 6968
# 6969
# 6970
# 6971
# 6972
# 6973
# 6974
# 6975
# 6976
# 6977
# 6978
# 6979
# 6980
# 6981
# 6982
# 6983
# 6984
# 6985
# 6986
# 6987
# 6988
# 6989
# 6990
# 6991
# 6992
# 6993
# 6994
# 6995
# 6996
# 6997
# 6998
# 6999
# 7000
# 7001
# 7002
# 7003
# 7004
# 7005
# 7006
# 7007
# 7008
# 7009
# 7010
# 7011
# 7012
# 7013
# 7014
# 7015
# 7016
# 7017
# 7018
# 7019
# 7020
# 7021
# 7022
# 7023
# 7024
# 7025
# 7026
# 7027
# 7028
# 7029
# 7030
# 7031
# 7032
# 7033
# 7034
# 7035
# 7036
# 7037
# 7038
# 7039
# 7040
# 7041
# 7042
# 7043
# 7044
# 7045
# 7046
# 7047
# 7048
# 7049
# 7050
# 7051
# 7052
# 7053
# 7054
# 7055
# 7056
# 7057
# 7058
# 7059
# 7060
# 7061
# 7062
# 7063
# 7064
# 7065
# 7066
# 7067
# 7068
# 7069
# 7070
# 7071
# 7072
# 7073
# 7074
# 7075
# 7076
# 7077
# 7078
# 7079
# 7080
# 7081
# 7082
# 7083
# 7084
# 7085
# 7086
# 7087
# 7088
# 7089
# 7090
# 7091
# 7092
# 7093
# 7094
# 7095
# 7096
# 7097
# 7098
# 7099
# 7100
# 7101
# 7102
# 7103
# 7104
# 7105
# 7106
# 7107
# 7108
# 7109
# 7110
# 7111
# 7112
# 7113
# 7114
# 7115
# 7116
# 7117
# 7118
# 7119
# 7120
# 7121
# 7122
# 7123
# 7124
# 7125
# 7126
# 7127
# 7128
# 7129
# 7130
# 7131
# 7132
# 7133
# 7134
# 7135
# 7136
# 7137
# 7138
# 7139
# 7140
# 7141
# 7142
# 7143
# 7144
# 7145
# 7146
# 7147
# 7148
# 7149
# 7150
# 7151
# 7152
# 7153
# 7154
# 7155
# 7156
# 7157
# 7158
# 7159
# 7160
# 7161
# 7162
# 7163
# 7164
# 7165
# 7166
# 7167
# 7168
# 7169
# 7170
# 7171
# 7172
# 7173
# 7174
# 7175
# 7176
# 7177
# 7178
# 7179
# 7180
# 7181
# 7182
# 7183
# 7184
# 7185
# 7186
# 7187
# 7188
# 7189
# 7190
# 7191
# 7192
# 7193
# 7194
# 7195
# 7196
# 7197
# 7198
# 7199
# 7200
# 7201
# 7202
# 7203
# 7204
# 7205
# 7206
# 7207
# 7208
# 7209
# 7210
# 7211
# 7212
# 7213
# 7214
# 7215
# 7216
# 7217
# 7218
# 7219
# 7220
# 7221
# 7222
# 7223
# 7224
# 7225
# 7226
# 7227
# 7228
# 7229
# 7230
# 7231
# 7232
# 7233
# 7234
# 7235
# 7236
# 7237
# 7238
# 7239
# 7240
# 7241
# 7242
# 7243
# 7244
# 7245
# 7246
# 7247
# 7248
# 7249
# 7250
# 7251
# 7252
# 7253
# 7254
# 7255
# 7256
# 7257
# 7258
# 7259
# 7260
# 7261
# 7262
# 7263
# 7264
# 7265
# 7266
# 7267
# 7268
# 7269
# 7270
# 7271
# 7272
# 7273
# 7274
# 7275
# 7276
# 7277
# 7278
# 7279
# 7280
# 7281
# 7282
# 7283
# 7284
# 7285
# 7286
# 7287
# 7288
# 7289
# 7290
# 7291
# 7292
# 7293
# 7294
# 7295
# 7296
# 7297
# 7298
# 7299
# 7300
# 7301
# 7302
# 7303
# 7304
# 7305
# 7306
# 7307
# 7308
# 7309
# 7310
# 7311
# 7312
# 7313
# 7314
# 7315
# 7316
# 7317
# 7318
# 7319
# 7320
# 7321
# 7322
# 7323
# 7324
# 7325
# 7326
# 7327
# 7328
# 7329
# 7330
# 7331
# 7332
# 7333
# 7334
# 7335
# 7336
# 7337
# 7338
# 7339
# 7340
# 7341
# 7342
# 7343
# 7344
# 7345
# 7346
# 7347
# 7348
# 7349
# 7350
# 7351
# 7352
# 7353
# 7354
# 7355
# 7356
# 7357
# 7358
# 7359
# 7360
# 7361
# 7362
# 7363
# 7364
# 7365
# 7366
# 7367
# 7368
# 7369
# 7370
# 7371
# 7372
# 7373
# 7374
# 7375
# 7376
# 7377
# 7378
# 7379
# 7380
# 7381
# 7382
# 7383
# 7384
# 7385
# 7386
# 7387
# 7388
# 7389
# 7390
# 7391
# 7392
# 7393
# 7394
# 7395
# 7396
# 7397
# 7398
# 7399
# 7400
# 7401
# 7402
# 7403
# 7404
# 7405
# 7406
# 7407
# 7408
# 7409
# 7410
# 7411
# 7412
# 7413
# 7414
# 7415
# 7416
# 7417
# 7418
# 7419
# 7420
# 7421
# 7422
# 7423
# 7424
# 7425
# 7426
# 7427
# 7428
# 7429
# 7430
# 7431
# 7432
# 7433
# 7434
# 7435
# 7436
# 7437
# 7438
# 7439
# 7440
# 7441
# 7442
# 7443
# 7444
# 7445
# 7446
# 7447
# 7448
# 7449
# 7450
# 7451
# 7452
# 7453
# 7454
# 7455
# 7456
# 7457
# 7458
# 7459
# 7460
# 7461
# 7462
# 7463
# 7464
# 7465
# 7466
# 7467
# 7468
# 7469
# 7470
# 7471
# 7472
# 7473
# 7474
# 7475
# 7476
# 7477
# 7478
# 7479
# 7480
# 7481
# 7482
# 7483
# 7484
# 7485
# 7486
# 7487
# 7488
# 7489
# 7490
# 7491
# 7492
# 7493
# 7494
# 7495
# 7496
# 7497
# 7498
# 7499
# 7500
# 7501
# 7502
# 7503
# 7504
# 7505
# 7506
# 7507
# 7508
# 7509
# 7510
# 7511
# 7512
# 7513
# 7514
# 7515
# 7516
# 7517
# 7518
# 7519
# 7520
# 7521
# 7522
# 7523
# 7524
# 7525
# 7526
# 7527
# 7528
# 7529
# 7530
# 7531
# 7532
# 7533
# 7534
# 7535
# 7536
# 7537
# 7538
# 7539
# 7540
# 7541
# 7542
# 7543
# 7544
# 7545
# 7546
# 7547
# 7548
# 7549
# 7550
# 7551
# 7552
# 7553
# 7554
# 7555
# 7556
# 7557
# 7558
# 7559
# 7560
# 7561
# 7562
# 7563
# 7564
# 7565
# 7566
# 7567
# 7568
# 7569
# 7570
# 7571
# 7572
# 7573
# 7574
# 7575
# 7576
# 7577
# 7578
# 7579
# 7580
# 7581
# 7582
# 7583
# 7584
# 7585
# 7586
# 7587
# 7588
# 7589
# 7590
# 7591
# 7592
# 7593
# 7594
# 7595
# 7596
# 7597
# 7598
# 7599
# 7600
# 7601
# 7602
# 7603
# 7604
# 7605
# 7606
# 7607
# 7608
# 7609
# 7610
# 7611
# 7612
# 7613
# 7614
# 7615
# 7616
# 7617
# 7618
# 7619
# 7620
# 7621
# 7622
# 7623
# 7624
# 7625
# 7626
# 7627
# 7628
# 7629
# 7630
# 7631
# 7632
# 7633
# 7634
# 7635
# 7636
# 7637
# 7638
# 7639
# 7640
# 7641
# 7642
# 7643
# 7644
# 7645
# 7646
# 7647
# 7648
# 7649
# 7650
# 7651
# 7652
# 7653
# 7654
# 7655
# 7656
# 7657
# 7658
# 7659
# 7660
# 7661
# 7662
# 7663
# 7664
# 7665
# 7666
# 7667
# 7668
# 7669
# 7670
# 7671
# 7672
# 7673
# 7674
# 7675
# 7676
# 7677
# 7678
# 7679
# 7680
# 7681
# 7682
# 7683
# 7684
# 7685
# 7686
# 7687
# 7688
# 7689
# 7690
# 7691
# 7692
# 7693
# 7694
# 7695
# 7696
# 7697
# 7698
# 7699
# 7700
# 7701
# 7702
# 7703
# 7704
# 7705
# 7706
# 7707
# 7708
# 7709
# 7710
# 7711
# 7712
# 7713
# 7714
# 7715
# 7716
# 7717
# 7718
# 7719
# 7720
# 7721
# 7722
# 7723
# 7724
# 7725
# 7726
# 7727
# 7728
# 7729
# 7730
# 7731
# 7732
# 7733
# 7734
# 7735
# 7736
# 7737
# 7738
# 7739
# 7740
# 7741
# 7742
# 7743
# 7744
# 7745
# 7746
# 7747
# 7748
# 7749
# 7750
# 7751
# 7752
# 7753
# 7754
# 7755
# 7756
# 7757
# 7758
# 7759
# 7760
# 7761
# 7762
# 7763
# 7764
# 7765
# 7766
# 7767
# 7768
# 7769
# 7770
# 7771
# 7772
# 7773
# 7774
# 7775
# 7776
# 7777
# 7778
# 7779
# 7780
# 7781
# 7782
# 7783
# 7784
# 7785
# 7786
# 7787
# 7788
# 7789
# 7790
# 7791
# 7792
# 7793
# 7794
# 7795
# 7796
# 7797
# 7798
# 7799
# 7800
# 7801
# 7802
# 7803
# 7804
# 7805
# 7806
# 7807
# 7808
# 7809
# 7810
# 7811
# 7812
# 7813
# 7814
# 7815
# 7816
# 7817
# 7818
# 7819
# 7820
# 7821
# 7822
# 7823
# 7824
# 7825
# 7826
# 7827
# 7828
# 7829
# 7830
# 7831
# 7832
# 7833
# 7834
# 7835
# 7836
# 7837
# 7838
# 7839
# 7840
# 7841
# 7842
# 7843
# 7844
# 7845
# 7846
# 7847
# 7848
# 7849
# 7850
# 7851
# 7852
# 7853
# 7854
# 7855
# 7856
# 7857
# 7858
# 7859
# 7860
# 7861
# 7862
# 7863
# 7864
# 7865
# 7866
# 7867
# 7868
# 7869
# 7870
# 7871
# 7872
# 7873
# 7874
# 7875
# 7876
# 7877
# 7878
# 7879
# 7880
# 7881
# 7882
# 7883
# 7884
# 7885
# 7886
# 7887
# 7888
# 7889
# 7890
# 7891
# 7892
# 7893
# 7894
# 7895
# 7896
# 7897
# 7898
# 7899
# 7900
# 7901
# 7902
# 7903
# 7904
# 7905
# 7906
# 7907
# 7908
# 7909
# 7910
# 7911
# 7912
# 7913
# 7914
# 7915
# 7916
# 7917
# 7918
# 7919
# 7920
# 7921
# 7922
# 7923
# 7924
# 7925
# 7926
# 7927
# 7928
# 7929
# 7930
# 7931
# 7932
# 7933
# 7934
# 7935
# 7936
# 7937
# 7938
# 7939
# 7940
# 7941
# 7942
# 7943
# 7944
# 7945
# 7946
# 7947
# 7948
# 7949
# 7950
# 7951
# 7952
# 7953
# 7954
# 7955
# 7956
# 7957
# 7958
# 7959
# 7960
# 7961
# 7962
# 7963
# 7964
# 7965
# 7966
# 7967
# 7968
# 7969
# 7970
# 7971
# 7972
# 7973
# 7974
# 7975
# 7976
# 7977
# 7978
# 7979
# 7980
# 7981
# 7982
# 7983
# 7984
# 7985
# 7986
# 7987
# 7988
# 7989
# 7990
# 7991
# 7992
# 7993
# 7994
# 7995
# 7996
# 7997
# 7998
# 7999
# 8000
# 8001
# 8002
# 8003
# 8004
# 8005
# 8006
# 8007
# 8008
# 8009
# 8010
# 8011
# 8012
# 8013
# 8014
# 8015
# 8016
# 8017
# 8018
# 8019
# 8020
# 8021
# 8022
# 8023
# 8024
# 8025
# 8026
# 8027
# 8028
# 8029
# 8030
# 8031
# 8032
# 8033
# 8034
# 8035
# 8036
# 8037
# 8038
# 8039
# 8040
# 8041
# 8042
# 8043
# 8044
# 8045
# 8046
# 8047
# 8048
# 8049
# 8050
# 8051
# 8052
# 8053
# 8054
# 8055
# 8056
# 8057
# 8058
# 8059
# 8060
# 8061
# 8062
# 8063
# 8064
# 8065
# 8066
# 8067
# 8068
# 8069
# 8070
# 8071
# 8072
# 8073
# 8074
# 8075
# 8076
# 8077
# 8078
# 8079
# 8080
# 8081
# 8082
# 8083
# 8084
# 8085
# 8086
# 8087
# 8088
# 8089
# 8090
# 8091
# 8092
# 8093
# 8094
# 8095
# 8096
# 8097
# 8098
# 8099
# 8100
# 8101
# 8102
# 8103
# 8104
# 8105
# 8106
# 8107
# 8108
# 8109
# 8110
# 8111
# 8112
# 8113
# 8114
# 8115
# 8116
# 8117
# 8118
# 8119
# 8120
# 8121
# 8122
# 8123
# 8124
# 8125
# 8126
# 8127
# 8128
# 8129
# 8130
# 8131
# 8132
# 8133
# 8134
# 8135
# 8136
# 8137
# 8138
# 8139
# 8140
# 8141
# 8142
# 8143
# 8144
# 8145
# 8146
# 8147
# 8148
# 8149
# 8150
# 8151
# 8152
# 8153
# 8154
# 8155
# 8156
# 8157
# 8158
# 8159
# 8160
# 8161
# 8162
# 8163
# 8164
# 8165
# 8166
# 8167
# 8168
# 8169
# 8170
# 8171
# 8172
# 8173
# 8174
# 8175
# 8176
# 8177
# 8178
# 8179
# 8180
# 8181
# 8182
# 8183
# 8184
# 8185
# 8186
# 8187
# 8188
# 8189
# 8190
# 8191
# 8192
# 8193
# 8194
# 8195
# 8196
# 8197
# 8198
# 8199
# 8200
# 8201
# 8202
# 8203
# 8204
# 8205
# 8206
# 8207
# 8208
# 8209
# 8210
# 8211
# 8212
# 8213
# 8214
# 8215
# 8216
# 8217
# 8218
# 8219
# 8220
# 8221
# 8222
# 8223
# 8224
# 8225
# 8226
# 8227
# 8228
# 8229
# 8230
# 8231
# 8232
# 8233
# 8234
# 8235
# 8236
# 8237
# 8238
# 8239
# 8240
# 8241
# 8242
# 8243
# 8244
# 8245
# 8246
# 8247
# 8248
# 8249
# 8250
# 8251
# 8252
# 8253
# 8254
# 8255
# 8256
# 8257
# 8258
# 8259
# 8260
# 8261
# 8262
# 8263
# 8264
# 8265
# 8266
# 8267
# 8268
# 8269
# 8270
# 8271
# 8272
# 8273
# 8274
# 8275
# 8276
# 8277
# 8278
# 8279
# 8280
# 8281
# 8282
# 8283
# 8284
# 8285
# 8286
# 8287
# 8288
# 8289
# 8290
# 8291
# 8292
# 8293
# 8294
# 8295
# 8296
# 8297
# 8298
# 8299
# 8300
# 8301
# 8302
# 8303
# 8304
# 8305
# 8306
# 8307
# 8308
# 8309
# 8310
# 8311
# 8312
# 8313
# 8314
# 8315
# 8316
# 8317
# 8318
# 8319
# 8320
# 8321
# 8322
# 8323
# 8324
# 8325
# 8326
# 8327
# 8328
# 8329
# 8330
# 8331
# 8332
# 8333
# 8334
# 8335
# 8336
# 8337
# 8338
# 8339
# 8340
# 8341
# 8342
# 8343
# 8344
# 8345
# 8346
# 8347
# 8348
# 8349
# 8350
# 8351
# 8352
# 8353
# 8354
# 8355
# 8356
# 8357
# 8358
# 8359
# 8360
# 8361
# 8362
# 8363
# 8364
# 8365
# 8366
# 8367
# 8368
# 8369
# 8370
# 8371
# 8372
# 8373
# 8374
# 8375
# 8376
# 8377
# 8378
# 8379
# 8380
# 8381
# 8382
# 8383
# 8384
# 8385
# 8386
# 8387
# 8388
# 8389
# 8390
# 8391
# 8392
# 8393
# 8394
# 8395
# 8396
# 8397
# 8398
# 8399
# 8400
# 8401
# 8402
# 8403
# 8404
# 8405
# 8406
# 8407
# 8408
# 8409
# 8410
# 8411
# 8412
# 8413
# 8414
# 8415
# 8416
# 8417
# 8418
# 8419
# 8420
# 8421
# 8422
# 8423
# 8424
# 8425
# 8426
# 8427
# 8428
# 8429
# 8430
# 8431
# 8432
# 8433
# 8434
# 8435
# 8436
# 8437
# 8438
# 8439
# 8440
# 8441
# 8442
# 8443
# 8444
# 8445
# 8446
# 8447
# 8448
# 8449
# 8450
# 8451
# 8452
# 8453
# 8454
# 8455
# 8456
# 8457
# 8458
# 8459
# 8460
# 8461
# 8462
# 8463
# 8464
# 8465
# 8466
# 8467
# 8468
# 8469
# 8470
# 8471
# 8472
# 8473
# 8474
# 8475
# 8476
# 8477
# 8478
# 8479
# 8480
# 8481
# 8482
# 8483
# 8484
# 8485
# 8486
# 8487
# 8488
# 8489
# 8490
# 8491
# 8492
# 8493
# 8494
# 8495
# 8496
# 8497
# 8498
# 8499
# 8500
# 8501
# 8502
# 8503
# 8504
# 8505
# 8506
# 8507
# 8508
# 8509
# 8510
# 8511
# 8512
# 8513
# 8514
# 8515
# 8516
# 8517
# 8518
# 8519
# 8520
# 8521
# 8522
# 8523
# 8524
# 8525
# 8526
# 8527
# 8528
# 8529
# 8530
# 8531
# 8532
# 8533
# 8534
# 8535
# 8536
# 8537
# 8538
# 8539
# 8540
# 8541
# 8542
# 8543
# 8544
# 8545
# 8546
# 8547
# 8548
# 8549
# 8550
# 8551
# 8552
# 8553
# 8554
# 8555
# 8556
# 8557
# 8558
# 8559
# 8560
# 8561
# 8562
# 8563
# 8564
# 8565
# 8566
# 8567
# 8568
# 8569
# 8570
# 8571
# 8572
# 8573
# 8574
# 8575
# 8576
# 8577
# 8578
# 8579
# 8580
# 8581
# 8582
# 8583
# 8584
# 8585
# 8586
# 8587
# 8588
# 8589
# 8590
# 8591
# 8592
# 8593
# 8594
# 8595
# 8596
# 8597
# 8598
# 8599
# 8600
# 8601
# 8602
# 8603
# 8604
# 8605
# 8606
# 8607
# 8608
# 8609
# 8610
# 8611
# 8612
# 8613
# 8614
# 8615
# 8616
# 8617
# 8618
# 8619
# 8620
# 8621
# 8622
# 8623
# 8624
# 8625
# 8626
# 8627
# 8628
# 8629
# 8630
# 8631
# 8632
# 8633
# 8634
# 8635
# 8636
# 8637
# 8638
# 8639
# 8640
# 8641
# 8642
# 8643
# 8644
# 8645
# 8646
# 8647
# 8648
# 8649
# 8650
# 8651
# 8652
# 8653
# 8654
# 8655
# 8656
# 8657
# 8658
# 8659
# 8660
# 8661
# 8662
# 8663
# 8664
# 8665
# 8666
# 8667
# 8668
# 8669
# 8670
# 8671
# 8672
# 8673
# 8674
# 8675
# 8676
# 8677
# 8678
# 8679
# 8680
# 8681
# 8682
# 8683
# 8684
# 8685
# 8686
# 8687
# 8688
# 8689
# 8690
# 8691
# 8692
# 8693
# 8694
# 8695
# 8696
# 8697
# 8698
# 8699
# 8700
# 8701
# 8702
# 8703
# 8704
# 8705
# 8706
# 8707
# 8708
# 8709
# 8710
# 8711
# 8712
# 8713
# 8714
# 8715
# 8716
# 8717
# 8718
# 8719
# 8720
# 8721
# 8722
# 8723
# 8724
# 8725
# 8726
# 8727
# 8728
# 8729
# 8730
# 8731
# 8732
# 8733
# 8734
# 8735
# 8736
# 8737
# 8738
# 8739
# 8740
# 8741
# 8742
# 8743
# 8744
# 8745
# 8746
# 8747
# 8748
# 8749
# 8750
# 8751
# 8752
# 8753
# 8754
# 8755
# 8756
# 8757
# 8758
# 8759
# 8760
# 8761
# 8762
# 8763
# 8764
# 8765
# 8766
# 8767
# 8768
# 8769
# 8770
# 8771
# 8772
# 8773
# 8774
# 8775
# 8776
# 8777
# 8778
# 8779
# 8780
# 8781
# 8782
# 8783
# 8784
# 8785
# 8786
# 8787
# 8788
# 8789
# 8790
# 8791
# 8792
# 8793
# 8794
# 8795
# 8796
# 8797
# 8798
# 8799
# 8800
# 8801
# 8802
# 8803
# 8804
# 8805
# 8806
# 8807
# 8808
# 8809
# 8810
# 8811
# 8812
# 8813
# 8814
# 8815
# 8816
# 8817
# 8818
# 8819
# 8820
# 8821
# 8822
# 8823
# 8824
# 8825
# 8826
# 8827
# 8828
# 8829
# 8830
# 8831
# 8832
# 8833
# 8834
# 8835
# 8836
# 8837
# 8838
# 8839
# 8840
# 8841
# 8842
# 8843
# 8844
# 8845
# 8846
# 8847
# 8848
# 8849
# 8850
# 8851
# 8852
# 8853
# 8854
# 8855
# 8856
# 8857
# 8858
# 8859
# 8860
# 8861
# 8862
# 8863
# 8864
# 8865
# 8866
# 8867
# 8868
# 8869
# 8870
# 8871
# 8872
# 8873
# 8874
# 8875
# 8876
# 8877
# 8878
# 8879
# 8880
# 8881
# 8882
# 8883
# 8884
# 8885
# 8886
# 8887
# 8888
# 8889
# 8890
# 8891
# 8892
# 8893
# 8894
# 8895
# 8896
# 8897
# 8898
# 8899
# 8900
# 8901
# 8902
# 8903
# 8904
# 8905
# 8906
# 8907
# 8908
# 8909
# 8910
# 8911
# 8912
# 8913
# 8914
# 8915
# 8916
# 8917
# 8918
# 8919
# 8920
# 8921
# 8922
# 8923
# 8924
# 8925
# 8926
# 8927
# 8928
# 8929
# 8930
# 8931
# 8932
# 8933
# 8934
# 8935
# 8936
# 8937
# 8938
# 8939
# 8940
# 8941
# 8942
# 8943
# 8944
# 8945
# 8946
# 8947
# 8948
# 8949
# 8950
# 8951
# 8952
# 8953
# 8954
# 8955
# 8956
# 8957
# 8958
# 8959
# 8960
# 8961
# 8962
# 8963
# 8964
# 8965
# 8966
# 8967
# 8968
# 8969
# 8970
# 8971
# 8972
# 8973
# 8974
# 8975
# 8976
# 8977
# 8978
# 8979
# 8980
# 8981
# 8982
# 8983
# 8984
# 8985
# 8986
# 8987
# 8988
# 8989
# 8990
# 8991
# 8992
# 8993
# 8994
# 8995
# 8996
# 8997
# 8998
# 8999
# 9000
# 9001
# 9002
# 9003
# 9004
# 9005
# 9006
# 9007
# 9008
# 9009
# 9010
# 9011
# 9012
# 9013
# 9014
# 9015
# 9016
# 9017
# 9018
# 9019
# 9020
# 9021
# 9022
# 9023
# 9024
# 9025
# 9026
# 9027
# 9028
# 9029
# 9030
# 9031
# 9032
# 9033
# 9034
# 9035
# 9036
# 9037
# 9038
# 9039
# 9040
# 9041
# 9042
# 9043
# 9044
# 9045
# 9046
# 9047
# 9048
# 9049
# 9050
# 9051
# 9052
# 9053
# 9054
# 9055
# 9056
# 9057
# 9058
# 9059
# 9060
# 9061
# 9062
# 9063
# 9064
# 9065
# 9066
# 9067
# 9068
# 9069
# 9070
# 9071
# 9072
# 9073
# 9074
# 9075
# 9076
# 9077
# 9078
# 9079
# 9080
# 9081
# 9082
# 9083
# 9084
# 9085
# 9086
# 9087
# 9088
# 9089
# 9090
# 9091
# 9092
# 9093
# 9094
# 9095
# 9096
# 9097
# 9098
# 9099
# 9100
# 9101
# 9102
# 9103
# 9104
# 9105
# 9106
# 9107
# 9108
# 9109
# 9110
# 9111
# 9112
# 9113
# 9114
# 9115
# 9116
# 9117
# 9118
# 9119
# 9120
# 9121
# 9122
# 9123
# 9124
# 9125
# 9126
# 9127
# 9128
# 9129
# 9130
# 9131
# 9132
# 9133
# 9134
# 9135
# 9136
# 9137
# 9138
# 9139
# 9140
# 9141
# 9142
# 9143
# 9144
# 9145
# 9146
# 9147
# 9148
# 9149
# 9150
# 9151
# 9152
# 9153
# 9154
# 9155
# 9156
# 9157
# 9158
# 9159
# 9160
# 9161
# 9162
# 9163
# 9164
# 9165
# 9166
# 9167
# 9168
# 9169
# 9170
# 9171
# 9172
# 9173
# 9174
# 9175
# 9176
# 9177
# 9178
# 9179
# 9180
# 9181
# 9182
# 9183
# 9184
# 9185
# 9186
# 9187
# 9188
# 9189
# 9190
# 9191
# 9192
# 9193
# 9194
# 9195
# 9196
# 9197
# 9198
# 9199
# 9200
# 9201
# 9202
# 9203
# 9204
# 9205
# 9206
# 9207
# 9208
# 9209
# 9210
# 9211
# 9212
# 9213
# 9214
# 9215
# 9216
# 9217
# 9218
# 9219
# 9220
# 9221
# 9222
# 9223
# 9224
# 9225
# 9226
# 9227
# 9228
# 9229
# 9230
# 9231
# 9232
# 9233
# 9234
# 9235
# 9236
# 9237
# 9238
# 9239
# 9240
# 9241
# 9242
# 9243
# 9244
# 9245
# 9246
# 9247
# 9248
# 9249
# 9250
# 9251
# 9252
# 9253
# 9254
# 9255
# 9256
# 9257
# 9258
# 9259
# 9260
# 9261
# 9262
# 9263
# 9264
# 9265
# 9266
# 9267
# 9268
# 9269
# 9270
# 9271
# 9272
# 9273
# 9274
# 9275
# 9276
# 9277
# 9278
# 9279
# 9280
# 9281
# 9282
# 9283
# 9284
# 9285
# 9286
# 9287
# 9288
# 9289
# 9290
# 9291
# 9292
# 9293
# 9294
# 9295
# 9296
# 9297
# 9298
# 9299
# 9300
# 9301
# 9302
# 9303
# 9304
# 9305
# 9306
# 9307
# 9308
# 9309
# 9310
# 9311
# 9312
# 9313
# 9314
# 9315
# 9316
# 9317
# 9318
# 9319
# 9320
# 9321
# 9322
# 9323
# 9324
# 9325
# 9326
# 9327
# 9328
# 9329
# 9330
# 9331
# 9332
# 9333
# 9334
# 9335
# 9336
# 9337
# 9338
# 9339
# 9340
# 9341
# 9342
# 9343
# 9344
# 9345
# 9346
# 9347
# 9348
# 9349
# 9350
# 9351
# 9352
# 9353
# 9354
# 9355
# 9356
# 9357
# 9358
# 9359
# 9360
# 9361
# 9362
# 9363
# 9364
# 9365
# 9366
# 9367
# 9368
# 9369
# 9370
# 9371
# 9372
# 9373
# 9374
# 9375
# 9376
# 9377
# 9378
# 9379
# 9380
# 9381
# 9382
# 9383
# 9384
# 9385
# 9386
# 9387
# 9388
# 9389
# 9390
# 9391
# 9392
# 9393
# 9394
# 9395
# 9396
# 9397
# 9398
# 9399
# 9400
# 9401
# 9402
# 9403
# 9404
# 9405
# 9406
# 9407
# 9408
# 9409
# 9410
# 9411
# 9412
# 9413
# 9414
# 9415
# 9416
# 9417
# 9418
# 9419
# 9420
# 9421
# 9422
# 9423
# 9424
# 9425
# 9426
# 9427
# 9428
# 9429
# 9430
# 9431
# 9432
# 9433
# 9434
# 9435
# 9436
# 9437
# 9438
# 9439
# 9440
# 9441
# 9442
# 9443
# 9444
# 9445
# 9446
# 9447
# 9448
# 9449
# 9450
# 9451
# 9452
# 9453
# 9454
# 9455
# 9456
# 9457
# 9458
# 9459
# 9460
# 9461
# 9462
# 9463
# 9464
# 9465
# 9466
# 9467
# 9468
# 9469
# 9470
# 9471
# 9472
# 9473
# 9474
# 9475
# 9476
# 9477
# 9478
# 9479
# 9480
# 9481
# 9482
# 9483
# 9484
# 9485
# 9486

# %%
corr = 0

for item in all_preds:
  if item[1] == item[2]:
    corr += 1
    print(item[0], item[1], item[2], 'correct')
  else:
    print(item[0], item[1], item[2], 'wrong')
 
print(len(all_preds))
print(corr/len(all_preds))
# Out:
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# >:ELOHIJM >LH(J(M/JM d!JX&SFSFSFSFS wrong
# YIW.@H YWH[d d!JX&SFSFSFSFS wrong
# MIT.@RAX M(N-TRX/ d!JX&SFSFSFSFS wrong
# >ET:B.OWN@N !>!](HT]B(J&WN&N[ d!JX&SFSFSFSFS wrong
# H@M@N HMN/ d!JX&SFSFSFSFS wrong
# W.C:L@MIJM W-CLM/JM d!JX&SFSFSFSFS wrong
# B.AM.:Y@DOWT B-(H-MYD/WT d!JX&SFSFSFSFS wrong
# QONEH QNH[/a d!JX&SFSFSFSFS wrong
# B.:D;J B-DJ/c d!JX&SFSFSFSFS wrong
# >;T >T d!JX&SFSFSFSFS wrong
# MID:J@N MDJN/ d!JX&SFSFSFSFS wrong
# D.IB:R;J DBR/J d!JX&SFSFSFSFS wrong
# >:ELOH;JNW. >LH(J(M/J+NW d!JX&SFSFSFSFS wrong
# VOWB VWB[ d!JX&SFSFSFSFS wrong
# WAT.:HIJ W:n-!T!HJ(H[ d!JX&SFSFSFSFS wrong
# K.:QAC K-QC/ d!JX&SFSFSFSFS wrong
# <;JN@JW <JN/J+W d!JX&SFSFSFSFS wrong
# W:>OT@K: W->T+K d!JX&SFSFSFSFS wrong
# L:K@ L+K d!JX&SFSFSFSFS wrong
# VAB.:<OT VB<(T/(WTc d!JX&SFSFSFSFS wrong
# >:AROWN >RWN/ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# N@P@L NPL[ d!JX&SFSFSFSFS wrong
# J@M@JW J(WM/J+W d!JX&SFSFSFSFS wrong
# X@K@M XKM/a d!JX&SFSFSFSFS wrong
# H@<IJR H-<JR/ d!JX&SFSFSFSFS wrong
# <;JN <JN d!JX&SFSFSFSFS wrong
# W.C:N@JIM W-CN(J(M/JM d!JX&SFSFSFSFS wrong
# D.:G@N@M DGN/+M d!JX&SFSFSFSFS wrong
# X@CAB XCB[ d!JX&SFSFSFSFS wrong
# K.AN.ECER K-(H-NCR/ d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# <;JN@JW <JN/J+W d!JX&SFSFSFSFS wrong
# >:AZAB.;XA !>!ZBX[d d!JX&SFSFSFSFS wrong
# LIC:T.OT L-!!CT(H[/(WT d!JX&SFSFSFSFS wrong
# HAP.@R H-PR/a d!JX&SFSFSFSFS wrong
# G.AM GM d!JX&SFSFSFSFS wrong
# MIG:R@CEJH@ MGRC/J+H d!JX&SFSFSFSFS wrong
# RAB RB/ d!JX&SFSFSFSFS wrong
# C.:>;L@T;K: C>L(H/T+K d!JX&SFSFSFSFS wrong
# >;T >T d!JX&SFSFSFSFS wrong
# J:HOWN@T@N JHWNTN/ d!JX&SFSFSFSFS wrong
# MIXW.Y M(N-XWY/ d!JX&SFSFSFSFS wrong
# B.:PIJK: B-P(H&J/+K d!JX&SFSFSFSFS wrong
# W:TOP W-TP/ d!JX&SFSFSFSFS wrong
# D.:D@NIJM DDN(J/JM d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# >:AMIT.AJ >MTJ/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# TIL:X@Y !T!LXY[ d!JX&SFSFSFSFS wrong
# K.:LIJ KLJ/ d!JX&SFSFSFSFS wrong
# L:DOWDIJ L-DWD/+J d!JX&SFSFSFSFS wrong
# JIT.EN !J!(NTN[ d!JX&SFSFSFSFS wrong
# MOCEH MCH/ d!JX&SFSFSFSFS wrong
# BAV.OWB B-(H-VWB/ d!JX&SFSFSFSFS wrong
# B.OW B+W d!JX&SFSFSFSFS wrong
# W:H;M W-HM d!JX&SFSFSFSFS wrong
# H@R:BI<IJ H-RB(J<J/ d!JX&SFSFSFSFS wrong
# W:>IM W->M d!JX&SFSFSFSFS wrong
# P.A>:AR;J P>R/J d!JX&SFSFSFSFS wrong
# L@HEM L+HM d!JX&SFSFSFSFS wrong
# HAJ.OWM H-JWM/ d!JX&SFSFSFSFS wrong
# D.@WID DWD/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# HAJ.OWM H-JWM/ d!JX&SFSFSFSFS wrong
# F:<ORIJM F<R(H/JM d!JX&SFSFSFSFS wrong
# MIV.AH:ARIJM !M!](H(T]VHR[/JM d!JX&SFSFSFSFS wrong
# WAJ.OWCA< W:n-!J!](H](J&WC<[ d!JX&SFSFSFSFS wrong
# >:ELOHEJK@ >LH(J(M/J+K d!JX&SFSFSFSFS wrong
# HAM.IS:P.;D H-MSPD/a d!JX&SFSFSFSFS wrong
# HAP.@TAX H-PTX/a d!JX&SFSFSFSFS wrong
# >OWPIJR@H >WPJR/~H d!JX&SFSFSFSFS wrong
# C;M CM/ d!JX&SFSFSFSFS wrong
# >OTOW >T+W d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# HAM.:L@>K@H H-ML>K(H/H d!JX&SFSFSFSFS wrong
# L:<OL@H L-<L(H/H d!JX&SFSFSFSFS wrong
# REKEB RKB/ d!JX&SFSFSFSFS wrong
# C;C CC/ d!JX&SFSFSFSFS wrong
# L;>MOR L-!!>MR[/c d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# B.AT B(T/T d!JX&SFSFSFSFS wrong
# B.:C;M B-CM/ d!JX&SFSFSFSFS wrong
# W:>ET W->T d!JX&SFSFSFSFS wrong
# S@BIJB SBJB/a d!JX&SFSFSFSFS wrong
# W:J@Y@> W-JY>[ d!JX&SFSFSFSFS wrong
# W:<@L@JW W-<L&J+W d!JX&SFSFSFSFS wrong
# HAJ.OWM H-JWM/ d!JX&SFSFSFSFS wrong
# W.BAJHW@H W-B-JHWH/ d!JX&SFSFSFSFS wrong
# C@LEG CLG/a d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# WA<:AY;J W-<Y/J d!JX&SFSFSFSFS wrong
# HAZ.O>T H-Z>T d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# N:TAT.IJW NT(N[TJ+W d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# N@P:L@H NPL[H d!JX&SFSFSFSFS wrong
# B@NEJK@ BN/J+K d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# W:HAJ:BW.SIJ W-H-JBWSJ/ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# B.@<;T B-(H-<T/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# <@FW. <F(H[W d!JX&SFSFSFSFS wrong
# LAP.@RIJM L-(H-PR/JM d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# HW.> HW> d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# NAP:COT;JNW. NPC/(WTJ+NW d!JX&SFSFSFSFS wrong
# W:HIN.;H W-HNH d!JX&SFSFSFSFS wrong
# JIC:T.EH !J!CTH[ d!JX&SFSFSFSFS wrong
# B.:J@DEJH@ B-JD/J+H d!JX&SFSFSFSFS wrong
# WAJ.O>MER W:n-!J!>MR[ d!JX&SFSFSFSFS wrong
# >:ELOHEJK@ >LH(J(M/J+K d!JX&SFSFSFSFS wrong
# HIN.OW HN(H+W d!JX&SFSFSFSFS wrong
# HAM.ELEK: H-MLK/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# POH PH d!JX&SFSFSFSFS wrong
# LOW L+W d!JX&SFSFSFSFS wrong
# H@>OJ;B H->JB[/ d!JX&SFSFSFSFS wrong
# W@XAJ W-XJ(H[ d!JX&SFSFSFSFS wrong
# H:ALOW> H-L&W> d!JX&SFSFSFSFS wrong
# W:K@L W-KL/ d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# B:LEB B-LB/c d!JX&SFSFSFSFS wrong
# YW.R YWR/ d!JX&SFSFSFSFS wrong
# >AB:R@H@M >BRHM/ d!JX&SFSFSFSFS wrong
# W:R@>@H W-R>H[ d!JX&SFSFSFSFS wrong
# J@DEJH@ JD/J+H d!JX&SFSFSFSFS wrong
# HIN.;H HNH d!JX&SFSFSFSFS wrong
# B.:N;J BN/J d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# C@XAV CXV[ d!JX&SFSFSFSFS wrong
# P.:LONIJ PLNJ/ d!JX&SFSFSFSFS wrong
# H@R;J HR/J d!JX&SFSFSFSFS wrong
# >EX@D >XD/a d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# S;PER SPR/ d!JX&SFSFSFSFS wrong
# WAJ.IQ.@XW.M W:n-!J!(LQX[W+M d!JX&SFSFSFSFS wrong
# J@BI> !J!](H]B(W>[ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# K.A<:FIJ K<(S&F/+J d!JX&SFSFSFSFS wrong
# G.IL:ALAJ GLLJ/ d!JX&SFSFSFSFS wrong
# W:ZIQ:N;J W-ZQN/J d!JX&SFSFSFSFS wrong
# J@MIJM@H J(WM/JM~H d!JX&SFSFSFSFS wrong
# B.:YIL.OW B-YL/+W d!JX&SFSFSFSFS wrong
# B.:QIJROWT B-QJR/WT d!JX&SFSFSFSFS wrong
# M:N@<ANIJ MN<[+NJ d!JX&SFSFSFSFS wrong
# CIN:<@R CN<R/ d!JX&SFSFSFSFS wrong
# >:AXUZ.AT >XZ(H/Tc d!JX&SFSFSFSFS wrong
# J:CAQ.;R !J!CQR[d d!JX&SFSFSFSFS wrong
# MIL.IP:N;J M(N-L-PN(H/J d!JX&SFSFSFSFS wrong
# B.:M;<@JW B-M<(J(M/J+W d!JX&SFSFSFSFS wrong
# >EX@JW >X/J+W d!JX&SFSFSFSFS wrong
# HAZ.EH H-ZH d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# W:GAM W-GM d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# LIP:N;J L-PN(H/J d!JX&SFSFSFSFS wrong
# >;JN >JN/c d!JX&SFSFSFSFS wrong
# H@>;L.EH H->LH d!JX&SFSFSFSFS wrong
# HAM.ELEK: H-MLK/ d!JX&SFSFSFSFS wrong
# W:<;JNAJIM W-<JN/JM d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# JOWS;P JWSP/ d!JX&SFSFSFSFS wrong
# L:M@<:L@H L-M<L/~Ha d!JX&SFSFSFSFS wrong
# K.AM.ID:B.@R K-(H-MDBR/a d!JX&SFSFSFSFS wrong
# B.AM.IL:X@M@H B-(H-MLXM(H/H d!JX&SFSFSFSFS wrong
# <AB:D.:K@ <BD/+K d!JX&SFSFSFSFS wrong
# W:JO>MAR W-!J!>MR[ d!JX&SFSFSFSFS wrong
# MOCEH MCH/ d!JX&SFSFSFSFS wrong
# Z@Q;N ZQN/a d!JX&SFSFSFSFS wrong
# HAP.:LIC:T.IJ H-PLCTJ/ d!JX&SFSFSFSFS wrong
# F:D;H FDH/c d!JX&SFSFSFSFS wrong
# W:GOCEN W-GCN/ d!JX&SFSFSFSFS wrong
# >AD.IJRIJM >DJR/JM d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# MIX:J@H MXJ(H/H d!JX&SFSFSFSFS wrong
# MIM.EN.W. M(N&M&N+(HW d!JX&SFSFSFSFS wrong
# L@<IJR L-(H-<JR/ d!JX&SFSFSFSFS wrong
# L@KEM L+KM d!JX&SFSFSFSFS wrong
# W:>;JN W->JN/c d!JX&SFSFSFSFS wrong
# W:>;L:K@H W-!>!(HLK[H d!JX&SFSFSFSFS wrong
# WAJ.;LAK: W:n-!J!(HLK[ d!JX&SFSFSFSFS wrong
# H@<@M H-<M/a d!JX&SFSFSFSFS wrong
# >AT.EM >TM d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# M@Y@>T@ MY>[T d!JX&SFSFSFSFS wrong
# C:L@L@H. CLL/+H d!JX&SFSFSFSFS wrong
# J:Q@ROWT JQR/WTa d!JX&SFSFSFSFS wrong
# MID.@H MD(H/H d!JX&SFSFSFSFS wrong
# MELEK: MLK/ d!JX&SFSFSFSFS wrong
# K.:L;J KL(J/J d!JX&SFSFSFSFS wrong
# L:RAG:LEJK@ L-RGL/J+K d!JX&SFSFSFSFS wrong
# <AB:D.OW <BD/+W d!JX&SFSFSFSFS wrong
# JOW>@B JW>B/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# K.:JOWM K-JWM/ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# W:>@CW.B@H W-!>!CWB[H d!JX&SFSFSFSFS wrong
# L@>IJC L-(H->JC/ d!JX&SFSFSFSFS wrong
# W:KOL W-KL/ d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# B.OW B+W d!JX&SFSFSFSFS wrong
# >:ADONEJK@ >D(WN/J+K d!JX&SFSFSFSFS wrong
# B:R@K@H BRK(H/H d!JX&SFSFSFSFS wrong
# W:L@FW.M W-L-!!F(J&WM[/c d!JX&SFSFSFSFS wrong
# >EX@JW >X/J+W d!JX&SFSFSFSFS wrong
# L@R@C@< L-(H-RC</a d!JX&SFSFSFSFS wrong
# <AD <D d!JX&SFSFSFSFS wrong
# N:>UM N>M/ d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# XONIJM XN(H[/JM d!JX&SFSFSFSFS wrong
# X@V@>NW. XV>[NW d!JX&SFSFSFSFS wrong
# W:H@>AX:ARONIJM W-H->XR(WN/JM d!JX&SFSFSFSFS wrong
# WAT.IC:>@B W:n-!T!C>B[ d!JX&SFSFSFSFS wrong
# L:C@>W.L L-C>WL/ d!JX&SFSFSFSFS wrong
# GIC:M;JKEM GCM/J+KM d!JX&SFSFSFSFS wrong
# W:K@L W-KL/ d!JX&SFSFSFSFS wrong
# JAD JD/c d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# HAR HR/ d!JX&SFSFSFSFS wrong
# K.IS:DOM K-SDM/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# B.AXW.YOWT B-(H-XWY/WT d!JX&SFSFSFSFS wrong
# WAJ.AK.;HW. W:n-!J!](H](NK(H[+HW d!JX&SFSFSFSFS wrong
# S:BIJBOTEJH@ SBJB/(WTJ+H d!JX&SFSFSFSFS wrong
# NAP:CIJ NPC/+J d!JX&SFSFSFSFS wrong
# W:GIJLW. W-!!GJL[W d!JX&SFSFSFSFS wrong
# >IC.;H >CH/c d!JX&SFSFSFSFS wrong
# B.AY.AR B-(H-YR/ d!JX&SFSFSFSFS wrong
# >AR:YOW >RY/+W d!JX&SFSFSFSFS wrong
# NAP:T.@LIJ NPTLJ/ d!JX&SFSFSFSFS wrong
# NIB:ZEH ]N]BZH[/a d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# W:CAL.:MW. W-!!CLM[Wd d!JX&SFSFSFSFS wrong
# M@G;N MGN/ d!JX&SFSFSFSFS wrong
# Q@CAR QCR[ d!JX&SFSFSFSFS wrong
# H@>OHEL H->HL/ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# L;>MOR L-!!>MR[/c d!JX&SFSFSFSFS wrong
# HIT:<AN.@H ]HT]<NH[ d!JX&SFSFSFSFS wrong
# HAM.IZ:B.;XA H-MZBX/ d!JX&SFSFSFSFS wrong
# L@K;N LKN d!JX&SFSFSFSFS wrong
# NOT;N NTN[/ d!JX&SFSFSFSFS wrong
# ZIB:XIJ ZBX/+J d!JX&SFSFSFSFS wrong
# M:ZW.ZOT MZWZ(H/(WT d!JX&SFSFSFSFS wrong
# B.EN BN/c d!JX&SFSFSFSFS wrong
# QAX !!(LQX[ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# HAM.;LIJY H-!M!](H]LJY[/ d!JX&SFSFSFSFS wrong
# HA>UM:N@M H->MNM d!JX&SFSFSFSFS wrong
# MIJ.AD M(N-JD/c d!JX&SFSFSFSFS wrong
# H@<AM.UD H-<M(WD/ d!JX&SFSFSFSFS wrong
# HAG.IB:<@H H-GB<(H/H d!JX&SFSFSFSFS wrong
# WAJ.A<:ABOD W:n-!J!<BD[ d!JX&SFSFSFSFS wrong
# Q:XW. !!(LQX[W d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# B.;N BN/a d!JX&SFSFSFSFS wrong
# WAJ.IT.EN W:n-!J!(NTN[ d!JX&SFSFSFSFS wrong
# W:NIS:K.OW W-NSK/+W d!JX&SFSFSFSFS wrong
# HAC.EMEC H-CMC/ d!JX&SFSFSFSFS wrong
# H@R:GW. HRG[W d!JX&SFSFSFSFS wrong
# W:H@J@H W-HJH[ d!JX&SFSFSFSFS wrong
# B.:<IJROW B-<JR/+W d!JX&SFSFSFSFS wrong
# X;N XN/ d!JX&SFSFSFSFS wrong
# HIT:QAD.@CW. ]HT]QDC[W d!JX&SFSFSFSFS wrong
# LIJ L+J d!JX&SFSFSFSFS wrong
# G.:R@P@M GRP[+M d!JX&SFSFSFSFS wrong
# WIJY@>TEM W-JY>[TM d!JX&SFSFSFSFS wrong
# >AXAT >X(D/T d!JX&SFSFSFSFS wrong
# NIG.:PW. ]N](NGP[W d!JX&SFSFSFSFS wrong
# T.ID:ROK: !T!DRK[ d!JX&SFSFSFSFS wrong
# B.EN BN/c d!JX&SFSFSFSFS wrong
# H;JLIJLW. !!]H]JL&JL[W d!JX&SFSFSFSFS wrong
# WAJ.;CEB W:n-!J!(JCB[ d!JX&SFSFSFSFS wrong
# LAX:MEK@ LXM/+K d!JX&SFSFSFSFS wrong
# M:FAX:AQIJM !M!FXQ[/JMd d!JX&SFSFSFSFS wrong
# W.M;J:HW@H W-M(N-JHWH/ d!JX&SFSFSFSFS wrong
# P.:L;VIJM PL(JV/JM d!JX&SFSFSFSFS wrong
# <IZ.IJM <Z/JM d!JX&SFSFSFSFS wrong
# T.IH:JEH !T!HJH[ d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# W.C:LOC W-CLC/c d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# M;>OWT M>(H/WTa d!JX&SFSFSFSFS wrong
# LE>:EKOL L-!!>KL[/c d!JX&SFSFSFSFS wrong
# HAN.OG;<A H-NG<[/ d!JX&SFSFSFSFS wrong
# G.;>EH G>H/ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# H:AJ;C H-JC/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# WAJ.O>MER W:n-!J!>MR[ d!JX&SFSFSFSFS wrong
# >;T >T d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# <@F@H <FH[ d!JX&SFSFSFSFS wrong
# WAJ.IF:R:PW. W:n-!J!FRP[W d!JX&SFSFSFSFS wrong
# M;>@Z M(N->Z d!JX&SFSFSFSFS wrong
# MOCEH MCH/ d!JX&SFSFSFSFS wrong
# R@>@H R>H[ d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# W.C:PAV:T.IJK: W-CPV[TJ+K d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# >OJ:BAJ >JB[/J+(J d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# H@<@M H-<M/a d!JX&SFSFSFSFS wrong
# K.AD KD/ d!JX&SFSFSFSFS wrong
# ZIQ.IJM ZQ/JM d!JX&SFSFSFSFS wrong
# H:ALO> H-L> d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# W:LA<:AFOWT W-L-!!<F(H[/WT d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# WAJ.AS.A< W:n-!J!](H](NS<[ d!JX&SFSFSFSFS wrong
# >@T.@H >TH d!JX&SFSFSFSFS wrong
# LOW L+W d!JX&SFSFSFSFS wrong
# W:L@R>W.B;NIJ W-L-(H-R>WBNJ/ d!JX&SFSFSFSFS wrong
# HAB.EV !!]H](NBV[ d!JX&SFSFSFSFS wrong
# >:ANIJ >NJ d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# T.O>KAL:N@H !T!>KL[NH d!JX&SFSFSFSFS wrong
# <IJR <JR/ d!JX&SFSFSFSFS wrong
# B.@<;T B-(H-<T/ d!JX&SFSFSFSFS wrong
# W:LIM:NAC.EH W-L-MNCH/ d!JX&SFSFSFSFS wrong
# MOCEH MCH/ d!JX&SFSFSFSFS wrong
# J:D;JHEM JD/J+HM d!JX&SFSFSFSFS wrong
# K.:F@KIJR K-FKJR/a d!JX&SFSFSFSFS wrong
# B.:QOLEK@ B-Q(WL/+K d!JX&SFSFSFSFS wrong
# K.IC:G@G@H K-CGG(H/H d!JX&SFSFSFSFS wrong
# HOWLIJD ]H](J&WL&JD[ d!JX&SFSFSFSFS wrong
# >;L;K: !>!(HLK[ d!JX&SFSFSFSFS wrong
# WAJ.IJRAC W:n-!J!JRC[ d!JX&SFSFSFSFS wrong
# XEREB XRB/ d!JX&SFSFSFSFS wrong
# WAJ.A<:ABOR W:n-!J!<BR[ d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# C:KAB !!CKB[ d!JX&SFSFSFSFS wrong
# W.MAL:>@K: W-ML>K/a d!JX&SFSFSFSFS wrong
# JOWS;P JWSP/ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# >:ELOHIJM >LH(J(M/JM d!JX&SFSFSFSFS wrong
# MOW>@B MW>B/ d!JX&SFSFSFSFS wrong
# Y:B@>OWT YB>/WTa d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# <AF.;R !!<FR[/da d!JX&SFSFSFSFS wrong
# L:>EP:RAJIM L->PRJM/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# BEN BN/c d!JX&SFSFSFSFS wrong
# J@MIJM J(WM/JM d!JX&SFSFSFSFS wrong
# W:DA<AT W-D<(T/T d!JX&SFSFSFSFS wrong
# <@L@JW <L&J+W d!JX&SFSFSFSFS wrong
# W.C:PAV:J@HW. W-CPVJHW/ d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# B.:NAX:AL@H B-NXL(H/H d!JX&SFSFSFSFS wrong
# W.MIC:MAR:T.@M W-MCMR(T/T+M d!JX&SFSFSFSFS wrong
# MIM.@X:@RAT M(N-MXR(T/Tc d!JX&SFSFSFSFS wrong
# METEG MTG/ d!JX&SFSFSFSFS wrong
# >W.RIJ.@H >WRJH/ d!JX&SFSFSFSFS wrong
# L:BIL:T.IJ L-BLT/~J d!JX&SFSFSFSFS wrong
# WAJ.IC:LAX W:n-!J!CLX[ d!JX&SFSFSFSFS wrong
# ZIM.@H ZM(H/H d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# L:P@N@JW L-PN(H/J+W d!JX&SFSFSFSFS wrong
# W.M@R@D:NW. W-MRD[NW d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# C:LOC CLC/c d!JX&SFSFSFSFS wrong
# >@BIJ >B/+J d!JX&SFSFSFSFS wrong
# JIK:S:MW. !J!KSM[W d!JX&SFSFSFSFS wrong
# W:HAG.;D W-!!]H](NGD[ d!JX&SFSFSFSFS wrong
# WAJ.O>M:RW. W:n-!J!>MR[W d!JX&SFSFSFSFS wrong
# B.:>EREY B->RY/ d!JX&SFSFSFSFS wrong
# Q@ROWB QRWB/ d!JX&SFSFSFSFS wrong
# W:JIY:X@Q W-JYXQ/ d!JX&SFSFSFSFS wrong
# >IJC >JC/ d!JX&SFSFSFSFS wrong
# Q:HAL QHL/c d!JX&SFSFSFSFS wrong
# NIB:G.AD !N!BGD[ d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# WAJ.IB:XAR W:n-!J!BXR[ d!JX&SFSFSFSFS wrong
# LA>:ACER L->CR d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# B.:N;JKEM BN/J+KM d!JX&SFSFSFSFS wrong
# HAD.@B@R H-DBR/a d!JX&SFSFSFSFS wrong
# J:RW.C@LA:M@H JRWCLM/~H d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# MIQ.IB:R;JHEM M(N-QBR/J+HM d!JX&SFSFSFSFS wrong
# <OWL@M <WLM/a d!JX&SFSFSFSFS wrong
# >EC:T.OWN >CTWN/ d!JX&SFSFSFSFS wrong
# XW.C@M X&WCM/ d!JX&SFSFSFSFS wrong
# MIM.IC:P.AXAT M(N-MCPX(T/T d!JX&SFSFSFSFS wrong
# >@D@M >DM/ d!JX&SFSFSFSFS wrong
# W.PUR@H W-PRH/ d!JX&SFSFSFSFS wrong
# MIK.AP M(N-KP/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# W.P@R:FW. W-PRF[W d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# HAM.ELEK: H-MLK/ d!JX&SFSFSFSFS wrong
# M;>;T M(N->T d!JX&SFSFSFSFS wrong
# >OWBIJC !>!](H](J&WB&JC[ d!JX&SFSFSFSFS wrong
# JIC.@<;NW. !J!](N]C<N[W d!JX&SFSFSFSFS wrong
# J@LAD JLD[ d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# >ES:T.;R >STR/ d!JX&SFSFSFSFS wrong
# W.L:>IM.IJ W-L->M/+J d!JX&SFSFSFSFS wrong
# C:KEM CKM/ d!JX&SFSFSFSFS wrong
# LIQ:HAL L-QHL/c d!JX&SFSFSFSFS wrong
# W.BIJRW.C@L@IM W-B-JRWCLM/ d!JX&SFSFSFSFS wrong
# W:HIT:<ORAR:T.IJ W-]HT]<(WR&R[TJ d!JX&SFSFSFSFS wrong
# M;>;T M(N->T d!JX&SFSFSFSFS wrong
# YIP.:@RIJM YP(WR/JM d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# MELEK: MLK/ d!JX&SFSFSFSFS wrong
# HAHW.> H-HW> d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# X@S;RW. XSR[W d!JX&SFSFSFSFS wrong
# <;JL@M <JLM/ d!JX&SFSFSFSFS wrong
# HAK.OH:ANIJM H-KHN/JM d!JX&SFSFSFSFS wrong
# MOCEH MCH/ d!JX&SFSFSFSFS wrong
# W:Q@LIJ W-QLJ/ d!JX&SFSFSFSFS wrong
# >IM >M d!JX&SFSFSFSFS wrong
# WAJ:CAB.;R W:n-!J!CBR[d d!JX&SFSFSFSFS wrong
# <OLAT <L(H/Tc d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# H@<:ABOD@H H-<BD(H/H d!JX&SFSFSFSFS wrong
# XEREB XRB/ d!JX&SFSFSFSFS wrong
# GAM GM d!JX&SFSFSFSFS wrong
# LOW L+W d!JX&SFSFSFSFS wrong
# H;>@KOL !H!](N]>KL[/a d!JX&SFSFSFSFS wrong
# Q:VORET QVR(T/T d!JX&SFSFSFSFS wrong
# YW.RIJ YWR/+J d!JX&SFSFSFSFS wrong
# W:>ET W->T d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# H@<@M H-<M/a d!JX&SFSFSFSFS wrong
# B:NOW BN/+W d!JX&SFSFSFSFS wrong
# J:HW.D@H JHWDH/ d!JX&SFSFSFSFS wrong
# D.@RAK:T.@ DRK[T d!JX&SFSFSFSFS wrong
# >OWR >WR/ d!JX&SFSFSFSFS wrong
# P.AR:<OH PR<H/ d!JX&SFSFSFSFS wrong
# MIP.IJ M(N-P(H&J/c d!JX&SFSFSFSFS wrong
# M:CUXIJM MCX[/JM:p d!JX&SFSFSFSFS wrong
# HAM.@JIM H-MJ(M/(JM d!JX&SFSFSFSFS wrong
# N@TAN NTN[ d!JX&SFSFSFSFS wrong
# M@CAX:T.@ MCX[T d!JX&SFSFSFSFS wrong
# R@P@> RP>/ d!JX&SFSFSFSFS wrong
# ZEH ZH d!JX&SFSFSFSFS wrong
# L;>MOR L-!!>MR[/c d!JX&SFSFSFSFS wrong
# LA<:AFOWT L-!!<F(H[/WT d!JX&SFSFSFSFS wrong
# L:P@N@JW L-PN(H/J+W d!JX&SFSFSFSFS wrong
# WAJ.IG.AC W:n-!J!(NGC[ d!JX&SFSFSFSFS wrong
# JOWRE> !J!](H](J&WR(H&>[ d!JX&SFSFSFSFS wrong
# XIZ:QIJ.@HW. XZQJHW/ d!JX&SFSFSFSFS wrong
# W:>EL W->L d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# COD CD/ d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# X@ZOWN XZWN/a d!JX&SFSFSFSFS wrong
# HIJ> HJ> d!JX&SFSFSFSFS wrong
# <AD <D d!JX&SFSFSFSFS wrong
# ZIQ:N;JKEM ZQN/J+KM d!JX&SFSFSFSFS wrong
# XAS:D.OW XSD/+W d!JX&SFSFSFSFS wrong
# LAY.W.L@H L-(H-YWL(H/H d!JX&SFSFSFSFS wrong
# LIP:N;JHEM L-PN(H/J+HM d!JX&SFSFSFSFS wrong
# LAM.:L@>K@H L-(H-ML>K(H/H d!JX&SFSFSFSFS wrong
# >IJC >JC/ d!JX&SFSFSFSFS wrong
# W:ZO>T W-Z>T d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# W:>;JN W->JN/c d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# LAXODEC L-(H-XDC/ d!JX&SFSFSFSFS wrong
# HIN:NIJ HN(H+NJ d!JX&SFSFSFSFS wrong
# W:J@Q:C@N W-JQCN/ d!JX&SFSFSFSFS wrong
# W:<AT.@H W-<TH d!JX&SFSFSFSFS wrong
# MAP:RIJS !M!](H]PR&JS[/ d!JX&SFSFSFSFS wrong
# P.@RAS PRS/ d!JX&SFSFSFSFS wrong
# K;N KN/ d!JX&SFSFSFSFS wrong
# J;Y;> !J!(JY>[ d!JX&SFSFSFSFS wrong
# ZEH ZH d!JX&SFSFSFSFS wrong
# J:KAB.EN.@H !J!KB(H[~Nd+H d!JX&SFSFSFSFS wrong
# N:>UM N>M/ d!JX&SFSFSFSFS wrong
# K;N KN d!JX&SFSFSFSFS wrong
# B.EN BN/c d!JX&SFSFSFSFS wrong
# W:LIN:SOK: W-L-!!NSK[/c d!JX&SFSFSFSFS wrong
# M;<IM M(N-<M d!JX&SFSFSFSFS wrong
# L@HEM L+HM d!JX&SFSFSFSFS wrong
# HAM.IN:X@H H-MNX(H/H d!JX&SFSFSFSFS wrong
# QOWMAT QWM(H/Tc d!JX&SFSFSFSFS wrong
# B.:JOWM B-JWM/ d!JX&SFSFSFSFS wrong
# CIM:<@H !!CM<[H d!JX&SFSFSFSFS wrong
# BE>:EMET B->M(T/T d!JX&SFSFSFSFS wrong
# >AX;R >XR/ d!JX&SFSFSFSFS wrong
# HW.> HW> d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# T.ID:R:CW. !T!DRC[W d!JX&SFSFSFSFS wrong
# HAM.IZ:B.;XA H-MZBX/ d!JX&SFSFSFSFS wrong
# >;L@JW >L&J+W d!JX&SFSFSFSFS wrong
# W:X;J W-XJ/ d!JX&SFSFSFSFS wrong
# RO>COW R>C/+W d!JX&SFSFSFSFS wrong
# L@KEM L+KM d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# HAZ.EH H-ZH d!JX&SFSFSFSFS wrong
# <@F@R <FR/ d!JX&SFSFSFSFS wrong
# H@<:AN.:TOTIJ H-<NTTJ/ d!JX&SFSFSFSFS wrong
# L:C@>W.L L-C>WL/ d!JX&SFSFSFSFS wrong
# WAX:AMIC.IJM W-XMC/JM d!JX&SFSFSFSFS wrong
# H@>:AHW.B@H H->H&WB[/H:p d!JX&SFSFSFSFS wrong
# Z@BAX ZBX/a d!JX&SFSFSFSFS wrong
# W:>EL W->L d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# B.:N;J BN/J d!JX&SFSFSFSFS wrong
# W:J@B;N W-!J!B(JN[ d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# L:HOWDOWT L-!!]H](J&WD(H[/WT d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# MIK.W.R M(N-KWR/ d!JX&SFSFSFSFS wrong
# J:R@> !!JR>[ d!JX&SFSFSFSFS wrong
# HAB.EV !!]H](NBV[ d!JX&SFSFSFSFS wrong
# H@>:ELOHIJM H->LH(J(M/JM d!JX&SFSFSFSFS wrong
# C@LOC CLC/a d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# H@>;JLIJM H->JL/JM d!JX&SFSFSFSFS wrong
# MELEK: MLK/ d!JX&SFSFSFSFS wrong
# M;HOWCIJ<A M(N-!!]H](J&WC&J<[/c d!JX&SFSFSFSFS wrong
# QOWY QWY/ d!JX&SFSFSFSFS wrong
# MIK.A<AS M(N-K<S/ d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# M;<:ALOWT M(N-!!<L(H[/WT d!JX&SFSFSFSFS wrong
# MELEK: MLK/ d!JX&SFSFSFSFS wrong
# HAN.@SEK: H-NSK/a d!JX&SFSFSFSFS wrong
# <AM.IJ <M/+J d!JX&SFSFSFSFS wrong
# NAX:AL@H NXL(H/H d!JX&SFSFSFSFS wrong
# MELEK: MLK/ d!JX&SFSFSFSFS wrong
# B:YIL.OW B-YL/+W d!JX&SFSFSFSFS wrong
# JIZ:K.:RW.K@ !J!ZKR[W+K d!JX&SFSFSFSFS wrong
# <UL.;NW. <L/+NW d!JX&SFSFSFSFS wrong
# <OWL@M <WLM/a d!JX&SFSFSFSFS wrong
# W.BAJ.OWM W-B-(H-JWM/ d!JX&SFSFSFSFS wrong
# WAJ.IT:P.@R:QW. W:n-!J!](HT]PRQ[W d!JX&SFSFSFSFS wrong
# D.IB:R;J DBR/J d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# C@N@H CN(H/H d!JX&SFSFSFSFS wrong
# W:J@D:<W. W-JD<[W d!JX&SFSFSFSFS wrong
# <AD <D d!JX&SFSFSFSFS wrong
# <IM.@K: <M+K d!JX&SFSFSFSFS wrong
# WAJ.A<AF W:n-!J!<F(H[ d!JX&SFSFSFSFS wrong
# X@K:M@H XKM(H/H d!JX&SFSFSFSFS wrong
# HW.> HW> d!JX&SFSFSFSFS wrong
# >;LEJK@ >L&J+K d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# B.@M B+M d!JX&SFSFSFSFS wrong
# MIM.;K: M(N&M+K d!JX&SFSFSFSFS wrong
# QOWL;K: QWL/+K d!JX&SFSFSFSFS wrong
# G.@D GD/ d!JX&SFSFSFSFS wrong
# W:<@BAR W-<BR[ d!JX&SFSFSFSFS wrong
# MOCEH MCH/ d!JX&SFSFSFSFS wrong
# W:<IW.@H W-<WH/ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# W@>;L;K: W:n-!>!(HLK[ d!JX&SFSFSFSFS wrong
# D.@WIJD DW&JD/ d!JX&SFSFSFSFS wrong
# XAJIL XJL/a d!JX&SFSFSFSFS wrong
# >:AROWN >RWN/ d!JX&SFSFSFSFS wrong
# >OJ:BEJK@ >JB[/J+K d!JX&SFSFSFSFS wrong
# LAC.@QER L-(H-CQR/a d!JX&SFSFSFSFS wrong
# <IM.:K@ <M+K d!JX&SFSFSFSFS wrong
# >:AL;JKEM >L&J+KM d!JX&SFSFSFSFS wrong
# <OWD <WD/ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# T.:N@H !!(NTN[H d!JX&SFSFSFSFS wrong
# B.:G@D@JW BGD/J+W d!JX&SFSFSFSFS wrong
# >OM:RIJM >MR[/JM d!JX&SFSFSFSFS wrong
# B.;JTOW BJT/+W d!JX&SFSFSFSFS wrong
# WAJ.IT.;N W:n-!J!(NTN[ d!JX&SFSFSFSFS wrong
# T.@MIJM TMJM/a d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# M@R@DW. MRD[W d!JX&SFSFSFSFS wrong
# C:LOC CLC/c d!JX&SFSFSFSFS wrong
# L@>OWR L-(H->WR/ d!JX&SFSFSFSFS wrong
# J@R@Q JRQ/a d!JX&SFSFSFSFS wrong
# T.:K@KIJM TK&K/JM d!JX&SFSFSFSFS wrong
# M:<AV M<V/ d!JX&SFSFSFSFS wrong
# M:LO> ML>/ d!JX&SFSFSFSFS wrong
# S@R S(WR[ d!JX&SFSFSFSFS wrong
# B.EX@RIJC B-(H-XRJC/ d!JX&SFSFSFSFS wrong
# W:<AT.@H W-<TH d!JX&SFSFSFSFS wrong
# WAJ.IPEN W:n-!J!PN(H[ d!JX&SFSFSFSFS wrong
# G.:BW.R@TOW GBWR(H/T+W d!JX&SFSFSFSFS wrong
# LAM.IL:X@M@H L-(H-MLXM(H/H d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# C@>W.L C>WL/ d!JX&SFSFSFSFS wrong
# XAS:D;J XSD/J d!JX&SFSFSFSFS wrong
# >IC.@H >C(H/H d!JX&SFSFSFSFS wrong
# W:>ET W->T d!JX&SFSFSFSFS wrong
# K.:K@L K-KL/ d!JX&SFSFSFSFS wrong
# LIJ L+J d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# L;>MOR L-!!>MR[/c d!JX&SFSFSFSFS wrong
# N@XOWR NXWR/ d!JX&SFSFSFSFS wrong
# M;>OWT M>(H/WTa d!JX&SFSFSFSFS wrong
# HAM.A<:AFEH H-M<FH/a d!JX&SFSFSFSFS wrong
# B.@GAD:T.@H BGD[T&H d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# K.@Z@B KZB/a d!JX&SFSFSFSFS wrong
# MAF.@> MF>/ d!JX&SFSFSFSFS wrong
# W:GAN.OWTIJ W-GN(N[&WTJ d!JX&SFSFSFSFS wrong
# >EB:R@TOW >BR(H/T+W d!JX&SFSFSFSFS wrong
# LOW L+W d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# HE<:ELIJTUNW. ]H]<L(H&J[T(M+NW d!JX&SFSFSFSFS wrong
# W:HAG.;R W-H-GR/ d!JX&SFSFSFSFS wrong
# NIY:M@TW. ]N]YMT[W d!JX&SFSFSFSFS wrong
# LIC:LOWM L-CLWM/c d!JX&SFSFSFSFS wrong
# W.M;<OWP W-M(N-<WP/ d!JX&SFSFSFSFS wrong
# W:HAX:AR;DIJM W-H-XRD/JM d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# L:JA<:AQOB L-J<QB/ d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# R:BOWT !!RB(H[/WT d!JX&SFSFSFSFS wrong
# <:AFOWT:KEM !!<F(H[/WT+KM d!JX&SFSFSFSFS wrong
# B:N;J BN/J d!JX&SFSFSFSFS wrong
# JA<AN J<N/ d!JX&SFSFSFSFS wrong
# J:HW.D@H JHWDH/ d!JX&SFSFSFSFS wrong
# HAK.OH;N H-KHN/ d!JX&SFSFSFSFS wrong
# WAJ.IG:HAR W:n-!J!GHR[ d!JX&SFSFSFSFS wrong
# L;B@B LBB/a d!JX&SFSFSFSFS wrong
# NEH:P.@KET ]N]HPK[/Ta d!JX&SFSFSFSFS wrong
# WAJ.AC:K.;M W:n-!J!](H]CKM[ d!JX&SFSFSFSFS wrong
# T.@MIJM TMJM/a d!JX&SFSFSFSFS wrong
# WAJ.IC:MA< W:n-!J!CM<[ d!JX&SFSFSFSFS wrong
# JW.K:LW. !J!(J&WKL[W d!JX&SFSFSFSFS wrong
# B.AJ.@MIJM B-(H-J(WM/JM d!JX&SFSFSFSFS wrong
# J:CAL.:XEN.W. !J!CLX[~Nd+(HW d!JX&SFSFSFSFS wrong
# LOW L+W d!JX&SFSFSFSFS wrong
# >OWCIJ<A !>!](H](J&WC&J<[ d!JX&SFSFSFSFS wrong
# K.@H;M K+HM d!JX&SFSFSFSFS wrong
# >AX:AREJK@ >XR/J+K d!JX&SFSFSFSFS wrong
# H@<@M H-<M/a d!JX&SFSFSFSFS wrong
# JAK.EN.W. !J!](H](NK(H[~N+(HW d!JX&SFSFSFSFS wrong
# <@L@JW <L&J+W d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# L@DA<AT L-!!(JD<[/T d!JX&SFSFSFSFS wrong
# W:REKEB W-RKB/ d!JX&SFSFSFSFS wrong
# B.:YUROWT BY(WR/WT d!JX&SFSFSFSFS wrong
# W.L:>@XIJK@ W-L->X/~J+K d!JX&SFSFSFSFS wrong
# B.:RIJTIJ BRJT/+J d!JX&SFSFSFSFS wrong
# L:>IC.@H L->C(H/H d!JX&SFSFSFSFS wrong
# >@MAR >MR[ d!JX&SFSFSFSFS wrong
# J:<@RIJM J<RJM/ d!JX&SFSFSFSFS wrong
# W@H@L:>@H W-HL>H d!JX&SFSFSFSFS wrong
# D.AB.;R !!DBR[d d!JX&SFSFSFSFS wrong
# C@>W.L C>WL/ d!JX&SFSFSFSFS wrong
# R@C@< RC</a d!JX&SFSFSFSFS wrong
# >@MAR >MR[ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# X@K@M XKM/a d!JX&SFSFSFSFS wrong
# CAT.ANIJ C(J(T[T+NJ d!JX&SFSFSFSFS wrong
# <EF:RIJM <FR(J(M/JM d!JX&SFSFSFSFS wrong
# L:<UM.AT L-<M(H/Tc d!JX&SFSFSFSFS wrong
# R@>C;J R>C/J d!JX&SFSFSFSFS wrong
# J:DA<:T.EM JD<[TM d!JX&SFSFSFSFS wrong
# M;YAX MYX/ d!JX&SFSFSFSFS wrong
# MIN MN d!JX&SFSFSFSFS wrong
# HAP.AR:T.:MIJM H-PRTM(J(M/JM d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# MAY.;B@H MYB(H/H d!JX&SFSFSFSFS wrong
# T.@BO> !T!B(W>[ d!JX&SFSFSFSFS wrong
# B.OW B+W d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# TAL:WEN.W. !T!](H]LW(H[~N+(HW d!JX&SFSFSFSFS wrong
# Y:B@>OWT YB>/WTa d!JX&SFSFSFSFS wrong
# HW.> HW> d!JX&SFSFSFSFS wrong
# W:QOYIJM W-Q(WY/JM d!JX&SFSFSFSFS wrong
# B.:KOL B-KL/ d!JX&SFSFSFSFS wrong
# K.AC.@LEG K-(H-CLG/a d!JX&SFSFSFSFS wrong
# H@>OK:LIJM H->KL[/JM d!JX&SFSFSFSFS wrong
# W:X@CAB:T.@ W-XCB[T d!JX&SFSFSFSFS wrong
# >@JIN >JN/a d!JX&SFSFSFSFS wrong
# L:VAM.:>OW L-!!VM>[/d+W d!JX&SFSFSFSFS wrong
# L;>MOR L-!!>MR[/c d!JX&SFSFSFSFS wrong
# W:<@MAD W-<MD[ d!JX&SFSFSFSFS wrong
# HAM.IT:HAL.;L H-!M!](HT]HLL[/ d!JX&SFSFSFSFS wrong
# W.B:N;J W-BN/J d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# >:AROWM:MEK.@ !>!RWM&M[~(Nd+K d!JX&SFSFSFSFS wrong
# >IJC >JC/ d!JX&SFSFSFSFS wrong
# HIN.:K@H HN(H+K&H d!JX&SFSFSFSFS wrong
# L:M@R:V@H L-!!MRV[/H d!JX&SFSFSFSFS wrong
# KIC:MO<A K-!!CM<[/c d!JX&SFSFSFSFS wrong
# MIC.@M M(N-CM d!JX&SFSFSFSFS wrong
# HAM.ELEK: H-MLK/ d!JX&SFSFSFSFS wrong
# HAM.@JIM H-MJ(M/(JM d!JX&SFSFSFSFS wrong
# L:NAX:AMOW L-!!NXM[/d+W d!JX&SFSFSFSFS wrong
# B:J@M@J B-J(WM/J+(J d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# QOWL QWL/ d!JX&SFSFSFSFS wrong
# W.L:>@XOWT W-L->XW(T/Ta d!JX&SFSFSFSFS wrong
# Z:K@R !!ZKR[ d!JX&SFSFSFSFS wrong
# ZEH ZH d!JX&SFSFSFSFS wrong
# JA<AN J<N/ d!JX&SFSFSFSFS wrong
# G.OWJ GWJ/ d!JX&SFSFSFSFS wrong
# >;L.EH >LH d!JX&SFSFSFSFS wrong
# >@Z >Z d!JX&SFSFSFSFS wrong
# >OW >W d!JX&SFSFSFSFS wrong
# C@NIJM CN(H/JM d!JX&SFSFSFSFS wrong
# W:HAL:WIJ.IM W-H-LWJ/(JM d!JX&SFSFSFSFS wrong
# HAC.:TIJ H-CTJ/ d!JX&SFSFSFSFS wrong
# K.A>:ACER K->CR d!JX&SFSFSFSFS wrong
# MOW<;D MW<D/ d!JX&SFSFSFSFS wrong
# W.B@<IT.IJM W-B-(H-<T/JM d!JX&SFSFSFSFS wrong
# L@HEM L+HM d!JX&SFSFSFSFS wrong
# <OL@H <L(H/H d!JX&SFSFSFSFS wrong
# F@DEH FDH/a d!JX&SFSFSFSFS wrong
# HIJ> HJ> d!JX&SFSFSFSFS wrong
# JOY:>OWT JY>[/WT d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# C@MAJIM CMJ(M/(JM d!JX&SFSFSFSFS wrong
# L;>MOR L-!!>MR[/c d!JX&SFSFSFSFS wrong
# G.AM GM d!JX&SFSFSFSFS wrong
# W:<@FIJT@ W-<F(H&J[T d!JX&SFSFSFSFS wrong
# <;DIJM <D/JM d!JX&SFSFSFSFS wrong
# B.EN BN/c d!JX&SFSFSFSFS wrong
# JA<:ALW. !J!](H]<L(H[W d!JX&SFSFSFSFS wrong
# W.M;<AL W-M(N-<L d!JX&SFSFSFSFS wrong
# MIN.IJ MN&J d!JX&SFSFSFSFS wrong
# W:>;JN W->JN/c d!JX&SFSFSFSFS wrong
# J@L:DW. JLD[W d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# M;>:AXUZ.@TOW M(N->XZ(H/T+W d!JX&SFSFSFSFS wrong
# GAT GT/ d!JX&SFSFSFSFS wrong
# B.AK.OXA B-(H-KX/ d!JX&SFSFSFSFS wrong
# W:HIN.;H W-HNH d!JX&SFSFSFSFS wrong
# MIQ.;Y M(N-QY/ d!JX&SFSFSFSFS wrong
# H@R@H HR(H/H d!JX&SFSFSFSFS wrong
# W.M:ROWMAM W-!M!RWM&M[/duc d!JX&SFSFSFSFS wrong
# B.:B;JT B-BJT/c d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# B.EN BN/c d!JX&SFSFSFSFS wrong
# K;N KN d!JX&SFSFSFSFS wrong
# Q@D:RW. QDR[W d!JX&SFSFSFSFS wrong
# >AL:P.AJIM >LP/JM d!JX&SFSFSFSFS wrong
# HAK.OH;N H-KHN/ d!JX&SFSFSFSFS wrong
# W:N@K:RIJ W-NKRJ/ d!JX&SFSFSFSFS wrong
# WAJHW@H W-JHWH/ d!JX&SFSFSFSFS wrong
# >OW >W d!JX&SFSFSFSFS wrong
# COM:ROWN CMRWN/ d!JX&SFSFSFSFS wrong
# LOW L+W d!JX&SFSFSFSFS wrong
# WAJ:HAL:LW. W:n-!J!HLL[Wd d!JX&SFSFSFSFS wrong
# JOWC;B J&WCB[/ d!JX&SFSFSFSFS wrong
# WAJ:HIJ W:n-!J!HJ(H[ d!JX&SFSFSFSFS wrong
# H@<;YIJM H-<Y/JM d!JX&SFSFSFSFS wrong
# W:>ET W->T d!JX&SFSFSFSFS wrong
# JOC:B;J JCB[/J d!JX&SFSFSFSFS wrong
# W:XUQ.IJM W-XQ/JM d!JX&SFSFSFSFS wrong
# <:AWON <WN/c d!JX&SFSFSFSFS wrong
# JIH:JEH !J!HJH[ d!JX&SFSFSFSFS wrong
# L:MA<:L@H L-M<L/~H d!JX&SFSFSFSFS wrong
# >OHEL >HL/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# L@HEM L+HM d!JX&SFSFSFSFS wrong
# H@>@REY H->RY/a d!JX&SFSFSFSFS wrong
# >:ANIJ >NJ d!JX&SFSFSFSFS wrong
# N:TAT.IJK@ NT(N[TJ+K d!JX&SFSFSFSFS wrong
# MAL.IJNIJM !M!](H]L(W&JN[/JM d!JX&SFSFSFSFS wrong
# H@<;Y H-<Y/ d!JX&SFSFSFSFS wrong
# LIY:M@>@M L-YM>/+M d!JX&SFSFSFSFS wrong
# NAP:C:K@ NPC/+K d!JX&SFSFSFSFS wrong
# >AL >L d!JX&SFSFSFSFS wrong
# T.IF:B.A< !T!FB<[ d!JX&SFSFSFSFS wrong
# >@MAR >MR[ d!JX&SFSFSFSFS wrong
# WAJ.IT:P.OF W:n-!J!TPF[ d!JX&SFSFSFSFS wrong
# P.:<OWR P<WR/ d!JX&SFSFSFSFS wrong
# Z@JIT ZJT/a d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# HAS.W.S H-SWS/ d!JX&SFSFSFSFS wrong
# L:K@L L-KL/ d!JX&SFSFSFSFS wrong
# >@BIJW >B/~J+W d!JX&SFSFSFSFS wrong
# P.:N;J PN(H/J d!JX&SFSFSFSFS wrong
# LA<:AFOWT L-!!<F(H[/WT d!JX&SFSFSFSFS wrong
# >EX@D >XD/a d!JX&SFSFSFSFS wrong
# W:>;T W->T d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# WAJ.IQ:B.:RUHW. W:n-!J!QBR[(W+HW d!JX&SFSFSFSFS wrong
# J:HW.D@H JHWDH/ d!JX&SFSFSFSFS wrong
# W:L@GECET W-L-!!(NGC[/T d!JX&SFSFSFSFS wrong
# >AR:M:NOWTEJH@ >RM(WN/WTJ+H d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# HAJ.@MIJM H-J(WM/JM d!JX&SFSFSFSFS wrong
# W.B:N;J W-BN/J d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# W:N@T@N W-NTN/ d!JX&SFSFSFSFS wrong
# K.OL KL/ d!JX&SFSFSFSFS wrong
# M:>OD M>D/ d!JX&SFSFSFSFS wrong
# M;R;<;HW. M(N-R</+HW d!JX&SFSFSFSFS wrong
# X@K@M XKM/a d!JX&SFSFSFSFS wrong
# HAC.:LIJCIJ H-CLJCJ/ d!JX&SFSFSFSFS wrong
# D.OB:ROWT DBR(W(T/WT d!JX&SFSFSFSFS wrong
# C:B@> CB>/ d!JX&SFSFSFSFS wrong
# BO<AZ B<Z/ d!JX&SFSFSFSFS wrong
# FIJMW. !!FJM[W d!JX&SFSFSFSFS wrong
# T.IX:JEH !T!XJH[ d!JX&SFSFSFSFS wrong
# M;<@WEL M(N-<WL/a d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# MIB.@N@JW M(N-BN/J+W d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# W:<;JN@JW W-<JN/J+W d!JX&SFSFSFSFS wrong
# <:AY@TIJ <Y(H/T+J d!JX&SFSFSFSFS wrong
# KIN.IJM KN/JM d!JX&SFSFSFSFS wrong
# C:N;J CN(H/J d!JX&SFSFSFSFS wrong
# L.@K: L+K d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# L@MAD LMD[ d!JX&SFSFSFSFS wrong
# HOWYIJ> ]H](J&WY&J>[ d!JX&SFSFSFSFS wrong
# K.IB:KOR@TOW K-BKR(H/T+W d!JX&SFSFSFSFS wrong
# SOWR;R S&WRR[/ d!JX&SFSFSFSFS wrong
# B.;N BN/a d!JX&SFSFSFSFS wrong
# L:K@ L+K d!JX&SFSFSFSFS wrong
# J:KAX:ACW. !J!KXC[Wd d!JX&SFSFSFSFS wrong
# WAJ:KAL W:n-!J!KL(H[d d!JX&SFSFSFSFS wrong
# >AT.@H >TH d!JX&SFSFSFSFS wrong
# WAJ.@BO>W. W:n-!J!B(W>[W d!JX&SFSFSFSFS wrong
# >@XIJW >X/~J+W d!JX&SFSFSFSFS wrong
# W.BA<:ALIJLOWT@M W-B-<LJL(H/WT+M d!JX&SFSFSFSFS wrong
# MAL:>@K@JW ML>K/J+W d!JX&SFSFSFSFS wrong
# WIX:JW. W-!!XJ(H[W d!JX&SFSFSFSFS wrong
# B.OCW. B(WC[W d!JX&SFSFSFSFS wrong
# H;M.@H HMH d!JX&SFSFSFSFS wrong
# WAJ.IT:Q:<W. W:n-!J!TQ<[W d!JX&SFSFSFSFS wrong
# HAM.ELEK: H-MLK/ d!JX&SFSFSFSFS wrong
# H:ALOM HLM d!JX&SFSFSFSFS wrong
# HAZ.EH H-ZH d!JX&SFSFSFSFS wrong
# M:FAN:>IJ !M!FN>[/d+J d!JX&SFSFSFSFS wrong
# B@N@JW BN/J+W d!JX&SFSFSFSFS wrong
# H@>;POD H->PD/ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# >IM.IJ >M/+J d!JX&SFSFSFSFS wrong
# MIQ:D.@C:K@ MQDC/+K d!JX&SFSFSFSFS wrong
# L:BIN:J@MIJN L-BNJM&JN/ d!JX&SFSFSFSFS wrong
# W:ZIR:MAT W-ZRM(H/Tc d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# W.L:XOMOWT W-L-X(WM(H/WT d!JX&SFSFSFSFS wrong
# HAK.W.CIJ H-K&WCJ/ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# W:>IM:RW. W-!!>MR[W d!JX&SFSFSFSFS wrong
# >:ANIJ >NJ d!JX&SFSFSFSFS wrong
# B.:Y;L B-YL/ d!JX&SFSFSFSFS wrong
# W.P:DW.J;J W-PD&W(H&J[/J:p d!JX&SFSFSFSFS wrong
# HOWJ HWJ d!JX&SFSFSFSFS wrong
# T.A<:AFEH !T!<FH[ d!JX&SFSFSFSFS wrong
# W:HW.> W-HW> d!JX&SFSFSFSFS wrong
# >:AX;RIJM >XR/JM d!JX&SFSFSFSFS wrong
# W:>ET W->T d!JX&SFSFSFSFS wrong
# KAS:P.OW KSP/+W d!JX&SFSFSFSFS wrong
# B.:JOWM B-JWM/ d!JX&SFSFSFSFS wrong
# W:ZEH W-ZH d!JX&SFSFSFSFS wrong
# HAZ.EH H-ZH d!JX&SFSFSFSFS wrong
# <OWL@M <WLM/a d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# J:HW.D@H JHWDH/ d!JX&SFSFSFSFS wrong
# B.:KAP B-KP/ d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# <AD <D d!JX&SFSFSFSFS wrong
# W.C:PAV:J@HW. W-CPVJHW/ d!JX&SFSFSFSFS wrong
# B.;JT BJT/c d!JX&SFSFSFSFS wrong
# P.AX:D.@M PXD/+M d!JX&SFSFSFSFS wrong
# HIY.IJLW. ]H](NY&JL[W d!JX&SFSFSFSFS wrong
# MOCEH MCH/ d!JX&SFSFSFSFS wrong
# WAJ.IT.:NW. W:n-!J!(NTN[W d!JX&SFSFSFSFS wrong
# WAJ.;LEK: W:n-!J!(HLK[ d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# B.:>;R B>R/ d!JX&SFSFSFSFS wrong
# WAJ.IC:LAX W:n-!J!CLX[ d!JX&SFSFSFSFS wrong
# W:J@RAD W-JRD[ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# G.:N@BW.K@ GNB[W+K d!JX&SFSFSFSFS wrong
# B.AL BL d!JX&SFSFSFSFS wrong
# G@D GD/ d!JX&SFSFSFSFS wrong
# HAP.ESEL H-PSL/ d!JX&SFSFSFSFS wrong
# C@XAV CXV[ d!JX&SFSFSFSFS wrong
# JIC:<IJ JC</+J d!JX&SFSFSFSFS wrong
# R;JX;NW. RJX/+NW d!JX&SFSFSFSFS wrong
# J.@Q@R JQR/a d!JX&SFSFSFSFS wrong
# YO>NOW Y>N/+W d!JX&SFSFSFSFS wrong
# J:Q@R JQR/ d!JX&SFSFSFSFS wrong
# HOMIJ.OWT HM(H&J[/WT d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# J@MIJN JMJN/a d!JX&SFSFSFSFS wrong
# HAF.@DEH H-FDH/a d!JX&SFSFSFSFS wrong
# P.:LIC:T.IJM PLCT(J/JM d!JX&SFSFSFSFS wrong
# SIJXON SJX(WN/ d!JX&SFSFSFSFS wrong
# K.OH;N KHN/ d!JX&SFSFSFSFS wrong
# B.;JT BJT/c d!JX&SFSFSFSFS wrong
# W:>@NOKIJ W->NKJ d!JX&SFSFSFSFS wrong
# W:CAX:AVW. W-!!CXV[W d!JX&SFSFSFSFS wrong
# B@> B(W>[ d!JX&SFSFSFSFS wrong
# FAR:<AP.AJ FR<P(J(M/J+(J d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# L:HIT:<AL.;M L-!!]HT]<LM[/ d!JX&SFSFSFSFS wrong
# <@F@H <FH[ d!JX&SFSFSFSFS wrong
# WAT.IC:QOV W:n-!T!CQV[ d!JX&SFSFSFSFS wrong
# B.:N;J BN/J d!JX&SFSFSFSFS wrong
# J:HOWC@P@V JHWCPV/ d!JX&SFSFSFSFS wrong
# WAJ:HIJ W:n-!J!HJ(H[ d!JX&SFSFSFSFS wrong
# >@D@M >DM/ d!JX&SFSFSFSFS wrong
# C:N@TOW CN(H/T+W d!JX&SFSFSFSFS wrong
# W:>;T W->T d!JX&SFSFSFSFS wrong
# L:P@NEJK@ L-PN(H/J+K d!JX&SFSFSFSFS wrong
# BAY:LW.T BYLWT/ d!JX&SFSFSFSFS wrong
# HAB.@K@> H-BK>/a d!JX&SFSFSFSFS wrong
# YIW.IJT@H YW(H&J[T&Hd d!JX&SFSFSFSFS wrong
# L;>MOR L-!!>MR[/c d!JX&SFSFSFSFS wrong
# P.@N@JW PN(H/J+W d!JX&SFSFSFSFS wrong
# HAK.OH;N H-KHN/ d!JX&SFSFSFSFS wrong
# JIK.@R;T !J!](N]KRT[ d!JX&SFSFSFSFS wrong
# RO<A R</ d!JX&SFSFSFSFS wrong
# WAJ.;Y;> W:n-!J!(JY>[ d!JX&SFSFSFSFS wrong
# WAJ.O>MER W:n-!J!>MR[ d!JX&SFSFSFSFS wrong
# H:ALOH H-L(>&H d!JX&SFSFSFSFS wrong
# HIN:XIJT@M ]H]NX(H&J[T+M d!JX&SFSFSFSFS wrong
# G.@DOWL GDWL/a d!JX&SFSFSFSFS wrong
# JIM.@L:>W. !J!](N]ML>[W d!JX&SFSFSFSFS wrong
# >AR:G.@M@N >RGMN/ d!JX&SFSFSFSFS wrong
# H@>@REY H->RY/a d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# W:R@>@H W-R>H[ d!JX&SFSFSFSFS wrong
# W:FAM:T.IJM W-F(JM[TJ+M d!JX&SFSFSFSFS wrong
# W:>ET W->T d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# W:HAL:WIJ.IM W-H-LWJ/(JM d!JX&SFSFSFSFS wrong
# JIC:K.@BW. !J!CKB[W d!JX&SFSFSFSFS wrong
# >@N@H >N&H d!JX&SFSFSFSFS wrong
# T.OWSIP !T!](H](J&WSP[ d!JX&SFSFSFSFS wrong
# HAG.@DOWL H-GDWL/a d!JX&SFSFSFSFS wrong
# CA>:AG@TOW C>G(H/T+W d!JX&SFSFSFSFS wrong
# HAD.:B@RIJM H-DBR/JM d!JX&SFSFSFSFS wrong
# W:GAM W-GM d!JX&SFSFSFSFS wrong
# M;>EREY M(N->RY/ d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# H@>:EMORIJ H->MRJ/ d!JX&SFSFSFSFS wrong
# MAJIM MJ(M/(JM d!JX&SFSFSFSFS wrong
# HAY.O>N H-Y>N/ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# K.OH KH d!JX&SFSFSFSFS wrong
# <ED:J@M <DJ/+M d!JX&SFSFSFSFS wrong
# G.AM GM d!JX&SFSFSFSFS wrong
# >AL >L d!JX&SFSFSFSFS wrong
# R@< R</a d!JX&SFSFSFSFS wrong
# P.:LIC:T.IJM PLCT(J/JM d!JX&SFSFSFSFS wrong
# ZEH ZH d!JX&SFSFSFSFS wrong
# W.B:RA<AC W-B-R<C/ d!JX&SFSFSFSFS wrong
# P.:R@T PRT/ d!JX&SFSFSFSFS wrong
# NID.@H ND(H/H d!JX&SFSFSFSFS wrong
# <IM.OW <M+W d!JX&SFSFSFSFS wrong
# G.A<:ARAT G<R(H/Tc d!JX&SFSFSFSFS wrong
# T.A<:AFEH !T!<FH[ d!JX&SFSFSFSFS wrong
# N@CIJM (>&NC(H/JM d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# >AR:B.@<IJM >RB</JM d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# WAJ.A<AF W:n-!J!<F(H[ d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# B.A<AL B<L/ d!JX&SFSFSFSFS wrong
# B.AK.AR:MEL B-(H-KRML/ d!JX&SFSFSFSFS wrong
# T.W.CIJ.@H TWCJ(H/H d!JX&SFSFSFSFS wrong
# COM:ROWN CMRWN/ d!JX&SFSFSFSFS wrong
# X@NW.N XNWN/ d!JX&SFSFSFSFS wrong
# MIQ.IR:B.OW M(N-QRB/+W d!JX&SFSFSFSFS wrong
# QOWM@H QWM(H/H d!JX&SFSFSFSFS wrong
# JO>KAL !J!>KL[ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# H@R@<IJM H-R</JM d!JX&SFSFSFSFS wrong
# JAC.IJ>W. !J!](H](NC&J>[W d!JX&SFSFSFSFS wrong
# <AM <M/ d!JX&SFSFSFSFS wrong
# G@ZW.L GZ&WL[/:pa d!JX&SFSFSFSFS wrong
# NAP:CIJ NPC/+J d!JX&SFSFSFSFS wrong
# YAD.IJQ YDJQ/ d!JX&SFSFSFSFS wrong
# LA>DONEJH@ L->D(WN/J+H d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# H@R:GW. HRG[W d!JX&SFSFSFSFS wrong
# X:AQOR !!XQR[/c d!JX&SFSFSFSFS wrong
# K.OH;N KHN/ d!JX&SFSFSFSFS wrong
# G.:BW.R@TIJ GBWR(H/T+J d!JX&SFSFSFSFS wrong
# B@HEM B+HM d!JX&SFSFSFSFS wrong
# <AD <D d!JX&SFSFSFSFS wrong
# N@CIJM (>&NC(H/JM d!JX&SFSFSFSFS wrong
# B.;JT BJT/c d!JX&SFSFSFSFS wrong
# LIB:NIJ L-BN/+J d!JX&SFSFSFSFS wrong
# NIT:P.AF:T.: ]N]TPF[T d!JX&SFSFSFSFS wrong
# >:ANIJ >NJ d!JX&SFSFSFSFS wrong
# W:>;JN W->JN/c d!JX&SFSFSFSFS wrong
# LA<:AFOT L-!!<F(H[/(WT d!JX&SFSFSFSFS wrong
# B.@>AM.@H B-(H->M(H/H d!JX&SFSFSFSFS wrong
# XEREB XRB/ d!JX&SFSFSFSFS wrong
# <:ALOWT !!<L(H[/WT d!JX&SFSFSFSFS wrong
# W:<EFER W-<FR/ d!JX&SFSFSFSFS wrong
# D.IB.ER DBR[d d!JX&SFSFSFSFS wrong
# NAP:COW NPC/+W d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# C;M CM/ d!JX&SFSFSFSFS wrong
# X@ZOWN XZWN/a d!JX&SFSFSFSFS wrong
# R@>IJNW. R>(H&J[NW d!JX&SFSFSFSFS wrong
# M;<AL M(N-<L d!JX&SFSFSFSFS wrong
# K.:SW.T KSWT/ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# H@>@REY H->RY/a d!JX&SFSFSFSFS wrong
# Q@DOWC QDWC/a d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# >OW >W d!JX&SFSFSFSFS wrong
# HIN.;H HNH d!JX&SFSFSFSFS wrong
# CEBA< CB</a d!JX&SFSFSFSFS wrong
# P.IL.AL:T.: PLL[Td d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# >;JN >JN/c d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# L:RO>C L-R>C/ d!JX&SFSFSFSFS wrong
# K.OH KH d!JX&SFSFSFSFS wrong
# HAB.AJIT H-BJT/a d!JX&SFSFSFSFS wrong
# C@LEP CLP/ d!JX&SFSFSFSFS wrong
# HAD.:B@RIJM H-DBR/JM d!JX&SFSFSFSFS wrong
# KAD.@T K-(H-DT/ d!JX&SFSFSFSFS wrong
# T.:N;HW. !!(NTN[+HW d!JX&SFSFSFSFS wrong
# K.OH KH d!JX&SFSFSFSFS wrong
# WAJ.A<AF W:n-!J!<F(H[ d!JX&SFSFSFSFS wrong
# HAC.:LOCIJM H-CLC/JM d!JX&SFSFSFSFS wrong
# NEG:D.OW NGD/+W d!JX&SFSFSFSFS wrong
# LA<:AFOWT L-!!<F(H[/WT d!JX&SFSFSFSFS wrong
# >@NIJ >NJ d!JX&SFSFSFSFS wrong
# <AD <D d!JX&SFSFSFSFS wrong
# >;L.EH >LH d!JX&SFSFSFSFS wrong
# T.:HIJ !T!HJ(H[ d!JX&SFSFSFSFS wrong
# M:NAC.EH MNCH/ d!JX&SFSFSFSFS wrong
# >OT@M >T+M d!JX&SFSFSFSFS wrong
# B.@HEM B+HM d!JX&SFSFSFSFS wrong
# >AP.IJL !>!](H](NP&JL[ d!JX&SFSFSFSFS wrong
# <OD <(WD/ d!JX&SFSFSFSFS wrong
# W:H@J@H W-HJH[ d!JX&SFSFSFSFS wrong
# <OLOWT <L(H/WT d!JX&SFSFSFSFS wrong
# B.AB.OQER B-(H-BQR/ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# JIX:JEH !J!XJH[ d!JX&SFSFSFSFS wrong
# HIL.AL:NW. HLL[NWd d!JX&SFSFSFSFS wrong
# T.IP:>@R@H TP>R(H/H d!JX&SFSFSFSFS wrong
# LIC:M@M@H L-CMM(H/H d!JX&SFSFSFSFS wrong
# X@RW.Y XRWY/ d!JX&SFSFSFSFS wrong
# W:<OLAT W-<L(H/Tc d!JX&SFSFSFSFS wrong
# B.:>EG:ROP B->GRP/ d!JX&SFSFSFSFS wrong
# W.B:MOWR@>IJM W-B-MWR>/JM d!JX&SFSFSFSFS wrong
# >;JDOW >JD/+W d!JX&SFSFSFSFS wrong
# W:J;C W-JC/ d!JX&SFSFSFSFS wrong
# WIJHOWZ@B@D W-JHWZBD/ d!JX&SFSFSFSFS wrong
# WAJ.IT:P.AL.;L W:n-!J!](HT]PLL[ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# HAC.@MAJIM H-CMJ(M/(JM d!JX&SFSFSFSFS wrong
# LOW L+W d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# J:M;J J(WM/J d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# W:CIC.@H W-CC/H d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# MIM.EN.W. M(N&M&N+(HW d!JX&SFSFSFSFS wrong
# >:ELOH;J >LH(J(M/J d!JX&SFSFSFSFS wrong
# HAG.OWJIM H-GWJ/(JM d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# >EF.@> !>!(NF>[ d!JX&SFSFSFSFS wrong
# T.IM:XEH !T!MXH[ d!JX&SFSFSFSFS wrong
# H@>EX@D H->XD/a d!JX&SFSFSFSFS wrong
# MID:J@N MDJN/ d!JX&SFSFSFSFS wrong
# XAL.OWTIJ !!XL(H[/WTd+J d!JX&SFSFSFSFS wrong
# HOWLIJD ]H](J&WL&JD[ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# G.ID.:LOW GDL[d+W d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# CILOH CLH/ d!JX&SFSFSFSFS wrong
# JIM.@Y;> !J!](N]MY>[ d!JX&SFSFSFSFS wrong
# >:ELOH;J >LH(J(M/J d!JX&SFSFSFSFS wrong
# ZAR:<:AKEM ZR</+KM d!JX&SFSFSFSFS wrong
# LOW L+W d!JX&SFSFSFSFS wrong
# HW.> HW> d!JX&SFSFSFSFS wrong
# M:YAW.:K@ !M!YW(H[/d+K d!JX&SFSFSFSFS wrong
# S@BIJB SBJB/a d!JX&SFSFSFSFS wrong
# MIJ.IF:R@>;L M(N-JFR>L/ d!JX&SFSFSFSFS wrong
# MA<:AF;H M<FH/c d!JX&SFSFSFSFS wrong
# NUS:K@ !!N(WS[/+K d!JX&SFSFSFSFS wrong
# C@M:<@H CM<[H d!JX&SFSFSFSFS wrong
# L:R@<@H L-R<(H/H d!JX&SFSFSFSFS wrong
# J;HW.> JHW>/ d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# >@CW.B !>!CWB[ d!JX&SFSFSFSFS wrong
# MIN MN d!JX&SFSFSFSFS wrong
# M;>OWT M>(H/WTa d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# J@R@B:<@M JRB<M/ d!JX&SFSFSFSFS wrong
# C:N;JM CN(J(M/JM d!JX&SFSFSFSFS wrong
# Y@B@> YB>/a d!JX&SFSFSFSFS wrong
# NIS:ROK: NSRK/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# B.:HA<:AWOTOW B-!!]H]<W(H[/(WT+W d!JX&SFSFSFSFS wrong
# J:HW.D@H JHWDH/ d!JX&SFSFSFSFS wrong
# B.AJ.OWM B-(H-JWM/ d!JX&SFSFSFSFS wrong
# WAJ.O>MAR W:n-!J!>MR[ d!JX&SFSFSFSFS wrong
# WAJ.@BO>W. W:n-!J!B(W>[W d!JX&SFSFSFSFS wrong
# MIN MN d!JX&SFSFSFSFS wrong
# M;>OWT M>(H/WTa d!JX&SFSFSFSFS wrong
# MIP.:N;J M(N-PN(H/J d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# J:RIJXW.N !J!](H]R(W&JX[WN d!JX&SFSFSFSFS wrong
# >IC:T.OW >C(H/T+W d!JX&SFSFSFSFS wrong
# HIG.@JOWN HGJWN/a d!JX&SFSFSFSFS wrong
# >@MAR >MR[ d!JX&SFSFSFSFS wrong
# WAJ.@C@B W:n-!J!C(WB[ d!JX&SFSFSFSFS wrong
# W:NIQ:D.AC:T.IJ W-]N]QDC[TJ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# MIS.:BIJBOWT@M M(N-SBJB/WT+M d!JX&SFSFSFSFS wrong
# HE<@N@N H-<NN/a d!JX&SFSFSFSFS wrong
# L;K: !!(HLK[ d!JX&SFSFSFSFS wrong
# HAB.:<@LIJM H-B<L/JM d!JX&SFSFSFSFS wrong
# T.IP:>@RET TP>R(T/Ta d!JX&SFSFSFSFS wrong
# >EREY >RY/ d!JX&SFSFSFSFS wrong
# W:K@L W-KL/ d!JX&SFSFSFSFS wrong
# K.@>AR:G.@M@N K-(H->RGMN/ d!JX&SFSFSFSFS wrong
# W:N@TAT.IJ W-NT(N[TJ d!JX&SFSFSFSFS wrong
# H@>:ELOHIJM H->LH(J(M/JM d!JX&SFSFSFSFS wrong
# B.:<;JN;J B-<JN/J d!JX&SFSFSFSFS wrong
# M:>AH:ABEJH@ !M!>HB[/Jd+H d!JX&SFSFSFSFS wrong
# B.O>:AK@H !!B(W>[/+K&H d!JX&SFSFSFSFS wrong
# B.IJ B+J d!JX&SFSFSFSFS wrong
# T.OWL:DOT TWLD(W(T/(WT d!JX&SFSFSFSFS wrong
# H@RA< H-R</ d!JX&SFSFSFSFS wrong
# D.:BAR DBR/c d!JX&SFSFSFSFS wrong
# HAM.ELEK: H-MLK/ d!JX&SFSFSFSFS wrong
# RO>C R>C/ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# B.:N;J BN/J d!JX&SFSFSFSFS wrong
# >OW >W d!JX&SFSFSFSFS wrong
# TO>K:LW. !T!>KL[W d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# W:<EF:RIJM W-<FR(J(M/JM d!JX&SFSFSFSFS wrong
# L:KW. !!(HLK[W d!JX&SFSFSFSFS wrong
# ZIPIJM Z(JP(J/JM d!JX&SFSFSFSFS wrong
# HAJ.@M H-JM/ d!JX&SFSFSFSFS wrong
# C@N@H CN(H/H d!JX&SFSFSFSFS wrong
# >;LAJ >L&J+(J d!JX&SFSFSFSFS wrong
# NEX:EZAQ !N!XZQ[ d!JX&SFSFSFSFS wrong
# B.:QW.M B-!!QWM[/c d!JX&SFSFSFSFS wrong
# CIL:X@H !!CLX[H d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# XAG.AJ XGJ/ d!JX&SFSFSFSFS wrong
# W:>;T W->T d!JX&SFSFSFSFS wrong
# M:RIJM@JW !M!](H]R(W&JM[/J+W d!JX&SFSFSFSFS wrong
# >;L >L/ d!JX&SFSFSFSFS wrong
# >:AB@NIJM >BN/JM d!JX&SFSFSFSFS wrong
# >AR:B.@<IJM >RB</JM d!JX&SFSFSFSFS wrong
# WAJ.O>MER W:n-!J!>MR[ d!JX&SFSFSFSFS wrong
# J@Y@>W. JY>[W d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# H@R;J HR/J d!JX&SFSFSFSFS wrong
# Q@R;XA QRX/ d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# Q:YIJR:K@ QYJR/+K d!JX&SFSFSFSFS wrong
# HAG.EPEN H-GPN/ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# HAK.IS.;> H-KS>/ d!JX&SFSFSFSFS wrong
# M:C@R:TOW !M!CRT[/d+W d!JX&SFSFSFSFS wrong
# T.IJR@>W.M !T!JR>[W+M d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# JIP:T.@X JPTX/ d!JX&SFSFSFSFS wrong
# HOWLIJD ]H](J&WL&JD[ d!JX&SFSFSFSFS wrong
# H@>@REY H->RY/a d!JX&SFSFSFSFS wrong
# W.MOWR@H W-MWR(H/H d!JX&SFSFSFSFS wrong
# CIL:XW. !!CLX[W d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# J:HIJ !J!HJ(H[ d!JX&SFSFSFSFS wrong
# K@L;B KLB/ d!JX&SFSFSFSFS wrong
# W:<EREL W-<RL/c d!JX&SFSFSFSFS wrong
# B.IL:B@B;K: B-LBB/+K d!JX&SFSFSFSFS wrong
# L:HIL.@XEM L-!H!](N]LXM[/c d!JX&SFSFSFSFS wrong
# C@Q;H CQH/ d!JX&SFSFSFSFS wrong
# J:HW.D@H JHWDH/ d!JX&SFSFSFSFS wrong
# HAM.ELEK: H-MLK/ d!JX&SFSFSFSFS wrong
# W@L@D WLD/ d!JX&SFSFSFSFS wrong
# W:<AB:D.:K@ W-<BD/+K d!JX&SFSFSFSFS wrong
# W.L:JO>@B W-L-J(W>B/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# >:ADON@J >DNJ/ d!JX&SFSFSFSFS wrong
# DIB.@H DB(H/H d!JX&SFSFSFSFS wrong
# >;L@JW >L&J+W d!JX&SFSFSFSFS wrong
# W:>AXAR W->XR/ d!JX&SFSFSFSFS wrong
# W:<AT.@H W-<TH d!JX&SFSFSFSFS wrong
# M;J M(J(M/J d!JX&SFSFSFSFS wrong
# HAL:LW.HW. !!HLL[Wd+HW d!JX&SFSFSFSFS wrong
# NEPEC NPC/ d!JX&SFSFSFSFS wrong
# H@<;Y H-<Y/ d!JX&SFSFSFSFS wrong
# MIM:S@K: MMSK/ d!JX&SFSFSFSFS wrong
# W:KIT.AT W-KTT[d d!JX&SFSFSFSFS wrong
# Y:B@> YB>/c d!JX&SFSFSFSFS wrong
# H@L:KW. HLK[W d!JX&SFSFSFSFS wrong
# H;M HM d!JX&SFSFSFSFS wrong
# J@DOW JD/+W d!JX&SFSFSFSFS wrong
# >;LIJ.@HW. >LJHW/ d!JX&SFSFSFSFS wrong
# >AT.@H >TH d!JX&SFSFSFSFS wrong
# YID:QIJ.@H YDQJH/ d!JX&SFSFSFSFS wrong
# F:RIJD;J FRJD/J d!JX&SFSFSFSFS wrong
# W:<AT.@H W-<TH d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# P.EQAX PQX/ d!JX&SFSFSFSFS wrong
# L:PIJ L-P(H&J/c d!JX&SFSFSFSFS wrong
# B.AC.IC.IJ B-(H-CCJ/ d!JX&SFSFSFSFS wrong
# LAJHW@H L-JHWH/ d!JX&SFSFSFSFS wrong
# WAT.:FIM;M W:n-!T!F(JM[+M d!JX&SFSFSFSFS wrong
# MIL:X@M@H MLXM(H/H d!JX&SFSFSFSFS wrong
# >AB:N;R >BNR/ d!JX&SFSFSFSFS wrong
# T.OS;P !T!(>SP[ d!JX&SFSFSFSFS wrong
# >AT.@H >TH d!JX&SFSFSFSFS wrong
# M:DIJN@H MDJN(H/H d!JX&SFSFSFSFS wrong
# N;R NR/ d!JX&SFSFSFSFS wrong
# >AT.@H >TH d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# <OFIJM <F(H[/JM d!JX&SFSFSFSFS wrong
# <IM.IJ <M+J d!JX&SFSFSFSFS wrong
# WAJ.IT.EN W:n-!J!(NTN[ d!JX&SFSFSFSFS wrong
# LIC:LOMOH L-CLMH/ d!JX&SFSFSFSFS wrong
# <ER:K.:K@ <RK/+K d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# <:AZAR:J@H <ZRJH/ d!JX&SFSFSFSFS wrong
# BEKEH BKH/ d!JX&SFSFSFSFS wrong
# WAJ.AQ.AP W:n-!J!](H](NQP[ d!JX&SFSFSFSFS wrong
# B.AS.W.SIJM B-(H-SWS/JM d!JX&SFSFSFSFS wrong
# B.:G;J> B-GJ>/c d!JX&SFSFSFSFS wrong
# LIB.@M LB/+M d!JX&SFSFSFSFS wrong
# HAL.IC:K.@H H-LCK(H/H d!JX&SFSFSFSFS wrong
# XER:P.@TOW XRP(H/T+W d!JX&SFSFSFSFS wrong
# K.IK.@RIJM KKR/JM d!JX&SFSFSFSFS wrong
# W:R;>CIJT W-R>CJT/ d!JX&SFSFSFSFS wrong
# W:>;JN W->JN/c d!JX&SFSFSFSFS wrong
# X:AZ@Q@H XZQ/H d!JX&SFSFSFSFS wrong
# WAT.IR:XAQ W:n-!T!RXQ[ d!JX&SFSFSFSFS wrong
# X@K:M@H XKM(H/H d!JX&SFSFSFSFS wrong
# L:BIL:T.IJ L-BLT/~J d!JX&SFSFSFSFS wrong
# S;PER SPR/ d!JX&SFSFSFSFS wrong
# WAJ.IQ:R@> W:n-!J!QR>[ d!JX&SFSFSFSFS wrong
# W:>ET W->T d!JX&SFSFSFSFS wrong
# >ID.@R;C !>!](N]DRC[ d!JX&SFSFSFSFS wrong
# LIP:N;J L-PN(H/J d!JX&SFSFSFSFS wrong
# HAM.O>:ABIJ.@H H-M(W>BJ/H d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# B.:JED:KEM B-JD/+KM d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# >:ELOHEJH@ >LH(J(M/J+H d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# G.AM GM d!JX&SFSFSFSFS wrong
# W:CW.BW. W-!!CWB[W d!JX&SFSFSFSFS wrong
# TAX:T.@JW TXT/J+W d!JX&SFSFSFSFS wrong
# T.IT.;N !T!(NTN[ d!JX&SFSFSFSFS wrong
# C:T.;J C(N(J(M/TJ d!JX&SFSFSFSFS wrong
# MIM.A<:AF;NW. M(N-M<F(H/+NW d!JX&SFSFSFSFS wrong
# W:>ET W->T d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# ZEH ZH d!JX&SFSFSFSFS wrong
# JIS:<W. !J!(NS<[W d!JX&SFSFSFSFS wrong
# LIZ:Q;N@JW L-ZQN/J+W d!JX&SFSFSFSFS wrong
# X@BER XBR/a d!JX&SFSFSFSFS wrong
# <;Y <Y/ d!JX&SFSFSFSFS wrong
# B.IF:K@ROW B-FKR/+W d!JX&SFSFSFSFS wrong
# H;M HM d!JX&SFSFSFSFS wrong
# JIY:H@R JYHR/ d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# C:T.AJIM C(N(J(M/TJM d!JX&SFSFSFSFS wrong
# NAX:AL@TIJ NXL(H/T+J d!JX&SFSFSFSFS wrong
# B.:N;JKEM BN/J+KM d!JX&SFSFSFSFS wrong
# G.;R@H GR(H/H d!JX&SFSFSFSFS wrong
# >:ELOHIJM >LH(J(M/JM d!JX&SFSFSFSFS wrong
# <:AL;JKEM <L&J+KM d!JX&SFSFSFSFS wrong
# W:>AR:B.@<@H W->RB</H d!JX&SFSFSFSFS wrong
# L:K@L L-KL/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# C:XIJN CXJN/ d!JX&SFSFSFSFS wrong
# N:KOW NKW/ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# TIT.;N !T!(NTN[ d!JX&SFSFSFSFS wrong
# H@>;LONIJ H->LNJ/ d!JX&SFSFSFSFS wrong
# B.:BA<AL B-B<L d!JX&SFSFSFSFS wrong
# <AD <D d!JX&SFSFSFSFS wrong
# CIK:BIJ !!CKB[J d!JX&SFSFSFSFS wrong
# L:BAB:KEM LBB/+KM d!JX&SFSFSFSFS wrong
# B:N;K: BN/+K d!JX&SFSFSFSFS wrong
# JOW<IJL !J!](H](J&W<&JL[ d!JX&SFSFSFSFS wrong
# G.OCEN GCN/ d!JX&SFSFSFSFS wrong
# L:P@NEJK@ L-PN(H/J+K d!JX&SFSFSFSFS wrong
# K.@L;B KLB/ d!JX&SFSFSFSFS wrong
# MAT.AT MTT/ d!JX&SFSFSFSFS wrong
# <@M;L <ML/a d!JX&SFSFSFSFS wrong
# ...
# W:K@L W-KL/ d!JX&SFSFSFSFS wrong
# >:ANAX:NW. >NXNW d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# C:MA< !!CM<[ d!JX&SFSFSFSFS wrong
# HAJ:RIJ<@H H-JRJ<(H/H d!JX&SFSFSFSFS wrong
# W:<@M@L W-<ML/ d!JX&SFSFSFSFS wrong
# MIC:P.@VIJ MCPV/+J d!JX&SFSFSFSFS wrong
# H@>:ELOHIJM H->LH(J(M/JM d!JX&SFSFSFSFS wrong
# H@<;D@H H-<D(H/H d!JX&SFSFSFSFS wrong
# J:HW.D@H JHWDH/ d!JX&SFSFSFSFS wrong
# HAM.IL:X@M@H H-MLXM(H/H d!JX&SFSFSFSFS wrong
# C@LW.XA CL&WX[/:pa d!JX&SFSFSFSFS wrong
# >:AL;JHEM >L&J+HM d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# Y:BO<IJM YB<JM/ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# T.:HIJ !T!HJ(H[ d!JX&SFSFSFSFS wrong
# W.B;JN W-BJN/c d!JX&SFSFSFSFS wrong
# JAC:LIJKW. !J!](H]CL&JK[W d!JX&SFSFSFSFS wrong
# L:BEN L-BN/c d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# L:HIP.@Q;D L-!H!](N]PQD[/c d!JX&SFSFSFSFS wrong
# J@DA<:T.IJ JD<[TJ d!JX&SFSFSFSFS wrong
# D.@W@H DW(H/H d!JX&SFSFSFSFS wrong
# MA<:AF;HW. M<F(H/+HW d!JX&SFSFSFSFS wrong
# >AD:MOWNIJ >DM&WNJ/ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# C:T.;J C(N(J(M/TJ d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# JIK.@R;T !J!](N]KRT[ d!JX&SFSFSFSFS wrong
# LIP:N;J L-PN(H/J d!JX&SFSFSFSFS wrong
# WAT.:HIJ W:n-!T!HJ(H[ d!JX&SFSFSFSFS wrong
# H@J:T@H HJ(H[&TH d!JX&SFSFSFSFS wrong
# <;F@W <FW/ d!JX&SFSFSFSFS wrong
# L:MIC:MERET L-MCMR(T/T d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# HAZ.O>T H-Z>T d!JX&SFSFSFSFS wrong
# X:AM;C XMC/c d!JX&SFSFSFSFS wrong
# Q@R:X@H QRX(H/H d!JX&SFSFSFSFS wrong
# >IJC >JC/ d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# W:QOWM@H W-QWM(H/H d!JX&SFSFSFSFS wrong
# W:>;T W->T d!JX&SFSFSFSFS wrong
# MIQ:D.@CIJ MQDC/+J d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# >AX:AR;J >XR/J d!JX&SFSFSFSFS wrong
# >@D@M >DM/ d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# XEM:D.@N XMDN/ d!JX&SFSFSFSFS wrong
# LIC:P.OV L-!!CPV[/c d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# W@VOPAX W-VPX/ d!JX&SFSFSFSFS wrong
# T.OWC@B TWCB/a d!JX&SFSFSFSFS wrong
# BAR:QOWS BRQWS/ d!JX&SFSFSFSFS wrong
# B:NOW BN/+W d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# W.B:B;JT W-B-BJT/c d!JX&SFSFSFSFS wrong
# JIC:T.AX:AWEH !J!](HCT]XWH[ d!JX&SFSFSFSFS wrong
# HAZ.@B H-Z(WB[/ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# W:YAD.IJQ W-YDJQ/ d!JX&SFSFSFSFS wrong
# TO>K;LW. !T!>KL[W d!JX&SFSFSFSFS wrong
# >AB.IJV !>!](H](NB&JV[ d!JX&SFSFSFSFS wrong
# L@FW.M L-!!F(J&WM[/c d!JX&SFSFSFSFS wrong
# >IT.IJ >T+J d!JX&SFSFSFSFS wrong
# MAC:B.IJR !M!](H]CB&JR[/ d!JX&SFSFSFSFS wrong
# M:ROWRAT MR&WR(H/Tc d!JX&SFSFSFSFS wrong
# W@XAJ W-XJ(H[ d!JX&SFSFSFSFS wrong
# W:ZIQ:N;J W-ZQN/J d!JX&SFSFSFSFS wrong
# B.;JTOW BJT/+W d!JX&SFSFSFSFS wrong
# L:<OWL@M L-<WLM/a d!JX&SFSFSFSFS wrong
# W.B:XAL.:LOW W-B-!!XLL[/d+W d!JX&SFSFSFSFS wrong
# >AC:R;J >CR/J d!JX&SFSFSFSFS wrong
# M;>;T M(N->T d!JX&SFSFSFSFS wrong
# RIB:Q@H RBQH/ d!JX&SFSFSFSFS wrong
# J@D@< JD<[ d!JX&SFSFSFSFS wrong
# J:SUB.@KW. !J!SBK[Wdu d!JX&SFSFSFSFS wrong
# WAJ.IC:MA< W:n-!J!CM<[ d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# G.OWR@L GWRL/a d!JX&SFSFSFSFS wrong
# >AR:G.OB >RGB/ d!JX&SFSFSFSFS wrong
# JIG.@LEH !J!](N]GLH[ d!JX&SFSFSFSFS wrong
# >AD:M@T:K@ >DM(H/T+K d!JX&SFSFSFSFS wrong
# BAJ.OWM B-(H-JWM/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# SAX:R@H. SXR/+H d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# MIS.@BIJB M(N-SBJB/a d!JX&SFSFSFSFS wrong
# >ES:T.;R >STR/ d!JX&SFSFSFSFS wrong
# WAJ.@CW.BW. W:n-!J!CWB[W d!JX&SFSFSFSFS wrong
# W.BIN:K@ W-BN/+K d!JX&SFSFSFSFS wrong
# M;>EREY M(N->RY/ d!JX&SFSFSFSFS wrong
# W:NEPEC W-NPC/ d!JX&SFSFSFSFS wrong
# M:DAB.;R !M!DBR[/d d!JX&SFSFSFSFS wrong
# LA<:ABOD L-!!<BD[/c d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# <ED:ROW <DR/+W d!JX&SFSFSFSFS wrong
# LAXODEC L-(H-XDC/ d!JX&SFSFSFSFS wrong
# HAZ.EH H-ZH d!JX&SFSFSFSFS wrong
# K.:MAL:>AK: K-ML>K/c d!JX&SFSFSFSFS wrong
# >:EDOWM >DWM/ d!JX&SFSFSFSFS wrong
# WAJ.AR:> W:n-!J!R>(H[ d!JX&SFSFSFSFS wrong
# JIX:JEH !J!XJH[ d!JX&SFSFSFSFS wrong
# N.@> N> d!JX&SFSFSFSFS wrong
# LAC.@W:> L-(H-CW>/ d!JX&SFSFSFSFS wrong
# HIQ.IJPW. ]H](NQ&JP[W d!JX&SFSFSFSFS wrong
# RAB.IJM RB/JM d!JX&SFSFSFSFS wrong
# W:XAN:P;J W-XNP/J d!JX&SFSFSFSFS wrong
# B.:ROXAB B-RXB/ d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# >AM.OWT >M(H/WT d!JX&SFSFSFSFS wrong
# HUG.AD ]H](NGD[:u d!JX&SFSFSFSFS wrong
# >:ADON@J >DNJ/ d!JX&SFSFSFSFS wrong
# WAJ.AX:ANW. W:n-!J!XN(H[W d!JX&SFSFSFSFS wrong
# REKEB RKB/ d!JX&SFSFSFSFS wrong
# Q@D@CIJM QDC/JM d!JX&SFSFSFSFS wrong
# Q:YIJR QYJR/c d!JX&SFSFSFSFS wrong
# MOW<;D MW<D/ d!JX&SFSFSFSFS wrong
# P.A<:AMON P<M(WN/ d!JX&SFSFSFSFS wrong
# <:AN@TOWT <NTWT/ d!JX&SFSFSFSFS wrong
# L:P@NEJK@ L-PN(H/J+K d!JX&SFSFSFSFS wrong
# B.AM.IL:X@M@H B-(H-MLXM(H/H d!JX&SFSFSFSFS wrong
# H@RA< H-R</ d!JX&SFSFSFSFS wrong
# H@>:AD@M@H H->DM(H/H d!JX&SFSFSFSFS wrong
# W:>EBEN W->BN/ d!JX&SFSFSFSFS wrong
# WAT.O>MAR:N@H W:n-!T!>MR[NH d!JX&SFSFSFSFS wrong
# H@>EBEN H->BN/ d!JX&SFSFSFSFS wrong
# >@FIJX@H !>!FJX[H d!JX&SFSFSFSFS wrong
# QODEC QDC/ d!JX&SFSFSFSFS wrong
# >UZ.;N >ZN d!JX&SFSFSFSFS wrong
# >;L >L/ d!JX&SFSFSFSFS wrong
# T.AXAT TXT/ d!JX&SFSFSFSFS wrong
# >:ELOHIJM >LH(J(M/JM d!JX&SFSFSFSFS wrong
# W:NOP W-NP/ d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# W.M:COW>@H W-MCW>(H/H d!JX&SFSFSFSFS wrong
# W:HAQ:R;B W-!!]H]QRB[ d!JX&SFSFSFSFS wrong
# LAP.@ROKET L-(H-PRK(T/T d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# W:>IJC W->JC/ d!JX&SFSFSFSFS wrong
# F:<AR F<R/c d!JX&SFSFSFSFS wrong
# WAJ.IB:NW. W:n-!J!BN(H[W d!JX&SFSFSFSFS wrong
# JOWD;< J&WD<[/ d!JX&SFSFSFSFS wrong
# WAJ:HIJ W:n-!J!HJ(H[ d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# M:<AV M<V/ d!JX&SFSFSFSFS wrong
# H@>OM;N H->MN[/ d!JX&SFSFSFSFS wrong
# XAJ XJ/ d!JX&SFSFSFSFS wrong
# HAHW.> H-HW> d!JX&SFSFSFSFS wrong
# K.W.C KWC/ d!JX&SFSFSFSFS wrong
# H@>:ELOHIJM H->LH(J(M/JM d!JX&SFSFSFSFS wrong
# >W.L@M >(J&WLM/ d!JX&SFSFSFSFS wrong
# T.AR:T.IJ T(WR[TJ d!JX&SFSFSFSFS wrong
# >EY:L@M >YL/+M d!JX&SFSFSFSFS wrong
# HAF.@DEH H-FDH/a d!JX&SFSFSFSFS wrong
# W:HID.AX:T.IJ W-]H](NDX[TJ d!JX&SFSFSFSFS wrong
# M@H MH d!JX&SFSFSFSFS wrong
# B.A<:AL;J B<L/J d!JX&SFSFSFSFS wrong
# HAJ.AR:D.;N H-JRDN/ d!JX&SFSFSFSFS wrong
# XEV:>@M XV>/+M d!JX&SFSFSFSFS wrong
# L:K@ L+K d!JX&SFSFSFSFS wrong
# T:DAB.;R !T!DBR[d d!JX&SFSFSFSFS wrong
# MIK.OL M(N-KL/ d!JX&SFSFSFSFS wrong
# B.EN BN/c d!JX&SFSFSFSFS wrong
# WAJ.IZ:K.OR W:n-!J!ZKR[ d!JX&SFSFSFSFS wrong
# K.OH;N KHN/ d!JX&SFSFSFSFS wrong
# C:K@B !!CKB[ d!JX&SFSFSFSFS wrong
# >AB:R@H@M >BRHM/ d!JX&SFSFSFSFS wrong
# B.:YUROWT BY(WR/WT d!JX&SFSFSFSFS wrong
# B.:Y;>T:KEM B-!!(JY>[/T+KM d!JX&SFSFSFSFS wrong
# H@>@REY H->RY/a d!JX&SFSFSFSFS wrong
# JIC:M@<;>L JCM<>L/ d!JX&SFSFSFSFS wrong
# >AK: >K d!JX&SFSFSFSFS wrong
# W:GAM W-GM d!JX&SFSFSFSFS wrong
# J@DAJ JD/J+(J d!JX&SFSFSFSFS wrong
# W.PIJN:X@S W-PJNXS/ d!JX&SFSFSFSFS wrong
# JIC:M:REN.W. !J!CMR[~N+(HW d!JX&SFSFSFSFS wrong
# HAJ.AR:D.;N H-JRDN/ d!JX&SFSFSFSFS wrong
# Q@YIJN QYJN/a d!JX&SFSFSFSFS wrong
# JA<:AMOD !J!<MD[ d!JX&SFSFSFSFS wrong
# T.AXAT TXT/ d!JX&SFSFSFSFS wrong
# L:F@R;J L-FR/J d!JX&SFSFSFSFS wrong
# ZIM:R@N ZMRN/ d!JX&SFSFSFSFS wrong
# WAT.:MAL.;V W:n-!T!MLV[d d!JX&SFSFSFSFS wrong
# NIP:L:>OWTEJK@ ]N]PL>[/WTJ+K d!JX&SFSFSFSFS wrong
# GIB:<OWN GB<WN/ d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# WAJ.@X@M W:n-!J!XM(M[ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# LA>:AX;JKEM L->X/J+KM d!JX&SFSFSFSFS wrong
# N:>UM N>M/ d!JX&SFSFSFSFS wrong
# H;N.@H HNH d!JX&SFSFSFSFS wrong
# L;K: !!(HLK[ d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# B:N;J BN/J d!JX&SFSFSFSFS wrong
# Q@CEH QCH/a d!JX&SFSFSFSFS wrong
# MOCEH MCH/ d!JX&SFSFSFSFS wrong
# WAJ.A<AN W:n-!J!<N(H[ d!JX&SFSFSFSFS wrong
# HAZ.OR:<IJM H-ZR<[/JM d!JX&SFSFSFSFS wrong
# W@>@R:D.: W->RD/ d!JX&SFSFSFSFS wrong
# L:<AD L-<D/ d!JX&SFSFSFSFS wrong
# J@DA<:T.@ JD<[T d!JX&SFSFSFSFS wrong
# WAJ.O>M:RW. W:n-!J!>MR[W d!JX&SFSFSFSFS wrong
# K.A>:ACER K->CR d!JX&SFSFSFSFS wrong
# <:AY;J <Y/J d!JX&SFSFSFSFS wrong
# N:BW.KAD:NE>Y.AR NBWKDN>YR/ d!JX&SFSFSFSFS wrong
# HAN.EGA< H-NG</ d!JX&SFSFSFSFS wrong
# S:RIJS SRJS/c d!JX&SFSFSFSFS wrong
# L:>IJC L->JC/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# Z:KOR !!ZKR[ d!JX&SFSFSFSFS wrong
# W:H@<AW.IJM W-H-<W(J(M/JM d!JX&SFSFSFSFS wrong
# H@>:AB@NIJM H->BN/JM d!JX&SFSFSFSFS wrong
# K.@B;D KBD/a d!JX&SFSFSFSFS wrong
# D.:R@KIJM DRK/JM d!JX&SFSFSFSFS wrong
# WAJ.;Y;> W:n-!J!(JY>[ d!JX&SFSFSFSFS wrong
# >AD:M@T@M >DM(H/T+M d!JX&SFSFSFSFS wrong
# R@< R</a d!JX&SFSFSFSFS wrong
# Q@DOWC QDWC/a d!JX&SFSFSFSFS wrong
# J@DIJ JD/+J d!JX&SFSFSFSFS wrong
# WAJ.@Q@M W:n-!J!Q(WM[ d!JX&SFSFSFSFS wrong
# W@>EC:Q:AL@H W:n-!>!CQL[H d!JX&SFSFSFSFS wrong
# R@>CIJM R>C/JM d!JX&SFSFSFSFS wrong
# H@<@M H-<M/a d!JX&SFSFSFSFS wrong
# Z.EH ZH d!JX&SFSFSFSFS wrong
# MOW>@B MW>B/ d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# HAZ.@K@R H-ZKR/a d!JX&SFSFSFSFS wrong
# VOWB VWB[ d!JX&SFSFSFSFS wrong
# G.AM GM d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# HAN.@X@C H-NXC/a d!JX&SFSFSFSFS wrong
# J:HWIH JHWH/ d!JX&SFSFSFSFS wrong
# L@K;N LKN d!JX&SFSFSFSFS wrong
# K.:>OWB K->WB/ d!JX&SFSFSFSFS wrong
# NIB:H:ALW. ]N]BHL[W d!JX&SFSFSFSFS wrong
# >AX:AR;JHEM >XR/J+HM d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# YAJID YJD/a d!JX&SFSFSFSFS wrong
# D.AB.;R !!DBR[d d!JX&SFSFSFSFS wrong
# >:ELOHIJM >LH(J(M/JM d!JX&SFSFSFSFS wrong
# RAB.IJM RB/JM d!JX&SFSFSFSFS wrong
# WAJ.;CEB W:n-!J!(JCB[ d!JX&SFSFSFSFS wrong
# <IM.@K: <M+K d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# LAM.@X:@R@T L-(H-MXR(T/Ta d!JX&SFSFSFSFS wrong
# H@>:ELOHIJM H->LH(J(M/JM d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# >:AL;JHEM >L&J+HM d!JX&SFSFSFSFS wrong
# W:HIL:B.AC:T.@M W-]H]LBC[T+M d!JX&SFSFSFSFS wrong
# N:>UM N>M/ d!JX&SFSFSFSFS wrong
# JIY:<AQ !J!Y<Q[ d!JX&SFSFSFSFS wrong
# >;LEJK@ >L&J+K d!JX&SFSFSFSFS wrong
# COWL;XA C&WLX[/ d!JX&SFSFSFSFS wrong
# M;>AXAR M(N->XR/ d!JX&SFSFSFSFS wrong
# W:Z;JTIJM W-ZJT/JM d!JX&SFSFSFSFS wrong
# <:AY;J <Y/J d!JX&SFSFSFSFS wrong
# MIV.@H MV(H/H d!JX&SFSFSFSFS wrong
# P.:N;J PN(H/J d!JX&SFSFSFSFS wrong
# JIF@FK@R JFFKR/ d!JX&SFSFSFSFS wrong
# WAJ.IQ:R@> W:n-!J!QR>[ d!JX&SFSFSFSFS wrong
# >@QW.M@H !>!QWM[H d!JX&SFSFSFSFS wrong
# MIN MN d!JX&SFSFSFSFS wrong
# HIN.;H HNH d!JX&SFSFSFSFS wrong
# MA<:AFEH M<FH/a d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# >@MAR >MR[ d!JX&SFSFSFSFS wrong
# CAL:M;JKEM CLM/J+KM d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# NIM.@L;V !N!](N]MLV[ d!JX&SFSFSFSFS wrong
# W.B:N;J W-BN/J d!JX&SFSFSFSFS wrong
# L:B;JT L-BJT d!JX&SFSFSFSFS wrong
# >OTOW >T+W d!JX&SFSFSFSFS wrong
# WAJ.O>MER W:n-!J!>MR[ d!JX&SFSFSFSFS wrong
# QOWL QWL/ d!JX&SFSFSFSFS wrong
# JIF:R@>;L JFR>L/ d!JX&SFSFSFSFS wrong
# L:QIJC L-QJC/ d!JX&SFSFSFSFS wrong
# W.L:K@L W-L-KL/ d!JX&SFSFSFSFS wrong
# HAX;R:CIJM H-XRC/JM d!JX&SFSFSFSFS wrong
# H:ALOW> H-L&W> d!JX&SFSFSFSFS wrong
# W:XAJ W-XJ(H[ d!JX&SFSFSFSFS wrong
# HW.> HW> d!JX&SFSFSFSFS wrong
# M;>AX:AR;J M(N->XR/J d!JX&SFSFSFSFS wrong
# K.:YIJR;J K-YJR/J d!JX&SFSFSFSFS wrong
# G.@>@L:T.@ G>L[T d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# HOL;K: HLK[/ d!JX&SFSFSFSFS wrong
# B.EN BN/c d!JX&SFSFSFSFS wrong
# LIB:NOWT L-!!BN(H[/WT d!JX&SFSFSFSFS wrong
# HAM.OWV H-MWV/ d!JX&SFSFSFSFS wrong
# L@>:EMORIJ L-(H->MRJ/ d!JX&SFSFSFSFS wrong
# WAJ.IC.@Q;HW. W:n-!J!(NCQ[+HW d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# W.M@R;J W-MR/J d!JX&SFSFSFSFS wrong
# W:CEMEN W-CMN/ d!JX&SFSFSFSFS wrong
# K.AM.@H K-MH d!JX&SFSFSFSFS wrong
# MIC.@M M(N-CM d!JX&SFSFSFSFS wrong
# H@<@M H-<M/a d!JX&SFSFSFSFS wrong
# JAXAD JXD/ d!JX&SFSFSFSFS wrong
# HAJ.IT:RIJ H-JTRJ/ d!JX&SFSFSFSFS wrong
# P.@N@JW PN(H/J+W d!JX&SFSFSFSFS wrong
# X:ALOWM XLWM/ d!JX&SFSFSFSFS wrong
# T@MUTW. !T!M(WT[W d!JX&SFSFSFSFS wrong
# >EX@JW >X/J+W d!JX&SFSFSFSFS wrong
# >;J >J d!JX&SFSFSFSFS wrong
# >EL:T.:Q;> >LTQ>/ d!JX&SFSFSFSFS wrong
# B.:>OHEL B->HL/ d!JX&SFSFSFSFS wrong
# W.B:N;J W-BN/J d!JX&SFSFSFSFS wrong
# <AM.EK@ <M/+K d!JX&SFSFSFSFS wrong
# Y:B@>OWT YB>/WTa d!JX&SFSFSFSFS wrong
# K.IJ KJ d!JX&SFSFSFSFS wrong
# WAJ.O>MER W:n-!J!>MR[ d!JX&SFSFSFSFS wrong
# D.@M DM/a d!JX&SFSFSFSFS wrong
# JIH:JEH !J!HJH[ d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# HAJ.:HW.DIJM H-JHWD(J/JM d!JX&SFSFSFSFS wrong
# WAT.O>MER W:n-!T!>MR[ d!JX&SFSFSFSFS wrong
# HAC.;NIJ H-CNJ/ d!JX&SFSFSFSFS wrong
# J:HOWCU<A JHWC</ d!JX&SFSFSFSFS wrong
# H@<@M H-<M/a d!JX&SFSFSFSFS wrong
# X@M;C XMC/a d!JX&SFSFSFSFS wrong
# JOWR:DIJM J&WRD[/JM d!JX&SFSFSFSFS wrong
# XIG:RW. !!XGR[W d!JX&SFSFSFSFS wrong
# >EREK: >RK/c d!JX&SFSFSFSFS wrong
# W.MIM.:YW.QOT;JHEM W-M(N-MYWQ(H/(WTJ+HM d!JX&SFSFSFSFS wrong
# >AC:R;JK: >CR/J+K d!JX&SFSFSFSFS wrong
# T.@MIJD TMJD/ d!JX&SFSFSFSFS wrong
# HAM.AJIM H-MJ(M/(JM d!JX&SFSFSFSFS wrong
# JO>CIJ.@HW. J>CJHW/ d!JX&SFSFSFSFS wrong
# B.EN BN/c d!JX&SFSFSFSFS wrong
# H@>AM.@H H->M(H/H d!JX&SFSFSFSFS wrong
# K.;N KN d!JX&SFSFSFSFS wrong
# >AT.EM >TM d!JX&SFSFSFSFS wrong
# HAQ:R;B !!]H]QRB[/a d!JX&SFSFSFSFS wrong
# K.:SIJLIJM KSJL/JM d!JX&SFSFSFSFS wrong
# J:<OWD;D !J!<WD&D[d d!JX&SFSFSFSFS wrong
# L:MA<AN LM<N d!JX&SFSFSFSFS wrong
# XAT.IJM XT/JM d!JX&SFSFSFSFS wrong
# G@D GD/ d!JX&SFSFSFSFS wrong
# Z@K@R ZKR/a d!JX&SFSFSFSFS wrong
# HAN.:XOCET H-NXC(T/T d!JX&SFSFSFSFS wrong
# C@M CM d!JX&SFSFSFSFS wrong
# WAJ.O>MER W:n-!J!>MR[ d!JX&SFSFSFSFS wrong
# WAJ:HIJ W:n-!J!HJ(H[ d!JX&SFSFSFSFS wrong
# M:BOR@K: !M!BRK[/du d!JX&SFSFSFSFS wrong
# HAB.:RIJT H-BRJT/ d!JX&SFSFSFSFS wrong
# MOW<;D MW<D/ d!JX&SFSFSFSFS wrong
# B.:P@N@JW B-PN(H/J+W d!JX&SFSFSFSFS wrong
# C;MOWT CM/WTa d!JX&SFSFSFSFS wrong
# L@NW.S L-!!NWS[/c d!JX&SFSFSFSFS wrong
# W@CEBER W-CBR/ d!JX&SFSFSFSFS wrong
# CIB.AR:T.@ CBR[Td d!JX&SFSFSFSFS wrong
# HAM.ELEK: H-MLK/ d!JX&SFSFSFSFS wrong
# >:AX;RIJM >XR/JM d!JX&SFSFSFSFS wrong
# T.:CW.<@H TCW<(H/H d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# X:ATAT XTT/ d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# W.P@QAD:T.IJ W-PQD[TJ d!JX&SFSFSFSFS wrong
# HAJ.AR:D.;N H-JRDN/ d!JX&SFSFSFSFS wrong
# SOP:DIJM SPD[/JM d!JX&SFSFSFSFS wrong
# C:BW.T;JKEM CBWT/J+KM d!JX&SFSFSFSFS wrong
# HAM.IZ:B.;XA H-MZBX/ d!JX&SFSFSFSFS wrong
# XIZ:QIJ.@H XZQJH/ d!JX&SFSFSFSFS wrong
# TA<:AFEH !T!<FH[ d!JX&SFSFSFSFS wrong
# C:N;J CN(J(M/J d!JX&SFSFSFSFS wrong
# >EL >L d!JX&SFSFSFSFS wrong
# >:ELOHEJK@ >LH(J(M/J+K d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# W:JOC:B;JHEM W-JCB[/J+HM d!JX&SFSFSFSFS wrong
# W:H@L@K:T.@ W-HLK[T d!JX&SFSFSFSFS wrong
# >:ADON@J >DNJ/ d!JX&SFSFSFSFS wrong
# G.AL GL/ d!JX&SFSFSFSFS wrong
# L@H. L+H d!JX&SFSFSFSFS wrong
# HAZ.EH H-ZH d!JX&SFSFSFSFS wrong
# >@MAR >MR[ d!JX&SFSFSFSFS wrong
# L;>MOR L-!!>MR[/c d!JX&SFSFSFSFS wrong
# <;D <D/ d!JX&SFSFSFSFS wrong
# HAV.AB.@<OWT H-VB<(T/WTa d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# XEREB XRB/ d!JX&SFSFSFSFS wrong
# C@M.@H CM~H d!JX&SFSFSFSFS wrong
# J:DIJDOT JDJD(T/(WT d!JX&SFSFSFSFS wrong
# WAJ.O>MER W:n-!J!>MR[ d!JX&SFSFSFSFS wrong
# T.AX:Q:RW.N !T!XQR[WN d!JX&SFSFSFSFS wrong
# B.:<;JN;J B-<JN/J d!JX&SFSFSFSFS wrong
# <AL <L d!JX&SFSFSFSFS wrong
# VOWB VWB/ d!JX&SFSFSFSFS wrong
# <:AB@D@JW <BD/J+W d!JX&SFSFSFSFS wrong
# W.N:>UM W-N>M/ d!JX&SFSFSFSFS wrong
# J:HW@H JHWH/ d!JX&SFSFSFSFS wrong
# W:HIN.;H W-HNH d!JX&SFSFSFSFS wrong
# W:N@TAT.@H W-NT(N[T&H d!JX&SFSFSFSFS wrong
# W.P:L;JV@H W-PLJV(H/H d!JX&SFSFSFSFS wrong
# B.AJ.OWM B-(H-JWM/ d!JX&SFSFSFSFS wrong
# C:MW.>;L CMW>L/ d!JX&SFSFSFSFS wrong
# L:HAG.IJD L-!!]H](NG&JD[/c d!JX&SFSFSFSFS wrong
# B.:Z@DOWN B-ZDWN/a d!JX&SFSFSFSFS wrong
# <@P@R <PR/a d!JX&SFSFSFSFS wrong
# >;L.EH >LH d!JX&SFSFSFSFS wrong
# <EF:R;H <FRH/ d!JX&SFSFSFSFS wrong
# >ET.;N !>!(NTN[ d!JX&SFSFSFSFS wrong
# W:NIL.@X:AM@H W-!N!](N]LXM[H d!JX&SFSFSFSFS wrong
# W:JETER W-JTR/ d!JX&SFSFSFSFS wrong
# W:H@R:XOQOWT W-H-RX(WQ/WT d!JX&SFSFSFSFS wrong
# HAN.;ROT H-NR/(WT d!JX&SFSFSFSFS wrong
# >AB:N;J >BN/J d!JX&SFSFSFSFS wrong
# LO> L> d!JX&SFSFSFSFS wrong
# L@NW. L+NW d!JX&SFSFSFSFS wrong
# HE>:EZIJNW. ]H]>Z&JN[W d!JX&SFSFSFSFS wrong
# W:X@LW. W-X(JL[W d!JX&SFSFSFSFS wrong
# >:ACER >CR d!JX&SFSFSFSFS wrong
# W:JIN.@Z:RW. W-!J!](N]NZR[W d!JX&SFSFSFSFS wrong
# LAJHW@H L-JHWH/ d!JX&SFSFSFSFS wrong
# G.@G GG/a d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# K.IK.AR KKR/c d!JX&SFSFSFSFS wrong
# D@WID DWD/ d!JX&SFSFSFSFS wrong
# HAZ.EH H-ZH d!JX&SFSFSFSFS wrong
# >ET >T d!JX&SFSFSFSFS wrong
# W.L:B@NEJK@ W-L-BN/J+K d!JX&SFSFSFSFS wrong
# MIB.OW> M(N-!!BW>[/ d!JX&SFSFSFSFS wrong
# W:CIB:<AT W-CB</Tc d!JX&SFSFSFSFS wrong
# W:REKEB W-RKB/ d!JX&SFSFSFSFS wrong
# W:LO> W-L> d!JX&SFSFSFSFS wrong
# R@X:B.@H. RXB/+H d!JX&SFSFSFSFS wrong
# K.AB.IJRIJM KBJR/JM d!JX&SFSFSFSFS wrong
# K.A>:ACER K->CR d!JX&SFSFSFSFS wrong
# K.@L KL/ d!JX&SFSFSFSFS wrong
# 9487
# 0.0

# %%
len(all_preds)
# Out:
# 9487
